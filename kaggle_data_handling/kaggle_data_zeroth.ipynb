# %% [raw]
#           Reading geometry description geometry.in.
# ------------------------------------------------------------
#   Input structure read successfully.
#   The structure contains       80 atoms,  and a total of       1016.000 electrons.
#
#   Input geometry:
#   | Unit cell:
#   |         6.238403         0.016947        -0.010515
#   |        -3.135384         5.396237         0.016790
#   |         0.040246        -0.048064        23.532612
#   | Atomic structure:
#   |       Atom                x [A]            y [A]            z [A]
#   |    1: Species Al             0.013606        -0.010724         5.857280
#   |    2: Species Al             0.023299        -0.032628        17.650178
#   |    3: Species Ga             4.672000         2.714065         5.844236
#   |    4: Species Ga             4.697407         2.687738        17.658482
#   |    5: Species Al             3.123474         0.005800         5.837938
#   |    6: Species Al             3.155369        -0.021814        17.642879
#   |    7: Species Ga             1.567799         2.699131         5.873834
#   |    8: Species Al             1.583240         2.685123        17.649250
#   |    9: Species Al             0.002130         0.000912        -0.048549
#   |   10: Species Al             0.012930        -0.011929        11.815515
#   |   11: Species Al             4.668588         2.727112        -0.056058
#   |   12: Species Al             4.689316         2.691377        11.816246
#   |   13: Species Al             3.117537         0.012577        -0.049610
#   |   14: Species Ga             3.148185        -0.000162        11.804434
#   |   15: Species Ga             1.555414         2.718636        -0.056202
#   |   16: Species Al             1.575064         2.691366        11.839600
#   |   17: Species Ga            -0.011937         1.801419         2.891203
#   |   18: Species Ga             0.019547         1.778245        14.742213
#   |   19: Species Al            -1.559611         4.498465         2.901296
#   |   20: Species Al            -1.545023         4.483120        14.742948
#   |   21: Species Al             3.130345         1.801779         2.877756
#   |   22: Species Al             3.135470         1.784277        14.739221
#   |   23: Species Ga             1.543262         4.519733         2.915061
#   |   24: Species Al             1.566507         4.489772        14.746235
#   |   25: Species Ga             1.570582         0.879783         8.838927
#   |   26: Species Ga             1.593332         0.868269        20.559073
#   |   27: Species Ga            -0.004780         3.596051         8.858494
#   |   28: Species Al             0.017586         3.570269        20.575504
#   |   29: Species Al             4.691214         0.898701         8.804372
#   |   30: Species Al             4.709503         0.885031        20.570668
#   |   31: Species Ga             3.132065         3.606042         8.879105
#   |   32: Species Al             3.149817         3.578914        20.570802
#   |   33: Species O             -0.000312         1.741058         4.929509
#   |   34: Species O              0.069631         1.749557        16.744112
#   |   35: Species O             -1.556183         4.553620         4.867445
#   |   36: Species O             -1.532648         4.532967        16.712554
#   |   37: Species O              3.123413         1.743408         4.873875
#   |   38: Species O              3.093429         1.744213        16.692097
#   |   39: Species O              1.547498         4.568400         4.912969
#   |   40: Species O              1.559166         4.488536        16.694381
#   |   41: Species O              1.576648         0.819593         6.811993
#   |   42: Species O              1.592557         0.879395        18.579031
#   |   43: Species O             -0.011849         3.666760         6.811689
#   |   44: Species O              0.070755         3.596201        18.616624
#   |   45: Species O              4.673879         0.841936         6.850195
#   |   46: Species O              4.704851         0.833886        18.594708
#   |   47: Species O              3.129932         3.666076         6.794827
#   |   48: Species O              3.088918         3.603798        18.598164
#   |   49: Species O              1.528388         0.922902        10.891130
#   |   50: Species O              1.598414         0.808290        22.582060
#   |   51: Species O              0.005911         3.527021        10.887327
#   |   52: Species O             -0.038249         3.585018        22.526278
#   |   53: Species O              4.742231         0.937685        10.843362
#   |   54: Species O              4.710695         0.899681        22.506751
#   |   55: Species O              3.131324         3.591799        10.880864
#   |   56: Species O              3.213000         3.594147        22.529167
#   |   57: Species O             -0.060708         1.790553         0.878399
#   |   58: Species O              0.008034         1.785025        12.755327
#   |   59: Species O             -1.559301         4.481266         0.936834
#   |   60: Species O             -1.590911         4.451297        12.784058
#   |   61: Species O              3.176220         1.794592         0.914540
#   |   62: Species O              3.143448         1.843720        12.776676
#   |   63: Species O              1.542421         4.565603         0.860985
#   |   64: Species O              1.609594         4.470038        12.769960
#   |   65: Species O              0.050829        -0.027951         2.861763
#   |   66: Species O              0.023056        -0.077738        14.739527
#   |   67: Species O              4.627921         2.744055         2.940230
#   |   68: Species O              4.647629         2.721818        14.782728
#   |   69: Species O              3.077716         0.035781         2.861393
#   |   70: Species O              3.145696        -0.012985        14.688156
#   |   71: Species O              1.602671         2.683244         2.884607
#   |   72: Species O              1.621960         2.715971        14.733931
#   |   73: Species O             -0.032623         0.013227         8.864244
#   |   74: Species O             -0.012994        -0.060341        20.568883
#   |   75: Species O              4.682283         2.648531         8.796009
#   |   76: Species O              4.702606         2.681993        20.508213
#   |   77: Species O              3.180564         0.024401         8.928736
#   |   78: Species O              3.201713        -0.050982        20.565058
#   |   79: Species O              1.568897         2.693127         8.768214
#   |   80: Species O              1.588450         2.726684        20.624242
#   |

# %%
import numpy as np
import pandas as pd

# %%
def lattmat(df,ajdi,relaxation_step_number):
    """Create a numpy matrix of lattice vectors. A column = a vector.
    
    Keyword arguments:
    df -- dataframe of the lattice vectors
    ajdi -- id of the material
    relaxation_step_number -- self explanatory
    """
    return np.transpose(df.loc[(df["id"]==ajdi) & (df["relaxation_step_number"]==relaxation_step_number)].loc[:,["lattice_vector_1_x" ,"lattice_vector_1_y" ,"lattice_vector_1_z" ,"lattice_vector_2_x" ,"lattice_vector_2_y" ,"lattice_vector_2_z" ,"lattice_vector_3_x" ,"lattice_vector_3_y", "lattice_vector_3_z"]].to_numpy().reshape(3,3))

# %%
def zeroth(raw_data_file, ajdi,df_general):
    with open(raw_data_file, 'r') as file:
        lines = ""
        line = ""
        df_atomic_egy = pd.DataFrame(columns=["id","relaxation_step_number","formation_energy_ev_natom","bandgap_energy_ev"])
        while True:
            try:
                line = next(file)
                if "The structure contains" in line:
                    num = line.split()[3]
                    [next(file) for _ in range(3)]
                    dic={}
                    dummy=[]
                    for _ in range(3):
                        line = next(file)
                        lines += line
                    for line in lines.splitlines():
                        dummy.append(line.split()[1:])
                    dic = {'id': ajdi, 'relaxation_step_number': 0, 
                           'lattice_vector_1_x': float(dummy[0][0]), 
                           'lattice_vector_1_y': float(dummy[0][1]), 
                           'lattice_vector_1_z': float(dummy[0][2]),
                           'lattice_vector_2_x': float(dummy[1][0]),
                           'lattice_vector_2_y': float(dummy[1][1]),
                           'lattice_vector_2_z': float(dummy[1][2]),
                           'lattice_vector_3_x': float(dummy[2][0]),
                           'lattice_vector_3_y': float(dummy[2][1]),
                           'lattice_vector_3_z': float(dummy[2][2]),
                          }
                    df_latt = pd.concat([pd.Series(v, name=k) for k, v in dic.items()], axis=1)
                    #print("Number of atoms:", num)
                    [next(file) for _ in range(2)]
                    x=[]
                    y=[]
                    z=[]
                    species=[]
                    dic={}
                    for _ in range(int(num)):
                        line = next(file)
                        data = line.split()[-4:]
                        #print("Atomic xyz:",line.split()[-4:])
                        x.append(data[1])
                        y.append(data[2])
                        z.append(data[3])
                        species.append(data[0])
                    dic = {"id": [ajdi for _ in range(len(species))], "relaxation_step_number": [0 for _ in range(len(species))], "species": species, "x [A]": x, "y [A]": y, "z [A]": z}
                    df_atomic_xyz = pd.concat([pd.Series(v, name=k) for k, v in dic.items()], axis=1)
                
                if "Total energy                  :" in line:
                    total_energy = float(line.split()[-2])
                if "ESTIMATED overall HOMO-LUMO gap:" in line:
                    gap_energy = float(line.split()[4])
                if "Relaxation step number      1:" in line:
                    values = df_general[df_general["id"]==ajdi].values[0]
                    foo = -2.5*(float(values[3])*(-3876.638238492914) + float(values[4])*(-22502.75773920757) + float(values[5])*(-66080.69404540183) - total_energy/float(values[2]))
                    dic = {"id": ajdi, "relaxation_step_number": 0, "formation_energy_ev_natom": foo, "bandgap_energy_ev": gap_energy}
                    df_atomic_egy = pd.concat([pd.Series(v, name=k) for k, v in dic.items()], axis=1)
            except StopIteration:
                print(ajdi,"ended.")
                return df_atomic_xyz, df_latt, df_atomic_egy

# %%
# test set
df_general = pd.read_csv("/home/jurka/research-project/test/relaxation/general.csv")
df_egy = pd.read_csv("/home/jurka/research-project/test/relaxation/energy_relaxation.csv")
df_latt = pd.read_csv("/home/jurka/research-project/test/relaxation/lattice_vector_relaxation.csv")
df_frac = pd.read_csv("/home/jurka/research-project/test/relaxation/atoms_frac_xyz_relaxation.csv")
df_xyz = pd.read_csv("/home/jurka/research-project/test/relaxation/atoms_xyz_relaxation.csv")

list_of_file_numbers = [i for i in range(1,601)]

for i in list_of_file_numbers:
    path = "".join(["/home/jurka/Desktop/REE/nomad_kaggle_bandfiles/test_bandfiles/just_bandfiles/", str(i), "/band.out"])
    
    df_xyz_zeroth, df_latt_zeroth, df_egy_zeroth = zeroth(path, i, df_general)
    
    
    #df_xyz = pd.concat([df_xyz, df_xyz_zeroth]).reset_index(drop=True)
    #df_latt = pd.concat([df_latt, df_latt_zeroth]).reset_index(drop=True)
    
    A = np.linalg.inv(lattmat(df_latt_zeroth,i,0))
    
    material = df_xyz_zeroth.loc[df_xyz_zeroth["id"]==i][df_xyz_zeroth.columns[3:].to_list()].to_numpy(dtype=float)
    
    material_frac = np.round(np.dot(material,np.transpose(A)),decimals=6)
    
    df_frac_zeroth = pd.DataFrame(material_frac, columns=["L1", "L2", "L3"])
    df_frac_zeroth = df_xyz_zeroth[df_xyz_zeroth.columns.to_list()[:3]].join(df_frac_zeroth,how="left")
    
    if len(df_latt[(df_latt["id"]==i) & (df_latt["relaxation_step_number"]==0)])==0:
        pos = df_frac.loc[df_frac["id"]==i].iloc[0].name
        df_frac = pd.concat([df_frac.iloc[:pos], df_frac_zeroth, df_frac.iloc[pos:]]).reset_index(drop=True)

        pos = df_xyz.loc[df_xyz["id"]==i].iloc[0].name
        df_xyz = pd.concat([df_xyz.iloc[:pos], df_xyz_zeroth, df_xyz.iloc[pos:]]).reset_index(drop=True)

        pos = df_latt.loc[df_latt["id"]==i].iloc[0].name
        df_latt = pd.concat([df_latt.iloc[:pos], df_latt_zeroth, df_latt.iloc[pos:]]).reset_index(drop=True)
        
        pos = df_egy.loc[df_egy["id"]==i].iloc[0].name
        df_egy = pd.concat([df_egy.iloc[:pos], df_egy_zeroth, df_egy.iloc[pos:]]).reset_index(drop=True)
        
df_latt.to_csv("/home/jurka/research-project/test/relaxation/with_all_zeroes/lattice.csv", index = False)
df_egy.to_csv("/home/jurka/research-project/test/relaxation/with_all_zeroes/energy.csv", index = False)
df_xyz.to_csv("/home/jurka/research-project/test/relaxation/with_all_zeroes/xyz.csv", index = False)
df_frac.to_csv("/home/jurka/research-project/test/relaxation/with_all_zeroes/frac.csv", index = False)
# Out:
# 1 ended.
# 2 ended.
# 3 ended.
# 4 ended.
# 5 ended.
# 6 ended.
# 7 ended.
# 8 ended.
# 9 ended.
# 10 ended.
# 11 ended.
# 12 ended.
# 13 ended.
# 14 ended.
# 15 ended.
# 16 ended.
# 17 ended.
# 18 ended.
# 19 ended.
# 20 ended.
# 21 ended.
# 22 ended.
# 23 ended.
# 24 ended.
# 25 ended.
# 26 ended.
# 27 ended.
# 28 ended.
# 29 ended.
# 30 ended.
# 31 ended.
# 32 ended.
# 33 ended.
# 34 ended.
# 35 ended.
# 36 ended.
# 37 ended.
# 38 ended.
# 39 ended.
# 40 ended.
# 41 ended.
# 42 ended.
# 43 ended.
# 44 ended.
# 45 ended.
# 46 ended.
# 47 ended.
# 48 ended.
# 49 ended.
# 50 ended.
# 51 ended.
# 52 ended.
# 53 ended.
# 54 ended.
# 55 ended.
# 56 ended.
# 57 ended.
# 58 ended.
# 59 ended.
# 60 ended.
# 61 ended.
# 62 ended.
# 63 ended.
# 64 ended.
# 65 ended.
# 66 ended.
# 67 ended.
# 68 ended.
# 69 ended.
# 70 ended.
# 71 ended.
# 72 ended.
# 73 ended.
# 74 ended.
# 75 ended.
# 76 ended.
# 77 ended.
# 78 ended.
# 79 ended.
# 80 ended.
# 81 ended.
# 82 ended.
# 83 ended.
# 84 ended.
# 85 ended.
# 86 ended.
# 87 ended.
# 88 ended.
# 89 ended.
# 90 ended.
# 91 ended.
# 92 ended.
# 93 ended.
# 94 ended.
# 95 ended.
# 96 ended.
# 97 ended.
# 98 ended.
# 99 ended.
# 100 ended.
# 101 ended.
# 102 ended.
# 103 ended.
# 104 ended.
# 105 ended.
# 106 ended.
# 107 ended.
# 108 ended.
# 109 ended.
# 110 ended.
# 111 ended.
# 112 ended.
# 113 ended.
# 114 ended.
# 115 ended.
# 116 ended.
# 117 ended.
# 118 ended.
# 119 ended.
# 120 ended.
# 121 ended.
# 122 ended.
# 123 ended.
# 124 ended.
# 125 ended.
# 126 ended.
# 127 ended.
# 128 ended.
# 129 ended.
# 130 ended.
# 131 ended.
# 132 ended.
# 133 ended.
# 134 ended.
# 135 ended.
# 136 ended.
# 137 ended.
# 138 ended.
# 139 ended.
# 140 ended.
# 141 ended.
# 142 ended.
# 143 ended.
# 144 ended.
# 145 ended.
# 146 ended.
# 147 ended.
# 148 ended.
# 149 ended.
# 150 ended.
# 151 ended.
# 152 ended.
# 153 ended.
# 154 ended.
# 155 ended.
# 156 ended.
# 157 ended.
# 158 ended.
# 159 ended.
# 160 ended.
# 161 ended.
# 162 ended.
# 163 ended.
# 164 ended.
# 165 ended.
# 166 ended.
# 167 ended.
# 168 ended.
# 169 ended.
# 170 ended.
# 171 ended.
# 172 ended.
# 173 ended.
# 174 ended.
# 175 ended.
# 176 ended.
# 177 ended.
# 178 ended.
# 179 ended.
# 180 ended.
# 181 ended.
# 182 ended.
# 183 ended.
# 184 ended.
# 185 ended.
# 186 ended.
# 187 ended.
# 188 ended.
# 189 ended.
# 190 ended.
# 191 ended.
# 192 ended.
# 193 ended.
# 194 ended.
# 195 ended.
# 196 ended.
# 197 ended.
# 198 ended.
# 199 ended.
# 200 ended.
# 201 ended.
# 202 ended.
# 203 ended.
# 204 ended.
# 205 ended.
# 206 ended.
# 207 ended.
# 208 ended.
# 209 ended.
# 210 ended.
# 211 ended.
# 212 ended.
# 213 ended.
# 214 ended.
# 215 ended.
# 216 ended.
# 217 ended.
# 218 ended.
# 219 ended.
# 220 ended.
# 221 ended.
# 222 ended.
# 223 ended.
# 224 ended.
# 225 ended.
# 226 ended.
# 227 ended.
# 228 ended.
# 229 ended.
# 230 ended.
# 231 ended.
# 232 ended.
# 233 ended.
# 234 ended.
# 235 ended.
# 236 ended.
# 237 ended.
# 238 ended.
# 239 ended.
# 240 ended.
# 241 ended.
# 242 ended.
# 243 ended.
# 244 ended.
# 245 ended.
# 246 ended.
# 247 ended.
# 248 ended.
# 249 ended.
# 250 ended.
# 251 ended.
# 252 ended.
# 253 ended.
# 254 ended.
# 255 ended.
# 256 ended.
# 257 ended.
# 258 ended.
# 259 ended.
# 260 ended.
# 261 ended.
# 262 ended.
# 263 ended.
# 264 ended.
# 265 ended.
# 266 ended.
# 267 ended.
# 268 ended.
# 269 ended.
# 270 ended.
# 271 ended.
# 272 ended.
# 273 ended.
# 274 ended.
# 275 ended.
# 276 ended.
# 277 ended.
# 278 ended.
# 279 ended.
# 280 ended.
# 281 ended.
# 282 ended.
# 283 ended.
# 284 ended.
# 285 ended.
# 286 ended.
# 287 ended.
# 288 ended.
# 289 ended.
# 290 ended.
# 291 ended.
# 292 ended.
# 293 ended.
# 294 ended.
# 295 ended.
# 296 ended.
# 297 ended.
# 298 ended.
# 299 ended.
# 300 ended.
# 301 ended.
# 302 ended.
# 303 ended.
# 304 ended.
# 305 ended.
# 306 ended.
# 307 ended.
# 308 ended.
# 309 ended.
# 310 ended.
# 311 ended.
# 312 ended.
# 313 ended.
# 314 ended.
# 315 ended.
# 316 ended.
# 317 ended.
# 318 ended.
# 319 ended.
# 320 ended.
# 321 ended.
# 322 ended.
# 323 ended.
# 324 ended.
# 325 ended.
# 326 ended.
# 327 ended.
# 328 ended.
# 329 ended.
# 330 ended.
# 331 ended.
# 332 ended.
# 333 ended.
# 334 ended.
# 335 ended.
# 336 ended.
# 337 ended.
# 338 ended.
# 339 ended.
# 340 ended.
# 341 ended.
# 342 ended.
# 343 ended.
# 344 ended.
# 345 ended.
# 346 ended.
# 347 ended.
# 348 ended.
# 349 ended.
# 350 ended.
# 351 ended.
# 352 ended.
# 353 ended.
# 354 ended.
# 355 ended.
# 356 ended.
# 357 ended.
# 358 ended.
# 359 ended.
# 360 ended.
# 361 ended.
# 362 ended.
# 363 ended.
# 364 ended.
# 365 ended.
# 366 ended.
# 367 ended.
# 368 ended.
# 369 ended.
# 370 ended.
# 371 ended.
# 372 ended.
# 373 ended.
# 374 ended.
# 375 ended.
# 376 ended.
# 377 ended.
# 378 ended.
# 379 ended.
# 380 ended.
# 381 ended.
# 382 ended.
# 383 ended.
# 384 ended.
# 385 ended.
# 386 ended.
# 387 ended.
# 388 ended.
# 389 ended.
# 390 ended.
# 391 ended.
# 392 ended.
# 393 ended.
# 394 ended.
# 395 ended.
# 396 ended.
# 397 ended.
# 398 ended.
# 399 ended.
# 400 ended.
# 401 ended.
# 402 ended.
# 403 ended.
# 404 ended.
# 405 ended.
# 406 ended.
# 407 ended.
# 408 ended.
# 409 ended.
# 410 ended.
# 411 ended.
# 412 ended.
# 413 ended.
# 414 ended.
# 415 ended.
# 416 ended.
# 417 ended.
# 418 ended.
# 419 ended.
# 420 ended.
# 421 ended.
# 422 ended.
# 423 ended.
# 424 ended.
# 425 ended.
# 426 ended.
# 427 ended.
# 428 ended.
# 429 ended.
# 430 ended.
# 431 ended.
# 432 ended.
# 433 ended.
# 434 ended.
# 435 ended.
# 436 ended.
# 437 ended.
# 438 ended.
# 439 ended.
# 440 ended.
# 441 ended.
# 442 ended.
# 443 ended.
# 444 ended.
# 445 ended.
# 446 ended.
# 447 ended.
# 448 ended.
# 449 ended.
# 450 ended.
# 451 ended.
# 452 ended.
# 453 ended.
# 454 ended.
# 455 ended.
# 456 ended.
# 457 ended.
# 458 ended.
# 459 ended.
# 460 ended.
# 461 ended.
# 462 ended.
# 463 ended.
# 464 ended.
# 465 ended.
# 466 ended.
# 467 ended.
# 468 ended.
# 469 ended.
# 470 ended.
# 471 ended.
# 472 ended.
# 473 ended.
# 474 ended.
# 475 ended.
# 476 ended.
# 477 ended.
# 478 ended.
# 479 ended.
# 480 ended.
# 481 ended.
# 482 ended.
# 483 ended.
# 484 ended.
# 485 ended.
# 486 ended.
# 487 ended.
# 488 ended.
# 489 ended.
# 490 ended.
# 491 ended.
# 492 ended.
# 493 ended.
# 494 ended.
# 495 ended.
# 496 ended.
# 497 ended.
# 498 ended.
# 499 ended.
# 500 ended.
# 501 ended.
# 502 ended.
# 503 ended.
# 504 ended.
# 505 ended.
# 506 ended.
# 507 ended.
# 508 ended.
# 509 ended.
# 510 ended.
# 511 ended.
# 512 ended.
# 513 ended.
# 514 ended.
# 515 ended.
# 516 ended.
# 517 ended.
# 518 ended.
# 519 ended.
# 520 ended.
# 521 ended.
# 522 ended.
# 523 ended.
# 524 ended.
# 525 ended.
# 526 ended.
# 527 ended.
# 528 ended.
# 529 ended.
# 530 ended.
# 531 ended.
# 532 ended.
# 533 ended.
# 534 ended.
# 535 ended.
# 536 ended.
# 537 ended.
# 538 ended.
# 539 ended.
# 540 ended.
# 541 ended.
# 542 ended.
# 543 ended.
# 544 ended.
# 545 ended.
# 546 ended.
# 547 ended.
# 548 ended.
# 549 ended.
# 550 ended.
# 551 ended.
# 552 ended.
# 553 ended.
# 554 ended.
# 555 ended.
# 556 ended.
# 557 ended.
# 558 ended.
# 559 ended.
# 560 ended.
# 561 ended.
# 562 ended.
# 563 ended.
# 564 ended.
# 565 ended.
# 566 ended.
# 567 ended.
# 568 ended.
# 569 ended.
# 570 ended.
# 571 ended.
# 572 ended.
# 573 ended.
# 574 ended.
# 575 ended.
# 576 ended.
# 577 ended.
# 578 ended.
# 579 ended.
# 580 ended.
# 581 ended.
# 582 ended.
# 583 ended.
# 584 ended.
# 585 ended.
# 586 ended.
# 587 ended.
# 588 ended.
# 589 ended.
# 590 ended.
# 591 ended.
# 592 ended.
# 593 ended.
# 594 ended.
# 595 ended.
# 596 ended.
# 597 ended.
# 598 ended.
# 599 ended.
# 600 ended.

# %%
# train set
list_of_file_numbers = [i for i in range(1,2401)]   

# Problematic datafiles:
print("Removing material id",list_of_file_numbers[list_of_file_numbers.index(464)])
del list_of_file_numbers[list_of_file_numbers.index(464)] # 464. is problematic and will not be included in the dataset
print("Removing material id",list_of_file_numbers[list_of_file_numbers.index(2189)])
del list_of_file_numbers[list_of_file_numbers.index(2189)] # 2189. is problematic and will not be included in the dataset

# Removing duplicates from the train set:
print("Removing material id",list_of_file_numbers[list_of_file_numbers.index(126)])
del list_of_file_numbers[list_of_file_numbers.index(126)] # id 395/126 is duplicate. One removed.
print("Removing material id",list_of_file_numbers[list_of_file_numbers.index(1215)])
del list_of_file_numbers[list_of_file_numbers.index(1215)] # id 1215/1886 is duplicate. One removed.
print("Removing material id",list_of_file_numbers[list_of_file_numbers.index(353)])
del list_of_file_numbers[list_of_file_numbers.index(353)] # id 2075/353 is duplicate. One removed.
print("Removing material id",list_of_file_numbers[list_of_file_numbers.index(308)])
del list_of_file_numbers[list_of_file_numbers.index(308)] # id 308/2154 is duplicate. One removed.
print("Removing material id",list_of_file_numbers[list_of_file_numbers.index(531)])
del list_of_file_numbers[list_of_file_numbers.index(531)] # id 531/1379 is duplicate. One removed.
print("Removing material id",list_of_file_numbers[list_of_file_numbers.index(2319)])
del list_of_file_numbers[list_of_file_numbers.index(2319)] # id 2319/2337 is duplicate. One removed.
print("Removing material id",list_of_file_numbers[list_of_file_numbers.index(2370)])
del list_of_file_numbers[list_of_file_numbers.index(2370)] # id 2370/2333 is duplicate. One removed.

df_general = pd.read_csv("/home/jurka/research-project/train/relaxation/general.csv")
df_egy = pd.read_csv("/home/jurka/research-project/train/relaxation/energy_relaxation.csv")
df_latt = pd.read_csv("/home/jurka/research-project/train/relaxation/lattice_vector_relaxation.csv")
df_frac = pd.read_csv("/home/jurka/research-project/train/relaxation/atoms_frac_xyz_relaxation.csv")
df_xyz = pd.read_csv("/home/jurka/research-project/train/relaxation/atoms_xyz_relaxation.csv")

for i in list_of_file_numbers:
    path = "".join(["/home/jurka/Desktop/REE/nomad_kaggle_bandfiles/train_bandfiles/just_bandfiles/", str(i), "/band.out"])
    
    df_xyz_zeroth, df_latt_zeroth, df_egy_zeroth = zeroth(path, i, df_general)
    
    #df_xyz = pd.concat([df_xyz, df_xyz_zeroth]).reset_index(drop=True)
    #df_latt = pd.concat([df_latt, df_latt_zeroth]).reset_index(drop=True)
    
    A = np.linalg.inv(lattmat(df_latt_zeroth,i,0))
    
    material = df_xyz_zeroth.loc[df_xyz_zeroth["id"]==i][df_xyz_zeroth.columns[3:].to_list()].to_numpy(dtype=float)
    
    material_frac = np.round(np.dot(material,np.transpose(A)),decimals=6)
    
    df_frac_zeroth = pd.DataFrame(material_frac, columns=["L1", "L2", "L3"])
    df_frac_zeroth = df_xyz_zeroth[df_xyz_zeroth.columns.to_list()[:3]].join(df_frac_zeroth,how="left")
    
    if len(df_latt[(df_latt["id"]==i) & (df_latt["relaxation_step_number"]==0)])==0:
        pos = df_frac.loc[df_frac["id"]==i].iloc[0].name
        df_frac = pd.concat([df_frac.iloc[:pos], df_frac_zeroth, df_frac.iloc[pos:]]).reset_index(drop=True)

        pos = df_xyz.loc[df_xyz["id"]==i].iloc[0].name
        df_xyz = pd.concat([df_xyz.iloc[:pos], df_xyz_zeroth, df_xyz.iloc[pos:]]).reset_index(drop=True)

        pos = df_latt.loc[df_latt["id"]==i].iloc[0].name
        df_latt = pd.concat([df_latt.iloc[:pos], df_latt_zeroth, df_latt.iloc[pos:]]).reset_index(drop=True)
        
        pos = df_egy.loc[df_egy["id"]==i].iloc[0].name
        df_egy = pd.concat([df_egy.iloc[:pos], df_egy_zeroth, df_egy.iloc[pos:]]).reset_index(drop=True)

df_latt.to_csv("/home/jurka/research-project/train/relaxation/with_all_zeroes/lattice.csv", index = False)
df_egy.to_csv("/home/jurka/research-project/train/relaxation/with_all_zeroes/energy.csv", index = False)
df_xyz.to_csv("/home/jurka/research-project/train/relaxation/with_all_zeroes/xyz.csv", index = False)
df_frac.to_csv("/home/jurka/research-project/train/relaxation/with_all_zeroes/frac.csv", index = False)
# Out:
# Removing material id 464
# Removing material id 2189
# Removing material id 126
# Removing material id 1215
# Removing material id 353
# Removing material id 308
# Removing material id 531
# Removing material id 2319
# Removing material id 2370
# 1 ended.
# 2 ended.
# 3 ended.
# 4 ended.
# 5 ended.
# 6 ended.
# 7 ended.
# 8 ended.
# 9 ended.
# 10 ended.
# 11 ended.
# 12 ended.
# 13 ended.
# 14 ended.
# 15 ended.
# 16 ended.
# 17 ended.
# 18 ended.
# 19 ended.
# 20 ended.
# 21 ended.
# 22 ended.
# 23 ended.
# 24 ended.
# 25 ended.
# 26 ended.
# 27 ended.
# 28 ended.
# 29 ended.
# 30 ended.
# 31 ended.
# 32 ended.
# 33 ended.
# 34 ended.
# 35 ended.
# 36 ended.
# 37 ended.
# 38 ended.
# 39 ended.
# 40 ended.
# 41 ended.
# 42 ended.
# 43 ended.
# 44 ended.
# 45 ended.
# 46 ended.
# 47 ended.
# 48 ended.
# 49 ended.
# 50 ended.
# 51 ended.
# 52 ended.
# 53 ended.
# 54 ended.
# 55 ended.
# 56 ended.
# 57 ended.
# 58 ended.
# 59 ended.
# 60 ended.
# 61 ended.
# 62 ended.
# 63 ended.
# 64 ended.
# 65 ended.
# 66 ended.
# 67 ended.
# 68 ended.
# 69 ended.
# 70 ended.
# 71 ended.
# 72 ended.
# 73 ended.
# 74 ended.
# 75 ended.
# 76 ended.
# 77 ended.
# 78 ended.
# 79 ended.
# 80 ended.
# 81 ended.
# 82 ended.
# 83 ended.
# 84 ended.
# 85 ended.
# 86 ended.
# 87 ended.
# 88 ended.
# 89 ended.
# 90 ended.
# 91 ended.
# 92 ended.
# 93 ended.
# 94 ended.
# 95 ended.
# 96 ended.
# 97 ended.
# 98 ended.
# 99 ended.
# 100 ended.
# 101 ended.
# 102 ended.
# 103 ended.
# 104 ended.
# 105 ended.
# 106 ended.
# 107 ended.
# 108 ended.
# 109 ended.
# 110 ended.
# 111 ended.
# 112 ended.
# 113 ended.
# 114 ended.
# 115 ended.
# 116 ended.
# 117 ended.
# 118 ended.
# 119 ended.
# 120 ended.
# 121 ended.
# 122 ended.
# 123 ended.
# 124 ended.
# 125 ended.
# 127 ended.
# 128 ended.
# 129 ended.
# 130 ended.
# 131 ended.
# 132 ended.
# 133 ended.
# 134 ended.
# 135 ended.
# 136 ended.
# 137 ended.
# 138 ended.
# 139 ended.
# 140 ended.
# 141 ended.
# 142 ended.
# 143 ended.
# 144 ended.
# 145 ended.
# 146 ended.
# 147 ended.
# 148 ended.
# 149 ended.
# 150 ended.
# 151 ended.
# 152 ended.
# 153 ended.
# 154 ended.
# 155 ended.
# 156 ended.
# 157 ended.
# 158 ended.
# 159 ended.
# 160 ended.
# 161 ended.
# 162 ended.
# 163 ended.
# 164 ended.
# 165 ended.
# 166 ended.
# 167 ended.
# 168 ended.
# 169 ended.
# 170 ended.
# 171 ended.
# 172 ended.
# 173 ended.
# 174 ended.
# 175 ended.
# 176 ended.
# 177 ended.
# 178 ended.
# 179 ended.
# 180 ended.
# 181 ended.
# 182 ended.
# 183 ended.
# 184 ended.
# 185 ended.
# 186 ended.
# 187 ended.
# 188 ended.
# 189 ended.
# 190 ended.
# 191 ended.
# 192 ended.
# 193 ended.
# 194 ended.
# 195 ended.
# 196 ended.
# 197 ended.
# 198 ended.
# 199 ended.
# 200 ended.
# 201 ended.
# 202 ended.
# 203 ended.
# 204 ended.
# 205 ended.
# 206 ended.
# 207 ended.
# 208 ended.
# 209 ended.
# 210 ended.
# 211 ended.
# 212 ended.
# 213 ended.
# 214 ended.
# 215 ended.
# 216 ended.
# 217 ended.
# 218 ended.
# 219 ended.
# 220 ended.
# 221 ended.
# 222 ended.
# 223 ended.
# 224 ended.
# 225 ended.
# 226 ended.
# 227 ended.
# 228 ended.
# 229 ended.
# 230 ended.
# 231 ended.
# 232 ended.
# 233 ended.
# 234 ended.
# 235 ended.
# 236 ended.
# 237 ended.
# 238 ended.
# 239 ended.
# 240 ended.
# 241 ended.
# 242 ended.
# 243 ended.
# 244 ended.
# 245 ended.
# 246 ended.
# 247 ended.
# 248 ended.
# 249 ended.
# 250 ended.
# 251 ended.
# 252 ended.
# 253 ended.
# 254 ended.
# 255 ended.
# 256 ended.
# 257 ended.
# 258 ended.
# 259 ended.
# 260 ended.
# 261 ended.
# 262 ended.
# 263 ended.
# 264 ended.
# 265 ended.
# 266 ended.
# 267 ended.
# 268 ended.
# 269 ended.
# 270 ended.
# 271 ended.
# 272 ended.
# 273 ended.
# 274 ended.
# 275 ended.
# 276 ended.
# 277 ended.
# 278 ended.
# 279 ended.
# 280 ended.
# 281 ended.
# 282 ended.
# 283 ended.
# 284 ended.
# 285 ended.
# 286 ended.
# 287 ended.
# 288 ended.
# 289 ended.
# 290 ended.
# 291 ended.
# 292 ended.
# 293 ended.
# 294 ended.
# 295 ended.
# 296 ended.
# 297 ended.
# 298 ended.
# 299 ended.
# 300 ended.
# 301 ended.
# 302 ended.
# 303 ended.
# 304 ended.
# 305 ended.
# 306 ended.
# 307 ended.
# 309 ended.
# 310 ended.
# 311 ended.
# 312 ended.
# 313 ended.
# 314 ended.
# 315 ended.
# 316 ended.
# 317 ended.
# 318 ended.
# 319 ended.
# 320 ended.
# 321 ended.
# 322 ended.
# 323 ended.
# 324 ended.
# 325 ended.
# 326 ended.
# 327 ended.
# 328 ended.
# 329 ended.
# 330 ended.
# 331 ended.
# 332 ended.
# 333 ended.
# 334 ended.
# 335 ended.
# 336 ended.
# 337 ended.
# 338 ended.
# 339 ended.
# 340 ended.
# 341 ended.
# 342 ended.
# 343 ended.
# 344 ended.
# 345 ended.
# 346 ended.
# 347 ended.
# 348 ended.
# 349 ended.
# 350 ended.
# 351 ended.
# 352 ended.
# 354 ended.
# 355 ended.
# 356 ended.
# 357 ended.
# 358 ended.
# 359 ended.
# 360 ended.
# 361 ended.
# 362 ended.
# 363 ended.
# 364 ended.
# 365 ended.
# 366 ended.
# 367 ended.
# 368 ended.
# 369 ended.
# 370 ended.
# 371 ended.
# 372 ended.
# 373 ended.
# 374 ended.
# 375 ended.
# 376 ended.
# 377 ended.
# 378 ended.
# 379 ended.
# 380 ended.
# 381 ended.
# 382 ended.
# 383 ended.
# 384 ended.
# 385 ended.
# 386 ended.
# 387 ended.
# 388 ended.
# 389 ended.
# 390 ended.
# 391 ended.
# 392 ended.
# 393 ended.
# 394 ended.
# 395 ended.
# 396 ended.
# 397 ended.
# 398 ended.
# 399 ended.
# 400 ended.
# 401 ended.
# 402 ended.
# 403 ended.
# 404 ended.
# 405 ended.
# 406 ended.
# 407 ended.
# 408 ended.
# 409 ended.
# 410 ended.
# 411 ended.
# 412 ended.
# 413 ended.
# 414 ended.
# 415 ended.
# 416 ended.
# 417 ended.
# 418 ended.
# 419 ended.
# 420 ended.
# 421 ended.
# 422 ended.
# 423 ended.
# 424 ended.
# 425 ended.
# 426 ended.
# 427 ended.
# 428 ended.
# 429 ended.
# 430 ended.
# 431 ended.
# 432 ended.
# 433 ended.
# 434 ended.
# 435 ended.
# 436 ended.
# 437 ended.
# 438 ended.
# 439 ended.
# 440 ended.
# 441 ended.
# 442 ended.
# 443 ended.
# 444 ended.
# 445 ended.
# 446 ended.
# 447 ended.
# 448 ended.
# 449 ended.
# 450 ended.
# 451 ended.
# 452 ended.
# 453 ended.
# 454 ended.
# 455 ended.
# 456 ended.
# 457 ended.
# 458 ended.
# 459 ended.
# 460 ended.
# 461 ended.
# 462 ended.
# 463 ended.
# 465 ended.
# 466 ended.
# 467 ended.
# 468 ended.
# 469 ended.
# 470 ended.
# 471 ended.
# 472 ended.
# 473 ended.
# 474 ended.
# 475 ended.
# 476 ended.
# 477 ended.
# 478 ended.
# 479 ended.
# 480 ended.
# 481 ended.
# 482 ended.
# 483 ended.
# 484 ended.
# 485 ended.
# 486 ended.
# 487 ended.
# 488 ended.
# 489 ended.
# 490 ended.
# 491 ended.
# 492 ended.
# 493 ended.
# 494 ended.
# 495 ended.
# 496 ended.
# 497 ended.
# 498 ended.
# 499 ended.
# 500 ended.
# 501 ended.
# 502 ended.
# 503 ended.
# 504 ended.
# 505 ended.
# 506 ended.
# 507 ended.
# 508 ended.
# 509 ended.
# 510 ended.
# 511 ended.
# 512 ended.
# 513 ended.
# 514 ended.
# 515 ended.
# 516 ended.
# 517 ended.
# 518 ended.
# 519 ended.
# 520 ended.
# 521 ended.
# 522 ended.
# 523 ended.
# 524 ended.
# 525 ended.
# 526 ended.
# 527 ended.
# 528 ended.
# 529 ended.
# 530 ended.
# 532 ended.
# 533 ended.
# 534 ended.
# 535 ended.
# 536 ended.
# 537 ended.
# 538 ended.
# 539 ended.
# 540 ended.
# 541 ended.
# 542 ended.
# 543 ended.
# 544 ended.
# 545 ended.
# 546 ended.
# 547 ended.
# 548 ended.
# 549 ended.
# 550 ended.
# 551 ended.
# 552 ended.
# 553 ended.
# 554 ended.
# 555 ended.
# 556 ended.
# 557 ended.
# 558 ended.
# 559 ended.
# 560 ended.
# 561 ended.
# 562 ended.
# 563 ended.
# 564 ended.
# 565 ended.
# 566 ended.
# 567 ended.
# 568 ended.
# 569 ended.
# 570 ended.
# 571 ended.
# 572 ended.
# 573 ended.
# 574 ended.
# 575 ended.
# 576 ended.
# 577 ended.
# 578 ended.
# 579 ended.
# 580 ended.
# 581 ended.
# 582 ended.
# 583 ended.
# 584 ended.
# 585 ended.
# 586 ended.
# 587 ended.
# 588 ended.
# 589 ended.
# 590 ended.
# 591 ended.
# 592 ended.
# 593 ended.
# 594 ended.
# 595 ended.
# 596 ended.
# 597 ended.
# 598 ended.
# 599 ended.
# 600 ended.
# 601 ended.
# 602 ended.
# 603 ended.
# 604 ended.
# 605 ended.
# 606 ended.
# 607 ended.
# 608 ended.
# 609 ended.
# 610 ended.
# 611 ended.
# 612 ended.
# 613 ended.
# 614 ended.
# 615 ended.
# 616 ended.
# 617 ended.
# 618 ended.
# 619 ended.
# 620 ended.
# 621 ended.
# 622 ended.
# 623 ended.
# 624 ended.
# 625 ended.
# 626 ended.
# 627 ended.
# 628 ended.
# 629 ended.
# 630 ended.
# 631 ended.
# 632 ended.
# 633 ended.
# 634 ended.
# 635 ended.
# 636 ended.
# 637 ended.
# 638 ended.
# 639 ended.
# 640 ended.
# 641 ended.
# 642 ended.
# 643 ended.
# 644 ended.
# 645 ended.
# 646 ended.
# 647 ended.
# 648 ended.
# 649 ended.
# 650 ended.
# 651 ended.
# 652 ended.
# 653 ended.
# 654 ended.
# 655 ended.
# 656 ended.
# 657 ended.
# 658 ended.
# 659 ended.
# 660 ended.
# 661 ended.
# 662 ended.
# 663 ended.
# 664 ended.
# 665 ended.
# 666 ended.
# 667 ended.
# 668 ended.
# 669 ended.
# 670 ended.
# 671 ended.
# 672 ended.
# 673 ended.
# 674 ended.
# 675 ended.
# 676 ended.
# 677 ended.
# 678 ended.
# 679 ended.
# 680 ended.
# 681 ended.
# 682 ended.
# 683 ended.
# 684 ended.
# 685 ended.
# 686 ended.
# 687 ended.
# 688 ended.
# 689 ended.
# 690 ended.
# 691 ended.
# 692 ended.
# 693 ended.
# 694 ended.
# 695 ended.
# 696 ended.
# 697 ended.
# 698 ended.
# 699 ended.
# 700 ended.
# 701 ended.
# 702 ended.
# 703 ended.
# 704 ended.
# 705 ended.
# 706 ended.
# 707 ended.
# 708 ended.
# 709 ended.
# 710 ended.
# 711 ended.
# 712 ended.
# 713 ended.
# 714 ended.
# 715 ended.
# 716 ended.
# 717 ended.
# 718 ended.
# 719 ended.
# 720 ended.
# 721 ended.
# 722 ended.
# 723 ended.
# 724 ended.
# 725 ended.
# 726 ended.
# 727 ended.
# 728 ended.
# 729 ended.
# 730 ended.
# 731 ended.
# 732 ended.
# 733 ended.
# 734 ended.
# 735 ended.
# 736 ended.
# 737 ended.
# 738 ended.
# 739 ended.
# 740 ended.
# 741 ended.
# 742 ended.
# 743 ended.
# 744 ended.
# 745 ended.
# 746 ended.
# 747 ended.
# 748 ended.
# 749 ended.
# 750 ended.
# 751 ended.
# 752 ended.
# 753 ended.
# 754 ended.
# 755 ended.
# 756 ended.
# 757 ended.
# 758 ended.
# 759 ended.
# 760 ended.
# 761 ended.
# 762 ended.
# 763 ended.
# 764 ended.
# 765 ended.
# 766 ended.
# 767 ended.
# 768 ended.
# 769 ended.
# 770 ended.
# 771 ended.
# 772 ended.
# 773 ended.
# 774 ended.
# 775 ended.
# 776 ended.
# 777 ended.
# 778 ended.
# 779 ended.
# 780 ended.
# 781 ended.
# 782 ended.
# 783 ended.
# 784 ended.
# 785 ended.
# 786 ended.
# 787 ended.
# 788 ended.
# 789 ended.
# 790 ended.
# 791 ended.
# 792 ended.
# 793 ended.
# 794 ended.
# 795 ended.
# 796 ended.
# 797 ended.
# 798 ended.
# 799 ended.
# 800 ended.
# 801 ended.
# 802 ended.
# 803 ended.
# 804 ended.
# 805 ended.
# 806 ended.
# 807 ended.
# 808 ended.
# 809 ended.
# 810 ended.
# 811 ended.
# 812 ended.
# 813 ended.
# 814 ended.
# 815 ended.
# 816 ended.
# 817 ended.
# 818 ended.
# 819 ended.
# 820 ended.
# 821 ended.
# 822 ended.
# 823 ended.
# 824 ended.
# 825 ended.
# 826 ended.
# 827 ended.
# 828 ended.
# 829 ended.
# 830 ended.
# 831 ended.
# 832 ended.
# 833 ended.
# 834 ended.
# 835 ended.
# 836 ended.
# 837 ended.
# 838 ended.
# 839 ended.
# 840 ended.
# 841 ended.
# 842 ended.
# 843 ended.
# 844 ended.
# 845 ended.
# 846 ended.
# 847 ended.
# 848 ended.
# 849 ended.
# 850 ended.
# 851 ended.
# 852 ended.
# 853 ended.
# 854 ended.
# 855 ended.
# 856 ended.
# 857 ended.
# 858 ended.
# 859 ended.
# 860 ended.
# 861 ended.
# 862 ended.
# 863 ended.
# 864 ended.
# 865 ended.
# 866 ended.
# 867 ended.
# 868 ended.
# 869 ended.
# 870 ended.
# 871 ended.
# 872 ended.
# 873 ended.
# 874 ended.
# 875 ended.
# 876 ended.
# 877 ended.
# 878 ended.
# 879 ended.
# 880 ended.
# 881 ended.
# 882 ended.
# 883 ended.
# 884 ended.
# 885 ended.
# 886 ended.
# 887 ended.
# 888 ended.
# 889 ended.
# 890 ended.
# 891 ended.
# 892 ended.
# 893 ended.
# 894 ended.
# 895 ended.
# 896 ended.
# 897 ended.
# 898 ended.
# 899 ended.
# 900 ended.
# 901 ended.
# 902 ended.
# 903 ended.
# 904 ended.
# 905 ended.
# 906 ended.
# 907 ended.
# 908 ended.
# 909 ended.
# 910 ended.
# 911 ended.
# 912 ended.
# 913 ended.
# 914 ended.
# 915 ended.
# 916 ended.
# 917 ended.
# 918 ended.
# 919 ended.
# 920 ended.
# 921 ended.
# 922 ended.
# 923 ended.
# 924 ended.
# 925 ended.
# 926 ended.
# 927 ended.
# 928 ended.
# 929 ended.
# 930 ended.
# 931 ended.
# 932 ended.
# 933 ended.
# 934 ended.
# 935 ended.
# 936 ended.
# 937 ended.
# 938 ended.
# 939 ended.
# 940 ended.
# 941 ended.
# 942 ended.
# 943 ended.
# 944 ended.
# 945 ended.
# 946 ended.
# 947 ended.
# 948 ended.
# 949 ended.
# 950 ended.
# 951 ended.
# 952 ended.
# 953 ended.
# 954 ended.
# 955 ended.
# 956 ended.
# 957 ended.
# 958 ended.
# 959 ended.
# 960 ended.
# 961 ended.
# 962 ended.
# 963 ended.
# 964 ended.
# 965 ended.
# 966 ended.
# 967 ended.
# 968 ended.
# 969 ended.
# 970 ended.
# 971 ended.
# 972 ended.
# 973 ended.
# 974 ended.
# 975 ended.
# 976 ended.
# 977 ended.
# 978 ended.
# 979 ended.
# 980 ended.
# 981 ended.
# 982 ended.
# 983 ended.
# 984 ended.
# 985 ended.
# 986 ended.
# 987 ended.
# 988 ended.
# 989 ended.
# 990 ended.
# 991 ended.
# 992 ended.
# 993 ended.
# 994 ended.
# 995 ended.
# 996 ended.
# 997 ended.
# 998 ended.
# 999 ended.
# 1000 ended.
# 1001 ended.
# 1002 ended.
# 1003 ended.
# 1004 ended.
# 1005 ended.
# 1006 ended.
# 1007 ended.
# 1008 ended.
# 1009 ended.
# 1010 ended.
# 1011 ended.
# 1012 ended.
# 1013 ended.
# 1014 ended.
# 1015 ended.
# 1016 ended.
# 1017 ended.
# 1018 ended.
# 1019 ended.
# 1020 ended.
# 1021 ended.
# 1022 ended.
# 1023 ended.
# 1024 ended.
# 1025 ended.
# 1026 ended.
# 1027 ended.
# 1028 ended.
# 1029 ended.
# 1030 ended.
# 1031 ended.
# 1032 ended.
# 1033 ended.
# 1034 ended.
# 1035 ended.
# 1036 ended.
# 1037 ended.
# 1038 ended.
# 1039 ended.
# 1040 ended.
# 1041 ended.
# 1042 ended.
# 1043 ended.
# 1044 ended.
# 1045 ended.
# 1046 ended.
# 1047 ended.
# 1048 ended.
# 1049 ended.
# 1050 ended.
# 1051 ended.
# 1052 ended.
# 1053 ended.
# 1054 ended.
# 1055 ended.
# 1056 ended.
# 1057 ended.
# 1058 ended.
# 1059 ended.
# 1060 ended.
# 1061 ended.
# 1062 ended.
# 1063 ended.
# 1064 ended.
# 1065 ended.
# 1066 ended.
# 1067 ended.
# 1068 ended.
# 1069 ended.
# 1070 ended.
# 1071 ended.
# 1072 ended.
# 1073 ended.
# 1074 ended.
# 1075 ended.
# 1076 ended.
# 1077 ended.
# 1078 ended.
# 1079 ended.
# 1080 ended.
# 1081 ended.
# 1082 ended.
# 1083 ended.
# 1084 ended.
# 1085 ended.
# 1086 ended.
# 1087 ended.
# 1088 ended.
# 1089 ended.
# 1090 ended.
# 1091 ended.
# 1092 ended.
# 1093 ended.
# 1094 ended.
# 1095 ended.
# 1096 ended.
# 1097 ended.
# 1098 ended.
# 1099 ended.
# 1100 ended.
# 1101 ended.
# 1102 ended.
# 1103 ended.
# 1104 ended.
# 1105 ended.
# 1106 ended.
# 1107 ended.
# 1108 ended.
# 1109 ended.
# 1110 ended.
# 1111 ended.
# 1112 ended.
# 1113 ended.
# 1114 ended.
# 1115 ended.
# 1116 ended.
# 1117 ended.
# 1118 ended.
# 1119 ended.
# 1120 ended.
# 1121 ended.
# 1122 ended.
# 1123 ended.
# 1124 ended.
# 1125 ended.
# 1126 ended.
# 1127 ended.
# 1128 ended.
# 1129 ended.
# 1130 ended.
# 1131 ended.
# 1132 ended.
# 1133 ended.
# 1134 ended.
# 1135 ended.
# 1136 ended.
# 1137 ended.
# 1138 ended.
# 1139 ended.
# 1140 ended.
# 1141 ended.
# 1142 ended.
# 1143 ended.
# 1144 ended.
# 1145 ended.
# 1146 ended.
# 1147 ended.
# 1148 ended.
# 1149 ended.
# 1150 ended.
# 1151 ended.
# 1152 ended.
# 1153 ended.
# 1154 ended.
# 1155 ended.
# 1156 ended.
# 1157 ended.
# 1158 ended.
# 1159 ended.
# 1160 ended.
# 1161 ended.
# 1162 ended.
# 1163 ended.
# 1164 ended.
# 1165 ended.
# 1166 ended.
# 1167 ended.
# 1168 ended.
# 1169 ended.
# 1170 ended.
# 1171 ended.
# 1172 ended.
# 1173 ended.
# 1174 ended.
# 1175 ended.
# 1176 ended.
# 1177 ended.
# 1178 ended.
# 1179 ended.
# 1180 ended.
# 1181 ended.
# 1182 ended.
# 1183 ended.
# 1184 ended.
# 1185 ended.
# 1186 ended.
# 1187 ended.
# 1188 ended.
# 1189 ended.
# 1190 ended.
# 1191 ended.
# 1192 ended.
# 1193 ended.
# 1194 ended.
# 1195 ended.
# 1196 ended.
# 1197 ended.
# 1198 ended.
# 1199 ended.
# 1200 ended.
# 1201 ended.
# 1202 ended.
# 1203 ended.
# 1204 ended.
# 1205 ended.
# 1206 ended.
# 1207 ended.
# 1208 ended.
# 1209 ended.
# 1210 ended.
# 1211 ended.
# 1212 ended.
# 1213 ended.
# 1214 ended.
# 1216 ended.
# 1217 ended.
# 1218 ended.
# 1219 ended.
# 1220 ended.
# 1221 ended.
# 1222 ended.
# 1223 ended.
# 1224 ended.
# 1225 ended.
# 1226 ended.
# 1227 ended.
# 1228 ended.
# 1229 ended.
# 1230 ended.
# 1231 ended.
# 1232 ended.
# 1233 ended.
# 1234 ended.
# 1235 ended.
# 1236 ended.
# 1237 ended.
# 1238 ended.
# 1239 ended.
# 1240 ended.
# 1241 ended.
# 1242 ended.
# 1243 ended.
# 1244 ended.
# 1245 ended.
# 1246 ended.
# 1247 ended.
# 1248 ended.
# 1249 ended.
# 1250 ended.
# 1251 ended.
# 1252 ended.
# 1253 ended.
# 1254 ended.
# 1255 ended.
# 1256 ended.
# 1257 ended.
# 1258 ended.
# 1259 ended.
# 1260 ended.
# 1261 ended.
# 1262 ended.
# 1263 ended.
# 1264 ended.
# 1265 ended.
# 1266 ended.
# 1267 ended.
# 1268 ended.
# 1269 ended.
# 1270 ended.
# 1271 ended.
# 1272 ended.
# 1273 ended.
# 1274 ended.
# 1275 ended.
# 1276 ended.
# 1277 ended.
# 1278 ended.
# 1279 ended.
# 1280 ended.
# 1281 ended.
# 1282 ended.
# 1283 ended.
# 1284 ended.
# 1285 ended.
# 1286 ended.
# 1287 ended.
# 1288 ended.
# 1289 ended.
# 1290 ended.
# 1291 ended.
# 1292 ended.
# 1293 ended.
# 1294 ended.
# 1295 ended.
# 1296 ended.
# 1297 ended.
# 1298 ended.
# 1299 ended.
# 1300 ended.
# 1301 ended.
# 1302 ended.
# 1303 ended.
# 1304 ended.
# 1305 ended.
# 1306 ended.
# 1307 ended.
# 1308 ended.
# 1309 ended.
# 1310 ended.
# 1311 ended.
# 1312 ended.
# 1313 ended.
# 1314 ended.
# 1315 ended.
# 1316 ended.
# 1317 ended.
# 1318 ended.
# 1319 ended.
# 1320 ended.
# 1321 ended.
# 1322 ended.
# 1323 ended.
# 1324 ended.
# 1325 ended.
# 1326 ended.
# 1327 ended.
# 1328 ended.
# 1329 ended.
# 1330 ended.
# 1331 ended.
# 1332 ended.
# 1333 ended.
# 1334 ended.
# 1335 ended.
# 1336 ended.
# 1337 ended.
# 1338 ended.
# 1339 ended.
# 1340 ended.
# 1341 ended.
# 1342 ended.
# 1343 ended.
# 1344 ended.
# 1345 ended.
# 1346 ended.
# 1347 ended.
# 1348 ended.
# 1349 ended.
# 1350 ended.
# 1351 ended.
# 1352 ended.
# 1353 ended.
# 1354 ended.
# 1355 ended.
# 1356 ended.
# 1357 ended.
# 1358 ended.
# 1359 ended.
# 1360 ended.
# 1361 ended.
# 1362 ended.
# 1363 ended.
# 1364 ended.
# 1365 ended.
# 1366 ended.
# 1367 ended.
# 1368 ended.
# 1369 ended.
# 1370 ended.
# 1371 ended.
# 1372 ended.
# 1373 ended.
# 1374 ended.
# 1375 ended.
# 1376 ended.
# 1377 ended.
# 1378 ended.
# 1379 ended.
# 1380 ended.
# 1381 ended.
# 1382 ended.
# 1383 ended.
# 1384 ended.
# 1385 ended.
# 1386 ended.
# 1387 ended.
# 1388 ended.
# 1389 ended.
# 1390 ended.
# 1391 ended.
# 1392 ended.
# 1393 ended.
# 1394 ended.
# 1395 ended.
# 1396 ended.
# 1397 ended.
# 1398 ended.
# 1399 ended.
# 1400 ended.
# 1401 ended.
# 1402 ended.
# 1403 ended.
# 1404 ended.
# 1405 ended.
# 1406 ended.
# 1407 ended.
# 1408 ended.
# 1409 ended.
# 1410 ended.
# 1411 ended.
# 1412 ended.
# 1413 ended.
# 1414 ended.
# 1415 ended.
# 1416 ended.
# 1417 ended.
# 1418 ended.
# 1419 ended.
# 1420 ended.
# 1421 ended.
# 1422 ended.
# 1423 ended.
# 1424 ended.
# 1425 ended.
# 1426 ended.
# 1427 ended.
# 1428 ended.
# 1429 ended.
# 1430 ended.
# 1431 ended.
# 1432 ended.
# 1433 ended.
# 1434 ended.
# 1435 ended.
# 1436 ended.
# 1437 ended.
# 1438 ended.
# 1439 ended.
# 1440 ended.
# 1441 ended.
# 1442 ended.
# 1443 ended.
# 1444 ended.
# 1445 ended.
# 1446 ended.
# 1447 ended.
# 1448 ended.
# 1449 ended.
# 1450 ended.
# 1451 ended.
# 1452 ended.
# 1453 ended.
# 1454 ended.
# 1455 ended.
# 1456 ended.
# 1457 ended.
# 1458 ended.
# 1459 ended.
# 1460 ended.
# 1461 ended.
# 1462 ended.
# 1463 ended.
# 1464 ended.
# 1465 ended.
# 1466 ended.
# 1467 ended.
# 1468 ended.
# 1469 ended.
# 1470 ended.
# 1471 ended.
# 1472 ended.
# 1473 ended.
# 1474 ended.
# 1475 ended.
# 1476 ended.
# 1477 ended.
# 1478 ended.
# 1479 ended.
# 1480 ended.
# 1481 ended.
# 1482 ended.
# 1483 ended.
# 1484 ended.
# 1485 ended.
# 1486 ended.
# 1487 ended.
# 1488 ended.
# 1489 ended.
# 1490 ended.
# 1491 ended.
# 1492 ended.
# 1493 ended.
# 1494 ended.
# 1495 ended.
# 1496 ended.
# 1497 ended.
# 1498 ended.
# 1499 ended.
# 1500 ended.
# 1501 ended.
# 1502 ended.
# 1503 ended.
# 1504 ended.
# 1505 ended.
# 1506 ended.
# 1507 ended.
# 1508 ended.
# 1509 ended.
# 1510 ended.
# 1511 ended.
# 1512 ended.
# 1513 ended.
# 1514 ended.
# 1515 ended.
# 1516 ended.
# 1517 ended.
# 1518 ended.
# 1519 ended.
# 1520 ended.
# 1521 ended.
# 1522 ended.
# 1523 ended.
# 1524 ended.
# 1525 ended.
# 1526 ended.
# 1527 ended.
# 1528 ended.
# 1529 ended.
# 1530 ended.
# 1531 ended.
# 1532 ended.
# 1533 ended.
# 1534 ended.
# 1535 ended.
# 1536 ended.
# 1537 ended.
# 1538 ended.
# 1539 ended.
# 1540 ended.
# 1541 ended.
# 1542 ended.
# 1543 ended.
# 1544 ended.
# 1545 ended.
# 1546 ended.
# 1547 ended.
# 1548 ended.
# 1549 ended.
# 1550 ended.
# 1551 ended.
# 1552 ended.
# 1553 ended.
# 1554 ended.
# 1555 ended.
# 1556 ended.
# 1557 ended.
# 1558 ended.
# 1559 ended.
# 1560 ended.
# 1561 ended.
# 1562 ended.
# 1563 ended.
# 1564 ended.
# 1565 ended.
# 1566 ended.
# 1567 ended.
# 1568 ended.
# 1569 ended.
# 1570 ended.
# 1571 ended.
# 1572 ended.
# 1573 ended.
# 1574 ended.
# 1575 ended.
# 1576 ended.
# 1577 ended.
# 1578 ended.
# 1579 ended.
# 1580 ended.
# 1581 ended.
# 1582 ended.
# 1583 ended.
# 1584 ended.
# 1585 ended.
# 1586 ended.
# 1587 ended.
# 1588 ended.
# 1589 ended.
# 1590 ended.
# 1591 ended.
# 1592 ended.
# 1593 ended.
# 1594 ended.
# 1595 ended.
# 1596 ended.
# 1597 ended.
# 1598 ended.
# 1599 ended.
# 1600 ended.
# 1601 ended.
# 1602 ended.
# 1603 ended.
# 1604 ended.
# 1605 ended.
# 1606 ended.
# 1607 ended.
# 1608 ended.
# 1609 ended.
# 1610 ended.
# 1611 ended.
# 1612 ended.
# 1613 ended.
# 1614 ended.
# 1615 ended.
# 1616 ended.
# 1617 ended.
# 1618 ended.
# 1619 ended.
# 1620 ended.
# 1621 ended.
# 1622 ended.
# 1623 ended.
# 1624 ended.
# 1625 ended.
# 1626 ended.
# 1627 ended.
# 1628 ended.
# 1629 ended.
# 1630 ended.
# 1631 ended.
# 1632 ended.
# 1633 ended.
# 1634 ended.
# 1635 ended.
# 1636 ended.
# 1637 ended.
# 1638 ended.
# 1639 ended.
# 1640 ended.
# 1641 ended.
# 1642 ended.
# 1643 ended.
# 1644 ended.
# 1645 ended.
# 1646 ended.
# 1647 ended.
# 1648 ended.
# 1649 ended.
# 1650 ended.
# 1651 ended.
# 1652 ended.
# 1653 ended.
# 1654 ended.
# 1655 ended.
# 1656 ended.
# 1657 ended.
# 1658 ended.
# 1659 ended.
# 1660 ended.
# 1661 ended.
# 1662 ended.
# 1663 ended.
# 1664 ended.
# 1665 ended.
# 1666 ended.
# 1667 ended.
# 1668 ended.
# 1669 ended.
# 1670 ended.
# 1671 ended.
# 1672 ended.
# 1673 ended.
# 1674 ended.
# 1675 ended.
# 1676 ended.
# 1677 ended.
# 1678 ended.
# 1679 ended.
# 1680 ended.
# 1681 ended.
# 1682 ended.
# 1683 ended.
# 1684 ended.
# 1685 ended.
# 1686 ended.
# 1687 ended.
# 1688 ended.
# 1689 ended.
# 1690 ended.
# 1691 ended.
# 1692 ended.
# 1693 ended.
# 1694 ended.
# 1695 ended.
# 1696 ended.
# 1697 ended.
# 1698 ended.
# 1699 ended.
# 1700 ended.
# 1701 ended.
# 1702 ended.
# 1703 ended.
# 1704 ended.
# 1705 ended.
# 1706 ended.
# 1707 ended.
# 1708 ended.
# 1709 ended.
# 1710 ended.
# 1711 ended.
# 1712 ended.
# 1713 ended.
# 1714 ended.
# 1715 ended.
# 1716 ended.
# 1717 ended.
# 1718 ended.
# 1719 ended.
# 1720 ended.
# 1721 ended.
# 1722 ended.
# 1723 ended.
# 1724 ended.
# 1725 ended.
# 1726 ended.
# 1727 ended.
# 1728 ended.
# 1729 ended.
# 1730 ended.
# 1731 ended.
# 1732 ended.
# 1733 ended.
# 1734 ended.
# 1735 ended.
# 1736 ended.
# 1737 ended.
# 1738 ended.
# 1739 ended.
# 1740 ended.
# 1741 ended.
# 1742 ended.
# 1743 ended.
# 1744 ended.
# 1745 ended.
# 1746 ended.
# 1747 ended.
# 1748 ended.
# 1749 ended.
# 1750 ended.
# 1751 ended.
# 1752 ended.
# 1753 ended.
# 1754 ended.
# 1755 ended.
# 1756 ended.
# 1757 ended.
# 1758 ended.
# 1759 ended.
# 1760 ended.
# 1761 ended.
# 1762 ended.
# 1763 ended.
# 1764 ended.
# 1765 ended.
# 1766 ended.
# 1767 ended.
# 1768 ended.
# 1769 ended.
# 1770 ended.
# 1771 ended.
# 1772 ended.
# 1773 ended.
# 1774 ended.
# 1775 ended.
# 1776 ended.
# 1777 ended.
# 1778 ended.
# 1779 ended.
# 1780 ended.
# 1781 ended.
# 1782 ended.
# 1783 ended.
# 1784 ended.
# 1785 ended.
# 1786 ended.
# 1787 ended.
# 1788 ended.
# 1789 ended.
# 1790 ended.
# 1791 ended.
# 1792 ended.
# 1793 ended.
# 1794 ended.
# 1795 ended.
# 1796 ended.
# 1797 ended.
# 1798 ended.
# 1799 ended.
# 1800 ended.
# 1801 ended.
# 1802 ended.
# 1803 ended.
# 1804 ended.
# 1805 ended.
# 1806 ended.
# 1807 ended.
# 1808 ended.
# 1809 ended.
# 1810 ended.
# 1811 ended.
# 1812 ended.
# 1813 ended.
# 1814 ended.
# 1815 ended.
# 1816 ended.
# 1817 ended.
# 1818 ended.
# 1819 ended.
# 1820 ended.
# 1821 ended.
# 1822 ended.
# 1823 ended.
# 1824 ended.
# 1825 ended.
# 1826 ended.
# 1827 ended.
# 1828 ended.
# 1829 ended.
# 1830 ended.
# 1831 ended.
# 1832 ended.
# 1833 ended.
# 1834 ended.
# 1835 ended.
# 1836 ended.
# 1837 ended.
# 1838 ended.
# 1839 ended.
# 1840 ended.
# 1841 ended.
# 1842 ended.
# 1843 ended.
# 1844 ended.
# 1845 ended.
# 1846 ended.
# 1847 ended.
# 1848 ended.
# 1849 ended.
# 1850 ended.
# 1851 ended.
# 1852 ended.
# 1853 ended.
# 1854 ended.
# 1855 ended.
# 1856 ended.
# 1857 ended.
# 1858 ended.
# 1859 ended.
# 1860 ended.
# 1861 ended.
# 1862 ended.
# 1863 ended.
# 1864 ended.
# 1865 ended.
# 1866 ended.
# 1867 ended.
# 1868 ended.
# 1869 ended.
# 1870 ended.
# 1871 ended.
# 1872 ended.
# 1873 ended.
# 1874 ended.
# 1875 ended.
# 1876 ended.
# 1877 ended.
# 1878 ended.
# 1879 ended.
# 1880 ended.
# 1881 ended.
# 1882 ended.
# 1883 ended.
# 1884 ended.
# 1885 ended.
# 1886 ended.
# 1887 ended.
# 1888 ended.
# 1889 ended.
# 1890 ended.
# 1891 ended.
# 1892 ended.
# 1893 ended.
# 1894 ended.
# 1895 ended.
# 1896 ended.
# 1897 ended.
# 1898 ended.
# 1899 ended.
# 1900 ended.
# 1901 ended.
# 1902 ended.
# 1903 ended.
# 1904 ended.
# 1905 ended.
# 1906 ended.
# 1907 ended.
# 1908 ended.
# 1909 ended.
# 1910 ended.
# 1911 ended.
# 1912 ended.
# 1913 ended.
# 1914 ended.
# 1915 ended.
# 1916 ended.
# 1917 ended.
# 1918 ended.
# 1919 ended.
# 1920 ended.
# 1921 ended.
# 1922 ended.
# 1923 ended.
# 1924 ended.
# 1925 ended.
# 1926 ended.
# 1927 ended.
# 1928 ended.
# 1929 ended.
# 1930 ended.
# 1931 ended.
# 1932 ended.
# 1933 ended.
# 1934 ended.
# 1935 ended.
# 1936 ended.
# 1937 ended.
# 1938 ended.
# 1939 ended.
# 1940 ended.
# 1941 ended.
# 1942 ended.
# 1943 ended.
# 1944 ended.
# 1945 ended.
# 1946 ended.
# 1947 ended.
# 1948 ended.
# 1949 ended.
# 1950 ended.
# 1951 ended.
# 1952 ended.
# 1953 ended.
# 1954 ended.
# 1955 ended.
# 1956 ended.
# 1957 ended.
# 1958 ended.
# 1959 ended.
# 1960 ended.
# 1961 ended.
# 1962 ended.
# 1963 ended.
# 1964 ended.
# 1965 ended.
# 1966 ended.
# 1967 ended.
# 1968 ended.
# 1969 ended.
# 1970 ended.
# 1971 ended.
# 1972 ended.
# 1973 ended.
# 1974 ended.
# 1975 ended.
# 1976 ended.
# 1977 ended.
# 1978 ended.
# 1979 ended.
# 1980 ended.
# 1981 ended.
# 1982 ended.
# 1983 ended.
# 1984 ended.
# 1985 ended.
# 1986 ended.
# 1987 ended.
# 1988 ended.
# 1989 ended.
# 1990 ended.
# 1991 ended.
# 1992 ended.
# 1993 ended.
# 1994 ended.
# 1995 ended.
# 1996 ended.
# 1997 ended.
# 1998 ended.
# 1999 ended.
# 2000 ended.
# 2001 ended.
# 2002 ended.
# 2003 ended.
# 2004 ended.
# 2005 ended.
# 2006 ended.
# 2007 ended.
# 2008 ended.
# 2009 ended.
# 2010 ended.
# 2011 ended.
# 2012 ended.
# 2013 ended.
# 2014 ended.
# 2015 ended.
# 2016 ended.
# 2017 ended.
# 2018 ended.
# 2019 ended.
# 2020 ended.
# 2021 ended.
# 2022 ended.
# 2023 ended.
# 2024 ended.
# 2025 ended.
# 2026 ended.
# 2027 ended.
# 2028 ended.
# 2029 ended.
# 2030 ended.
# 2031 ended.
# 2032 ended.
# 2033 ended.
# 2034 ended.
# 2035 ended.
# 2036 ended.
# 2037 ended.
# 2038 ended.
# 2039 ended.
# 2040 ended.
# 2041 ended.
# 2042 ended.
# 2043 ended.
# 2044 ended.
# 2045 ended.
# 2046 ended.
# 2047 ended.
# 2048 ended.
# 2049 ended.
# 2050 ended.
# 2051 ended.
# 2052 ended.
# 2053 ended.
# 2054 ended.
# 2055 ended.
# 2056 ended.
# 2057 ended.
# 2058 ended.
# 2059 ended.
# 2060 ended.
# 2061 ended.
# 2062 ended.
# 2063 ended.
# 2064 ended.
# 2065 ended.
# 2066 ended.
# 2067 ended.
# 2068 ended.
# 2069 ended.
# 2070 ended.
# 2071 ended.
# 2072 ended.
# 2073 ended.
# 2074 ended.
# 2075 ended.
# 2076 ended.
# 2077 ended.
# 2078 ended.
# 2079 ended.
# 2080 ended.
# 2081 ended.
# 2082 ended.
# 2083 ended.
# 2084 ended.
# 2085 ended.
# 2086 ended.
# 2087 ended.
# 2088 ended.
# 2089 ended.
# 2090 ended.
# 2091 ended.
# 2092 ended.
# 2093 ended.
# 2094 ended.
# 2095 ended.
# 2096 ended.
# 2097 ended.
# 2098 ended.
# 2099 ended.
# 2100 ended.
# 2101 ended.
# 2102 ended.
# 2103 ended.
# 2104 ended.
# 2105 ended.
# 2106 ended.
# 2107 ended.
# 2108 ended.
# 2109 ended.
# 2110 ended.
# 2111 ended.
# 2112 ended.
# 2113 ended.
# 2114 ended.
# 2115 ended.
# 2116 ended.
# 2117 ended.
# 2118 ended.
# 2119 ended.
# 2120 ended.
# 2121 ended.
# 2122 ended.
# 2123 ended.
# 2124 ended.
# 2125 ended.
# 2126 ended.
# 2127 ended.
# 2128 ended.
# 2129 ended.
# 2130 ended.
# 2131 ended.
# 2132 ended.
# 2133 ended.
# 2134 ended.
# 2135 ended.
# 2136 ended.
# 2137 ended.
# 2138 ended.
# 2139 ended.
# 2140 ended.
# 2141 ended.
# 2142 ended.
# 2143 ended.
# 2144 ended.
# 2145 ended.
# 2146 ended.
# 2147 ended.
# 2148 ended.
# 2149 ended.
# 2150 ended.
# 2151 ended.
# 2152 ended.
# 2153 ended.
# 2154 ended.
# 2155 ended.
# 2156 ended.
# 2157 ended.
# 2158 ended.
# 2159 ended.
# 2160 ended.
# 2161 ended.
# 2162 ended.
# 2163 ended.
# 2164 ended.
# 2165 ended.
# 2166 ended.
# 2167 ended.
# 2168 ended.
# 2169 ended.
# 2170 ended.
# 2171 ended.
# 2172 ended.
# 2173 ended.
# 2174 ended.
# 2175 ended.
# 2176 ended.
# 2177 ended.
# 2178 ended.
# 2179 ended.
# 2180 ended.
# 2181 ended.
# 2182 ended.
# 2183 ended.
# 2184 ended.
# 2185 ended.
# 2186 ended.
# 2187 ended.
# 2188 ended.
# 2190 ended.
# 2191 ended.
# 2192 ended.
# 2193 ended.
# 2194 ended.
# 2195 ended.
# 2196 ended.
# 2197 ended.
# 2198 ended.
# 2199 ended.
# 2200 ended.
# 2201 ended.
# 2202 ended.
# 2203 ended.
# 2204 ended.
# 2205 ended.
# 2206 ended.
# 2207 ended.
# 2208 ended.
# 2209 ended.
# 2210 ended.
# 2211 ended.
# 2212 ended.
# 2213 ended.
# 2214 ended.
# 2215 ended.
# 2216 ended.
# 2217 ended.
# 2218 ended.
# 2219 ended.
# 2220 ended.
# 2221 ended.
# 2222 ended.
# 2223 ended.
# 2224 ended.
# 2225 ended.
# 2226 ended.
# 2227 ended.
# 2228 ended.
# 2229 ended.
# 2230 ended.
# 2231 ended.
# 2232 ended.
# 2233 ended.
# 2234 ended.
# 2235 ended.
# 2236 ended.
# 2237 ended.
# 2238 ended.
# 2239 ended.
# 2240 ended.
# 2241 ended.
# 2242 ended.
# 2243 ended.
# 2244 ended.
# 2245 ended.
# 2246 ended.
# 2247 ended.
# 2248 ended.
# 2249 ended.
# 2250 ended.
# 2251 ended.
# 2252 ended.
# 2253 ended.
# 2254 ended.
# 2255 ended.
# 2256 ended.
# 2257 ended.
# 2258 ended.
# 2259 ended.
# 2260 ended.
# 2261 ended.
# 2262 ended.
# 2263 ended.
# 2264 ended.
# 2265 ended.
# 2266 ended.
# 2267 ended.
# 2268 ended.
# 2269 ended.
# 2270 ended.
# 2271 ended.
# 2272 ended.
# 2273 ended.
# 2274 ended.
# 2275 ended.
# 2276 ended.
# 2277 ended.
# 2278 ended.
# 2279 ended.
# 2280 ended.
# 2281 ended.
# 2282 ended.
# 2283 ended.
# 2284 ended.
# 2285 ended.
# 2286 ended.
# 2287 ended.
# 2288 ended.
# 2289 ended.
# 2290 ended.
# 2291 ended.
# 2292 ended.
# 2293 ended.
# 2294 ended.
# 2295 ended.
# 2296 ended.
# 2297 ended.
# 2298 ended.
# 2299 ended.
# 2300 ended.
# 2301 ended.
# 2302 ended.
# 2303 ended.
# 2304 ended.
# 2305 ended.
# 2306 ended.
# 2307 ended.
# 2308 ended.
# 2309 ended.
# 2310 ended.
# 2311 ended.
# 2312 ended.
# 2313 ended.
# 2314 ended.
# 2315 ended.
# 2316 ended.
# 2317 ended.
# 2318 ended.
# 2320 ended.
# 2321 ended.
# 2322 ended.
# 2323 ended.
# 2324 ended.
# 2325 ended.
# 2326 ended.
# 2327 ended.
# 2328 ended.
# 2329 ended.
# 2330 ended.
# 2331 ended.
# 2332 ended.
# 2333 ended.
# 2334 ended.
# 2335 ended.
# 2336 ended.
# 2337 ended.
# 2338 ended.
# 2339 ended.
# 2340 ended.
# 2341 ended.
# 2342 ended.
# 2343 ended.
# 2344 ended.
# 2345 ended.
# 2346 ended.
# 2347 ended.
# 2348 ended.
# 2349 ended.
# 2350 ended.
# 2351 ended.
# 2352 ended.
# 2353 ended.
# 2354 ended.
# 2355 ended.
# 2356 ended.
# 2357 ended.
# 2358 ended.
# 2359 ended.
# 2360 ended.
# 2361 ended.
# 2362 ended.
# 2363 ended.
# 2364 ended.
# 2365 ended.
# 2366 ended.
# 2367 ended.
# 2368 ended.
# 2369 ended.
# 2371 ended.
# 2372 ended.
# 2373 ended.
# 2374 ended.
# 2375 ended.
# 2376 ended.
# 2377 ended.
# 2378 ended.
# 2379 ended.
# 2380 ended.
# 2381 ended.
# 2382 ended.
# 2383 ended.
# 2384 ended.
# 2385 ended.
# 2386 ended.
# 2387 ended.
# 2388 ended.
# 2389 ended.
# 2390 ended.
# 2391 ended.
# 2392 ended.
# 2393 ended.
# 2394 ended.
# 2395 ended.
# 2396 ended.
# 2397 ended.
# 2398 ended.
# 2399 ended.
# 2400 ended.
