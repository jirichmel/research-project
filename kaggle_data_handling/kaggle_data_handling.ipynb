# %% [markdown]
# # Kaggle Dataset

# %%
import numpy as np
import pandas as pd
import os
import ray

# %%
# Multiprocessing is required otherwise we're gonna have a bad time
num_cpus = 15
ray.init(num_cpus = 15)
# Out:
# 2020-03-10 21:36:43,024	WARNING services.py:586 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2020-03-10 21:36:43,028	INFO resource_spec.py:212 -- Starting Ray with 343.12 GiB memory available for workers and up to 18.63 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-03-10 21:36:45,061	INFO services.py:1078 -- View the Ray dashboard at localhost:8265
# {'node_ip_address': '172.20.0.18',
#  'redis_address': '172.20.0.18:41265',
#  'object_store_address': '/tmp/ray/session_2020-03-10_21-36-43_023491_281069/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2020-03-10_21-36-43_023491_281069/sockets/raylet',
#  'webui_url': 'localhost:8265',
#  'session_dir': '/tmp/ray/session_2020-03-10_21-36-43_023491_281069'}

# %%
# The following function finds a specific line and get data in this single line
def match_line(raw_data_file, *args): # the path to the file and the sought strings
    lines = ""
    with open(raw_data_file, 'r') as file:
        for line in file: # iterate through the text file
            for arg in args: # for all strings passed to the function...
                if arg in line: # if the current line contains the sought string, then:
                    lines += line # Will add the matched text to the lines string
    return lines

# Gets all the numerical values from all the lines with the given match_string
# and outputs them in a list of three numerical values which can then be processed further
def get_line_data_with_species(input_string, keyword):
    vector_DATA = []
    l = []
    species = []
    for line in input_string:
        if keyword in line:
            l = []
            for t in line.split():
                try:
                    l.append(float(t))
                except ValueError:
                    pass
            vector_DATA.append(l)
            # get the element from the end of the string and use the same data format as vector_DATA:
            species.append(line[-2:].strip())
    return vector_DATA, species

# %%
def directories(where,number_of_directories):
    print("Make sure empty",where,"folder exists in the given path!")
    os.mkdir("".join(["../", where,"/directory_tree"]))
    os.mkdir("".join(["../", where,"/final"]))
    os.mkdir("".join(["../", where,"/relaxation"]))
    for i in range(1,number_of_directories+1):
        os.mkdir("".join(["../", where,"/directory_tree/",str(i)]))
    print("In","".join(["../",where]),"created final, relaxation and directory_tree folders,",number_of_directories,"directories in",where,"/directory_tree folder were created.")

# %%
# A Ray remote function
@ray.remote(num_return_vals=9)
def iterate_thru_all(where, list_of_filenumbers, *args): # number of files is the number of files from train_ or test_
    
    #Loading the OLS oxide energies:
    oxides = pd.read_csv("../OLS_oxide_energies").to_numpy()
    
    #############################
    
    # Need to load this to get the spacegroup column:
    df_work_test_or_train_DATA = pd.read_csv("".join(["../", where,".csv/", where,".csv"]))
    
    #############################
    
    ## General test or train data:
    df_general_DATA = pd.DataFrame(columns = ["id", "spacegroup", "number_of_total_atoms", 
                                                    "percent_atom_al", "percent_atom_ga", "percent_atom_in"]) 
    
    
    ## It is worth it to store the final values right now during the extraction:
    # Final lattice vectors:
    df_lattice_vector_DATA = pd.DataFrame(columns = ["id", 
                                                      "lattice_vector_1_x", "lattice_vector_1_y", "lattice_vector_1_z", 
                                                      "lattice_vector_2_x", "lattice_vector_2_y", "lattice_vector_2_z",
                                                      "lattice_vector_3_x", "lattice_vector_3_y", "lattice_vector_3_z"])
    # Final atomic coordinates:
    df_atoms_xyz_DATA = pd.DataFrame(columns = ["id", "species", "x [A]", "y [A]", "z [A]"])
    
    # Final fractional atomic coordinates:
    df_atoms_frac_xyz_DATA = pd.DataFrame(columns = ["id", "species", "L1", "L2", "L3"])
    
    # Final energy:
    df_energy_DATA = pd.DataFrame(columns = ["id", "formation_energy_ev_natom", "bandgap_energy_ev"])
    
    
    
    ## Relaxation step data:
    # lattice_vector data of relaxation steps:
    df_lattice_vector_relaxation_DATA = pd.DataFrame(columns = ["id", "relaxation_step_number", 
                                                      "lattice_vector_1_x", "lattice_vector_1_y", "lattice_vector_1_z", 
                                                      "lattice_vector_2_x", "lattice_vector_2_y", "lattice_vector_2_z",
                                                      "lattice_vector_3_x", "lattice_vector_3_y", "lattice_vector_3_z"])
    # atomic coordinates during relaxation steps:
    df_atoms_xyz_relaxation_DATA = pd.DataFrame(columns = ["id", "relaxation_step_number", "species", "x [A]", "y [A]", "z [A]"])

    # Fractional atomic coordinates during relaxation steps:
    df_atoms_frac_xyz_relaxation_DATA = pd.DataFrame(columns = ["id", "relaxation_step_number", "species", "L1", "L2", "L3"])

    # Energies during relaxation steps:
    df_energy_relaxation_DATA = pd.DataFrame(columns = ["id", "relaxation_step_number", "formation_energy_ev_natom", "bandgap_energy_ev"])
    
    ########################
    
    k = 0 # a counter
    l = 0 # another counter
    m = 0 # another counter
    n = 0 # another counter
    
    # Global iterators:
    global_iterator_0 = 0
    global_iterator_1 = 0
    global_iterator_2 = 0
    
    
    #########################
    
    for i in list_of_filenumbers:

        print("Extracting from bandfile number ", str(i), ".", " Calculating...")
        raw_data_file = "".join(["../", where, "_just_bandfiles/", str(i), "/band.out"]) # specify the path to the file in an iterable form
        output = match_line(raw_data_file, *args)
        output = output.splitlines() # convert the string into a list using the line breakers
        
        
        # Get kation percetages right:
        LINE_DATA = get_line_data_with_species(output[output.index("  Final atomic structure:"):],"            atom")
        for j in LINE_DATA[1]:
            if j == "O":
                k = k + 1
            elif j == "Al":
                l = l + 1
            elif j == "Ga":
                m = m + 1
            elif j == "In":
                n = n + 1
        NATOMS = k + l + m + n
        # Kation percentages (notice the absense of oxygen in the following three lines)
        percent_atom_al = l/(l+m+n)
        percent_atom_ga = m/(l+m+n)
        percent_atom_in = n/(l+m+n)
        # General data is stored right here:
        df_general_DATA.loc[i-1] = [str(i), df_work_test_or_train_DATA.at[i-1, "spacegroup"], str(NATOMS), percent_atom_al, percent_atom_ga, percent_atom_in]
        # Clearing some variables for future use:
        k = 0
        l = 0
        m = 0
        n = 0
        
        ## Final output dataset:
        # Preparing the final output in case no relaxation data are present and to get the final values 
        FINAL = output[output.index("  Final atomic structure:")-1:]
        
        # folder for the final data values:
        os.mkdir("".join(["../", where,"/directory_tree/", str(i),"/",str(i)]))
        
        # Lattice vectors:
        LINE_DATA_lattice = get_line_data_with_species(FINAL[2:5], "  lattice_vector")[0]
        
        # Open the file to save the lattice datapoint into a its folder:
        f = open("".join(["../", where,"/directory_tree/", str(i),"/",str(i),"/lattice_vector.csv"]),'w')
        f.write("id,lattice_vector_1_x,lattice_vector_1_y,lattice_vector_1_z,lattice_vector_2_x,lattice_vector_2_y,lattice_vector_2_z,lattice_vector_3_x,lattice_vector_3_y,lattice_vector_3_z\n")
        f.write(",".join(map(str,[i] + LINE_DATA_lattice[0] + LINE_DATA_lattice[1] + LINE_DATA_lattice[2]))+"\n")
        f.close()
        
        df_lattice_vector_DATA.loc[i-1] = [str(i)] + LINE_DATA_lattice[0] + LINE_DATA_lattice[1] + LINE_DATA_lattice[2]

        # Energies:
        LINE_DATA_gap = get_line_data_with_species([FINAL[0]],"  ESTIMATED overall HOMO-LUMO gap:")[0][0][0]
        LINE_DATA_energy = np.around(get_line_data_with_species([FINAL[-1]],"  | Total energy of the DFT / Hartree-Fock s.c.f. calculation      :")[0][0][0],decimals=8)
        # Formation calculation:
        LINE_DATA_energy = -2.5*(percent_atom_al*oxides[0][0] + percent_atom_ga*oxides[0][1] + percent_atom_in*oxides[0][2] - LINE_DATA_energy/NATOMS)
        # Open the file to save the energy datapoint into a its folder:
        f = open("".join(["../", where,"/directory_tree/", str(i),"/",str(i),"/energy.csv"]),'w')
        f.write("id,formation_energy_ev_natom,bandgap_energy_ev\n")
        f.write(",".join(map(str,[i] + [LINE_DATA_energy, LINE_DATA_gap]))+"\n")
        f.close()
        
        df_energy_DATA.loc[i-1] = [str(i),LINE_DATA_energy,LINE_DATA_gap]

        # Atomic positions:
        LINE_DATA_atom = get_line_data_with_species(FINAL,"            atom") # returns a list of two lists
        LINE_DATA_frac = get_line_data_with_species(FINAL, "       atom_frac") # returns a list of two lists
        
        f = open("".join(["../", where,"/directory_tree/", str(i),"/",str(i),"/atoms_xyz.csv"]),'w')
        g = open("".join(["../", where,"/directory_tree/", str(i),"/",str(i),"/atoms_frac_xyz.csv"]),'w')
        f.write("id,species,x [A],y [A],z [A]\n")
        g.write("id,species,L1,L2,L3\n")
        
        for j in range(NATOMS):
            f.write(",".join(map(str,[i, LINE_DATA_atom[1][j]] + LINE_DATA_atom[0][j]))+"\n")
            
            df_atoms_xyz_DATA.loc[global_iterator_0] = [str(i),str(LINE_DATA_atom[1][j])] + LINE_DATA_atom[0][j]

            g.write(",".join(map(str,[i, LINE_DATA_frac[1][j]] + LINE_DATA_frac[0][j]))+"\n")
            
            df_atoms_frac_xyz_DATA.loc[global_iterator_0] = [str(i),str(LINE_DATA_frac[1][j])] + LINE_DATA_frac[0][j]
            
            global_iterator_0 += 1
            
        f.close()
        g.close()
        
        # removes also the line before "  Final atomic structure:" which contains HOMO-LUMO energy and its value is reported two lines above this which we are about to remove:
        del output[output.index("  Final atomic structure:")-1:] 
        
        while k < len(output) and "  Relaxation step number" not in output[k]: # remove the selfconsistency output data before the Relaxation steps (can remove the whole list)
            k = k + 1
        del output[:k]
        k = 0
        
        if output != []: # if there are any Relaxation data then...
            LINE_DATA_energy = []
            LINE_DATA_gap = []
            # lattice_vectors of Relaxation + energies of Relaxation:
            LINE_DATA = get_line_data_with_species(output, "  lattice_vector")[0]
            
            l = 1 # relaxation step number starts with 1
            
            #the first folder for the first relaxation data
            os.mkdir("".join(["../", where,"/directory_tree/", str(i),"/",str(i),".", str(l)]))
            
            l = 2
            for j in range(1,len(output)): # omit the first line which includes the first Relaxation step number string
                if "Relaxation step number" in output[j]: # right above relaxation step number are two numerical values we want
                    
                    LINE_DATA_energy.append(get_line_data_with_species([output[j-2]],"  | Total energy                  :")[0][0][1])
                    LINE_DATA_gap.append(get_line_data_with_species([output[j-1]],"  ESTIMATED overall HOMO-LUMO gap:")[0][0][0])
                    
                    os.mkdir("".join(["../", where,"/directory_tree/", str(i),"/",str(i),".", str(l)]))
                    l = l + 1
            
            # Add the last relaxation step values:
            LINE_DATA_energy.append(get_line_data_with_species([output[-1]],"  | Total energy                  :")[0][0][1])
            LINE_DATA_gap.append(get_line_data_with_species([output[-2]],"  ESTIMATED overall HOMO-LUMO gap:")[0][0][0])
            
            
            l = 1 # relaxation step number starts with 1
            while LINE_DATA != []: # using the list of lattice vectors until we empty it
                
                # Open the file to save the lattice datapoint into a its folder:
                f = open("".join(["../", where,"/directory_tree/", str(i),"/",str(i),".", str(l),"/lattice_vector.csv"]),'w')
                f.write("id,relaxation_step_number,lattice_vector_1_x,lattice_vector_1_y,lattice_vector_1_z,lattice_vector_2_x,lattice_vector_2_y,lattice_vector_2_z,lattice_vector_3_x,lattice_vector_3_y,lattice_vector_3_z\n")
                f.write(",".join(map(str,[i, l] + LINE_DATA[0] + LINE_DATA[1] + LINE_DATA[2]))+"\n")
                f.close()
                
                df_lattice_vector_relaxation_DATA.loc[global_iterator_1] = [str(i),str(l)] + LINE_DATA[0] + LINE_DATA[1] + LINE_DATA[2]
                
                #Calculating the formation energy:
                LINE_DATA_energy[0] = -2.5*(percent_atom_al*oxides[0][0] + percent_atom_ga*oxides[0][1] + percent_atom_in*oxides[0][2] - LINE_DATA_energy[0]/NATOMS)
                
                # Open the file to save the energy datapoint into a its folder:
                f = open("".join(["../", where,"/directory_tree/", str(i),"/",str(i),".", str(l),"/energy.csv"]),'w')
                f.write("id,relaxation_step_number,formation_energy_ev_natom,bandgap_energy_ev\n")
                f.write(",".join(map(str,[i, l] + [LINE_DATA_energy[0], LINE_DATA_gap[0]]))+"\n")
                f.close()
                
                
                df_energy_relaxation_DATA.loc[global_iterator_1] = [str(i),str(l),LINE_DATA_energy[0],LINE_DATA_gap[0]]
                
                
                del LINE_DATA[:3] # delete the three values used
                del LINE_DATA_energy[0]
                del LINE_DATA_gap[0]
                
                l = l + 1 # counter for relaxation step
                global_iterator_1 += 1
            l = 0
            
            # Atomic positions of Relaxation + Fractional coordinates of Relaxation:
            LINE_DATA = get_line_data_with_species(output, "            atom")
            LINE_DATA_frac = get_line_data_with_species(output, "       atom_frac") # returns a list of two lists
            k = 1
            while LINE_DATA != ([], []):
                
                f = open("".join(["../", where,"/directory_tree/", str(i),"/",str(i),".", str(k),"/atoms_xyz.csv"]),'w')
                g = open("".join(["../", where,"/directory_tree/", str(i),"/",str(i),".", str(k),"/atoms_frac_xyz.csv"]),'w')
                f.write("id,relaxation_step_number,species,x [A],y [A],z [A]\n")
                g.write("id,relaxation_step_number,species,L1,L2,L3\n")
                
                for j in range(NATOMS):
                    
                    f.write(",".join(map(str,[i, k, LINE_DATA[1][j]] + LINE_DATA[0][j]))+"\n")
                    df_atoms_xyz_relaxation_DATA.loc[global_iterator_2] = [str(i),str(k),str(LINE_DATA[1][j])] + LINE_DATA[0][j]
                    g.write(",".join(map(str,[i, k, LINE_DATA_frac[1][j]] + LINE_DATA_frac[0][j]))+"\n")
                    df_atoms_frac_xyz_relaxation_DATA.loc[global_iterator_2] = [str(i),str(k),str(LINE_DATA_frac[1][j])] + LINE_DATA_frac[0][j]
                    global_iterator_2 += 1
                
                f.close()
                g.close()
                
                del LINE_DATA_frac[0][:NATOMS]
                del LINE_DATA_frac[1][:NATOMS]
                
                del LINE_DATA[0][:NATOMS]
                del LINE_DATA[1][:NATOMS]
                
                k += 1
            k = 0
        else: # if there are no relaxation data, then the final atomic structure is the only data point of the given material.
            # This is easily handled since the structure of the Final is the same everywhere
            # The relevant data is already in variables.
            # Lattice vectors:
            l = 0 # no relaxation means we assign zero to relaxation step number
            
            df_lattice_vector_relaxation_DATA.loc[global_iterator_1] = [str(i),str(l)] + LINE_DATA_lattice[0] + LINE_DATA_lattice[1] + LINE_DATA_lattice[2]
            
            # Energies:
            df_energy_relaxation_DATA.loc[global_iterator_1] = [str(i),str(l),LINE_DATA_energy,LINE_DATA_gap]
            
            global_iterator_1 += 1
            
            # Atomic positions:
            for j in range(NATOMS):
                
                df_atoms_xyz_relaxation_DATA.loc[global_iterator_2] = [str(i),str(l),str(LINE_DATA_atom[1][j])] + LINE_DATA_atom[0][j]
                df_atoms_frac_xyz_relaxation_DATA.loc[global_iterator_2] = [str(i),str(l),str(LINE_DATA_frac[1][j])] + LINE_DATA_frac[0][j]
                
                global_iterator_2 += 1
            
    # return the created dataframes
    print("Done with files",min(list_of_filenumbers), "-", max(list_of_filenumbers), ".")
    return df_general_DATA, df_lattice_vector_relaxation_DATA, df_energy_relaxation_DATA, df_atoms_xyz_relaxation_DATA, df_atoms_frac_xyz_relaxation_DATA, df_lattice_vector_DATA, df_energy_DATA, df_atoms_xyz_DATA, df_atoms_frac_xyz_DATA

# %%
# Create parent directories of the materials
directories("train",2400)
# Out:
# Make sure empty train folder exists in the given path!
# In ../train created final, relaxation and directory_tree folders, 2400 directories in train /directory_tree folder were created.

# %%
# Create parent directories of the materials
directories("test",600)
# Out:
# Make sure empty test folder exists in the given path!
# In ../test created final, relaxation and directory_tree folders, 600 directories in test /directory_tree folder were created.

# %%
# train set
list_of_file_numbers = []
for k in range(num_cpus):
    list_of_file_numbers.append(list(range(1 +k*160,160+1 +k*160)))
    
## Cleaning the train set:

# Problematic datafiles:
print("Removing material id",list_of_file_numbers[2][list_of_file_numbers[2].index(464)])
del list_of_file_numbers[2][list_of_file_numbers[2].index(464)] # 464. is problematic and will not be included in the dataset
print("Removing material id",list_of_file_numbers[13][list_of_file_numbers[13].index(2189)])
del list_of_file_numbers[13][list_of_file_numbers[13].index(2189)] # 2189. is problematic and will not be included in the dataset

# Removing duplicates from the train set:
print("Removing material id",list_of_file_numbers[0][list_of_file_numbers[0].index(126)])
del list_of_file_numbers[0][list_of_file_numbers[0].index(126)] # id 395/126 is duplicate. One removed.
print("Removing material id",list_of_file_numbers[7][list_of_file_numbers[7].index(1215)])
del list_of_file_numbers[7][list_of_file_numbers[7].index(1215)] # id 1215/1886 is duplicate. One removed.
print("Removing material id",list_of_file_numbers[2][list_of_file_numbers[2].index(353)])
del list_of_file_numbers[2][list_of_file_numbers[2].index(353)] # id 2075/353 is duplicate. One removed.
print("Removing material id",list_of_file_numbers[1][list_of_file_numbers[1].index(308)])
del list_of_file_numbers[1][list_of_file_numbers[1].index(308)] # id 308/2154 is duplicate. One removed.
print("Removing material id",list_of_file_numbers[3][list_of_file_numbers[3].index(531)])
del list_of_file_numbers[3][list_of_file_numbers[3].index(531)] # id 531/1379 is duplicate. One removed.
print("Removing material id",list_of_file_numbers[14][list_of_file_numbers[14].index(2319)])
del list_of_file_numbers[14][list_of_file_numbers[14].index(2319)] # id 2319/2337 is duplicate. One removed.
print("Removing material id",list_of_file_numbers[14][list_of_file_numbers[14].index(2370)])
del list_of_file_numbers[14][list_of_file_numbers[14].index(2370)] # id 2370/2333 is duplicate. One removed.

object_ids = []

# Parallel forcycle:
for core in range(num_cpus): # get the object ids into a list
    object_ids.append( iterate_thru_all.remote("train",list_of_file_numbers[core],"  Relaxation step number", "  lattice_vector ", "            atom", "       atom_frac", 
                 "ESTIMATED overall HOMO-LUMO gap:", "  | Total energy                  :", "  Final atomic structure:", 
                 "  | Total energy of the DFT / Hartree-Fock s.c.f. calculation      :")
)
dataframes = []
for core in range(num_cpus): # get the actual dataframes from the object ids
    dataframes.append(ray.get(object_ids[core]))

# concatenate the dataframes
df_general_DATA = pd.concat([dataframes[core][0] for core in range(num_cpus)], ignore_index=True)
df_lattice_vector_relaxation_DATA = pd.concat([dataframes[core][1] for core in range(num_cpus)], ignore_index=True)
df_energy_relaxation_DATA = pd.concat([dataframes[core][2] for core in range(num_cpus)], ignore_index=True)
df_atoms_xyz_relaxation_DATA = pd.concat([dataframes[core][3] for core in range(num_cpus)], ignore_index=True)
df_atoms_frac_xyz_relaxation_DATA = pd.concat([dataframes[core][4] for core in range(num_cpus)], ignore_index=True)

# save the datasets:
df_general_DATA.to_csv("../train/relaxation/general.csv", index = False)
df_lattice_vector_relaxation_DATA.to_csv("../train/relaxation/lattice_vector_relaxation.csv", index = False)
df_energy_relaxation_DATA.to_csv("../train/relaxation/energy_relaxation.csv", index = False)
df_atoms_xyz_relaxation_DATA.to_csv("../train/relaxation/atoms_xyz_relaxation.csv", index = False)
df_atoms_frac_xyz_relaxation_DATA.to_csv("../train/relaxation/atoms_frac_xyz_relaxation.csv", index = False)

df_lattice_vector_DATA = pd.concat([dataframes[core][5] for core in range(num_cpus)], ignore_index=True)
df_energy_DATA = pd.concat([dataframes[core][6] for core in range(num_cpus)], ignore_index=True)
df_atoms_xyz_DATA = pd.concat([dataframes[core][7] for core in range(num_cpus)], ignore_index=True)
df_atoms_frac_xyz_DATA = pd.concat([dataframes[core][8] for core in range(num_cpus)], ignore_index=True)

df_lattice_vector_DATA.to_csv("../train/final/lattice_vector.csv", index = False)
df_energy_DATA.to_csv("../train/final/energy.csv", index = False)
df_atoms_xyz_DATA.to_csv("../train/final/atoms_xyz.csv", index = False)
df_atoms_frac_xyz_DATA.to_csv("../train/final/atoms_frac_xyz.csv", index = False)
# Out:
# Removing material id 464
# Removing material id 2189
# Removing material id 126
# Removing material id 1215
# Removing material id 353
# Removing material id 308
# Removing material id 531
# Removing material id 2319
# Removing material id 2370
# (pid=279403) Extracting from bandfile number  1121 .  Calculating...
# (pid=279410) Extracting from bandfile number  2081 .  Calculating...
# (pid=279401) Extracting from bandfile number  2241 .  Calculating...
# (pid=279406) Extracting from bandfile number  1921 .  Calculating...
# (pid=279398) Extracting from bandfile number  321 .  Calculating...
# (pid=279399) Extracting from bandfile number  641 .  Calculating...
# (pid=279408) Extracting from bandfile number  481 .  Calculating...
# (pid=279404) Extracting from bandfile number  1441 .  Calculating...
# (pid=279396) Extracting from bandfile number  961 .  Calculating...
# (pid=279397) Extracting from bandfile number  1 .  Calculating...
# (pid=279400) Extracting from bandfile number  801 .  Calculating...
# (pid=279409) Extracting from bandfile number  161 .  Calculating...
# (pid=279402) Extracting from bandfile number  1761 .  Calculating...
# (pid=279405) Extracting from bandfile number  1281 .  Calculating...
# (pid=279407) Extracting from bandfile number  1601 .  Calculating...
# (pid=279408) Extracting from bandfile number  482 .  Calculating...
# (pid=279397) Extracting from bandfile number  2 .  Calculating...
# (pid=279407) Extracting from bandfile number  1602 .  Calculating...
# (pid=279406) Extracting from bandfile number  1922 .  Calculating...
# (pid=279403) Extracting from bandfile number  1122 .  Calculating...
# (pid=279407) Extracting from bandfile number  1603 .  Calculating...
# (pid=279406) Extracting from bandfile number  1923 .  Calculating...
# (pid=279407) Extracting from bandfile number  1604 .  Calculating...
# (pid=279401) Extracting from bandfile number  2242 .  Calculating...
# (pid=279396) Extracting from bandfile number  962 .  Calculating...
# (pid=279398) Extracting from bandfile number  322 .  Calculating...
# (pid=279403) Extracting from bandfile number  1123 .  Calculating...
# (pid=279406) Extracting from bandfile number  1924 .  Calculating...
# (pid=279398) Extracting from bandfile number  323 .  Calculating...
# (pid=279405) Extracting from bandfile number  1282 .  Calculating...
# (pid=279400) Extracting from bandfile number  802 .  Calculating...
# (pid=279407) Extracting from bandfile number  1605 .  Calculating...
# (pid=279405) Extracting from bandfile number  1283 .  Calculating...
# (pid=279410) Extracting from bandfile number  2082 .  Calculating...
# (pid=279401) Extracting from bandfile number  2243 .  Calculating...
# (pid=279402) Extracting from bandfile number  1762 .  Calculating...
# (pid=279399) Extracting from bandfile number  642 .  Calculating...
# (pid=279410) Extracting from bandfile number  2083 .  Calculating...
# (pid=279397) Extracting from bandfile number  3 .  Calculating...
# (pid=279404) Extracting from bandfile number  1442 .  Calculating...
# (pid=279409) Extracting from bandfile number  162 .  Calculating...
# (pid=279397) Extracting from bandfile number  4 .  Calculating...
# (pid=279397) Extracting from bandfile number  5 .  Calculating...
# (pid=279396) Extracting from bandfile number  963 .  Calculating...
# (pid=279399) Extracting from bandfile number  643 .  Calculating...
# (pid=279401) Extracting from bandfile number  2244 .  Calculating...
# (pid=279406) Extracting from bandfile number  1925 .  Calculating...
# (pid=279408) Extracting from bandfile number  483 .  Calculating...
# (pid=279408) Extracting from bandfile number  484 .  Calculating...
# (pid=279401) Extracting from bandfile number  2245 .  Calculating...
# (pid=279403) Extracting from bandfile number  1124 .  Calculating...
# (pid=279410) Extracting from bandfile number  2084 .  Calculating...
# (pid=279402) Extracting from bandfile number  1763 .  Calculating...
# (pid=279400) Extracting from bandfile number  803 .  Calculating...
# (pid=279397) Extracting from bandfile number  6 .  Calculating...
# (pid=279399) Extracting from bandfile number  644 .  Calculating...
# (pid=279405) Extracting from bandfile number  1284 .  Calculating...
# (pid=279396) Extracting from bandfile number  964 .  Calculating...
# (pid=279402) Extracting from bandfile number  1764 .  Calculating...
# (pid=279398) Extracting from bandfile number  324 .  Calculating...
# (pid=279397) Extracting from bandfile number  7 .  Calculating...
# (pid=279403) Extracting from bandfile number  1125 .  Calculating...
# (pid=279409) Extracting from bandfile number  163 .  Calculating...
# (pid=279404) Extracting from bandfile number  1443 .  Calculating...
# (pid=279404) Extracting from bandfile number  1444 .  Calculating...
# (pid=279403) Extracting from bandfile number  1126 .  Calculating...
# (pid=279407) Extracting from bandfile number  1606 .  Calculating...
# (pid=279406) Extracting from bandfile number  1926 .  Calculating...
# (pid=279408) Extracting from bandfile number  485 .  Calculating...
# (pid=279407) Extracting from bandfile number  1607 .  Calculating...
# (pid=279403) Extracting from bandfile number  1127 .  Calculating...
# (pid=279397) Extracting from bandfile number  8 .  Calculating...
# (pid=279405) Extracting from bandfile number  1285 .  Calculating...
# (pid=279398) Extracting from bandfile number  325 .  Calculating...
# (pid=279410) Extracting from bandfile number  2085 .  Calculating...
# (pid=279407) Extracting from bandfile number  1608 .  Calculating...
# (pid=279401) Extracting from bandfile number  2246 .  Calculating...
# (pid=279405) Extracting from bandfile number  1286 .  Calculating...
# (pid=279402) Extracting from bandfile number  1765 .  Calculating...
# (pid=279398) Extracting from bandfile number  326 .  Calculating...
# (pid=279410) Extracting from bandfile number  2086 .  Calculating...
# (pid=279399) Extracting from bandfile number  645 .  Calculating...
# (pid=279396) Extracting from bandfile number  965 .  Calculating...
# (pid=279401) Extracting from bandfile number  2247 .  Calculating...
# (pid=279409) Extracting from bandfile number  164 .  Calculating...
# (pid=279396) Extracting from bandfile number  966 .  Calculating...
# (pid=279397) Extracting from bandfile number  9 .  Calculating...
# (pid=279403) Extracting from bandfile number  1128 .  Calculating...
# (pid=279409) Extracting from bandfile number  165 .  Calculating...
# (pid=279404) Extracting from bandfile number  1445 .  Calculating...
# (pid=279404) Extracting from bandfile number  1446 .  Calculating...
# (pid=279406) Extracting from bandfile number  1927 .  Calculating...
# (pid=279400) Extracting from bandfile number  804 .  Calculating...
# (pid=279406) Extracting from bandfile number  1928 .  Calculating...
# (pid=279408) Extracting from bandfile number  486 .  Calculating...
# (pid=279408) Extracting from bandfile number  487 .  Calculating...
# (pid=279405) Extracting from bandfile number  1287 .  Calculating...
# (pid=279396) Extracting from bandfile number  967 .  Calculating...
# (pid=279402) Extracting from bandfile number  1766 .  Calculating...
# (pid=279407) Extracting from bandfile number  1609 .  Calculating...
# (pid=279405) Extracting from bandfile number  1288 .  Calculating...
# (pid=279399) Extracting from bandfile number  646 .  Calculating...
# (pid=279409) Extracting from bandfile number  166 .  Calculating...
# (pid=279405) Extracting from bandfile number  1289 .  Calculating...
# (pid=279401) Extracting from bandfile number  2248 .  Calculating...
# (pid=279398) Extracting from bandfile number  327 .  Calculating...
# (pid=279401) Extracting from bandfile number  2249 .  Calculating...
# (pid=279400) Extracting from bandfile number  805 .  Calculating...
# (pid=279397) Extracting from bandfile number  10 .  Calculating...
# (pid=279409) Extracting from bandfile number  167 .  Calculating...
# (pid=279402) Extracting from bandfile number  1767 .  Calculating...
# (pid=279404) Extracting from bandfile number  1447 .  Calculating...
# (pid=279403) Extracting from bandfile number  1129 .  Calculating...
# (pid=279409) Extracting from bandfile number  168 .  Calculating...
# (pid=279398) Extracting from bandfile number  328 .  Calculating...
# (pid=279404) Extracting from bandfile number  1448 .  Calculating...
# (pid=279410) Extracting from bandfile number  2087 .  Calculating...
# (pid=279407) Extracting from bandfile number  1610 .  Calculating...
# (pid=279404) Extracting from bandfile number  1449 .  Calculating...
# (pid=279406) Extracting from bandfile number  1929 .  Calculating...
# (pid=279397) Extracting from bandfile number  11 .  Calculating...
# (pid=279406) Extracting from bandfile number  1930 .  Calculating...
# (pid=279397) Extracting from bandfile number  12 .  Calculating...
# (pid=279399) Extracting from bandfile number  647 .  Calculating...
# (pid=279408) Extracting from bandfile number  488 .  Calculating...
# (pid=279404) Extracting from bandfile number  1450 .  Calculating...
# (pid=279404) Extracting from bandfile number  1451 .  Calculating...
# (pid=279402) Extracting from bandfile number  1768 .  Calculating...
# (pid=279404) Extracting from bandfile number  1452 .  Calculating...
# (pid=279410) Extracting from bandfile number  2088 .  Calculating...
# (pid=279409) Extracting from bandfile number  169 .  Calculating...
# (pid=279400) Extracting from bandfile number  806 .  Calculating...
# (pid=279400) Extracting from bandfile number  807 .  Calculating...
# (pid=279396) Extracting from bandfile number  968 .  Calculating...
# (pid=279402) Extracting from bandfile number  1769 .  Calculating...
# (pid=279409) Extracting from bandfile number  170 .  Calculating...
# (pid=279409) Extracting from bandfile number  171 .  Calculating...
# (pid=279398) Extracting from bandfile number  329 .  Calculating...
# (pid=279409) Extracting from bandfile number  172 .  Calculating...
# (pid=279403) Extracting from bandfile number  1130 .  Calculating...
# (pid=279405) Extracting from bandfile number  1290 .  Calculating...
# (pid=279404) Extracting from bandfile number  1453 .  Calculating...
# (pid=279403) Extracting from bandfile number  1131 .  Calculating...
# (pid=279407) Extracting from bandfile number  1611 .  Calculating...
# (pid=279404) Extracting from bandfile number  1454 .  Calculating...
# (pid=279405) Extracting from bandfile number  1291 .  Calculating...
# (pid=279408) Extracting from bandfile number  489 .  Calculating...
# (pid=279409) Extracting from bandfile number  173 .  Calculating...
# (pid=279401) Extracting from bandfile number  2250 .  Calculating...
# (pid=279397) Extracting from bandfile number  13 .  Calculating...
# (pid=279408) Extracting from bandfile number  490 .  Calculating...
# (pid=279397) Extracting from bandfile number  14 .  Calculating...
# (pid=279402) Extracting from bandfile number  1770 .  Calculating...
# (pid=279406) Extracting from bandfile number  1931 .  Calculating...
# (pid=279408) Extracting from bandfile number  491 .  Calculating...
# (pid=279399) Extracting from bandfile number  648 .  Calculating...
# (pid=279397) Extracting from bandfile number  15 .  Calculating...
# (pid=279410) Extracting from bandfile number  2089 .  Calculating...
# (pid=279408) Extracting from bandfile number  492 .  Calculating...
# (pid=279407) Extracting from bandfile number  1612 .  Calculating...
# (pid=279404) Extracting from bandfile number  1455 .  Calculating...
# (pid=279406) Extracting from bandfile number  1932 .  Calculating...
# (pid=279409) Extracting from bandfile number  174 .  Calculating...
# (pid=279408) Extracting from bandfile number  493 .  Calculating...
# (pid=279405) Extracting from bandfile number  1292 .  Calculating...
# (pid=279396) Extracting from bandfile number  969 .  Calculating...
# (pid=279400) Extracting from bandfile number  808 .  Calculating...
# (pid=279407) Extracting from bandfile number  1613 .  Calculating...
# (pid=279405) Extracting from bandfile number  1293 .  Calculating...
# (pid=279410) Extracting from bandfile number  2090 .  Calculating...
# (pid=279398) Extracting from bandfile number  330 .  Calculating...
# (pid=279400) Extracting from bandfile number  809 .  Calculating...
# (pid=279403) Extracting from bandfile number  1132 .  Calculating...
# (pid=279405) Extracting from bandfile number  1294 .  Calculating...
# (pid=279401) Extracting from bandfile number  2251 .  Calculating...
# (pid=279404) Extracting from bandfile number  1456 .  Calculating...
# (pid=279401) Extracting from bandfile number  2252 .  Calculating...
# (pid=279399) Extracting from bandfile number  649 .  Calculating...
# (pid=279409) Extracting from bandfile number  175 .  Calculating...
# (pid=279402) Extracting from bandfile number  1771 .  Calculating...
# (pid=279406) Extracting from bandfile number  1933 .  Calculating...
# (pid=279407) Extracting from bandfile number  1614 .  Calculating...
# (pid=279402) Extracting from bandfile number  1772 .  Calculating...
# (pid=279406) Extracting from bandfile number  1934 .  Calculating...
# (pid=279398) Extracting from bandfile number  331 .  Calculating...
# (pid=279397) Extracting from bandfile number  16 .  Calculating...
# (pid=279400) Extracting from bandfile number  810 .  Calculating...
# (pid=279410) Extracting from bandfile number  2091 .  Calculating...
# (pid=279400) Extracting from bandfile number  811 .  Calculating...
# (pid=279408) Extracting from bandfile number  494 .  Calculating...
# (pid=279408) Extracting from bandfile number  495 .  Calculating...
# (pid=279405) Extracting from bandfile number  1295 .  Calculating...
# (pid=279410) Extracting from bandfile number  2092 .  Calculating...
# (pid=279404) Extracting from bandfile number  1457 .  Calculating...
# (pid=279405) Extracting from bandfile number  1296 .  Calculating...
# (pid=279401) Extracting from bandfile number  2253 .  Calculating...
# (pid=279396) Extracting from bandfile number  970 .  Calculating...
# (pid=279402) Extracting from bandfile number  1773 .  Calculating...
# (pid=279396) Extracting from bandfile number  971 .  Calculating...
# (pid=279409) Extracting from bandfile number  176 .  Calculating...
# (pid=279409) Extracting from bandfile number  177 .  Calculating...
# (pid=279404) Extracting from bandfile number  1458 .  Calculating...
# (pid=279403) Extracting from bandfile number  1133 .  Calculating...
# (pid=279404) Extracting from bandfile number  1459 .  Calculating...
# (pid=279403) Extracting from bandfile number  1134 .  Calculating...
# (pid=279399) Extracting from bandfile number  650 .  Calculating...
# (pid=279406) Extracting from bandfile number  1935 .  Calculating...
# (pid=279399) Extracting from bandfile number  651 .  Calculating...
# (pid=279397) Extracting from bandfile number  17 .  Calculating...
# (pid=279402) Extracting from bandfile number  1774 .  Calculating...
# (pid=279410) Extracting from bandfile number  2093 .  Calculating...
# (pid=279407) Extracting from bandfile number  1615 .  Calculating...
# (pid=279400) Extracting from bandfile number  812 .  Calculating...
# (pid=279409) Extracting from bandfile number  178 .  Calculating...
# (pid=279398) Extracting from bandfile number  332 .  Calculating...
# (pid=279396) Extracting from bandfile number  972 .  Calculating...
# (pid=279405) Extracting from bandfile number  1297 .  Calculating...
# (pid=279401) Extracting from bandfile number  2254 .  Calculating...
# (pid=279398) Extracting from bandfile number  333 .  Calculating...
# (pid=279405) Extracting from bandfile number  1298 .  Calculating...
# (pid=279396) Extracting from bandfile number  973 .  Calculating...
# (pid=279397) Extracting from bandfile number  18 .  Calculating...
# (pid=279401) Extracting from bandfile number  2255 .  Calculating...
# (pid=279409) Extracting from bandfile number  179 .  Calculating...
# (pid=279410) Extracting from bandfile number  2094 .  Calculating...
# (pid=279406) Extracting from bandfile number  1936 .  Calculating...
# (pid=279410) Extracting from bandfile number  2095 .  Calculating...
# (pid=279404) Extracting from bandfile number  1460 .  Calculating...
# (pid=279408) Extracting from bandfile number  496 .  Calculating...
# (pid=279407) Extracting from bandfile number  1616 .  Calculating...
# (pid=279399) Extracting from bandfile number  652 .  Calculating...
# (pid=279408) Extracting from bandfile number  497 .  Calculating...
# (pid=279404) Extracting from bandfile number  1461 .  Calculating...
# (pid=279403) Extracting from bandfile number  1135 .  Calculating...
# (pid=279410) Extracting from bandfile number  2096 .  Calculating...
# (pid=279397) Extracting from bandfile number  19 .  Calculating...
# (pid=279401) Extracting from bandfile number  2256 .  Calculating...
# (pid=279397) Extracting from bandfile number  20 .  Calculating...
# (pid=279408) Extracting from bandfile number  498 .  Calculating...
# (pid=279407) Extracting from bandfile number  1617 .  Calculating...
# (pid=279397) Extracting from bandfile number  21 .  Calculating...
# (pid=279402) Extracting from bandfile number  1775 .  Calculating...
# (pid=279400) Extracting from bandfile number  813 .  Calculating...
# (pid=279397) Extracting from bandfile number  22 .  Calculating...
# (pid=279407) Extracting from bandfile number  1618 .  Calculating...
# (pid=279397) Extracting from bandfile number  23 .  Calculating...
# (pid=279400) Extracting from bandfile number  814 .  Calculating...
# (pid=279406) Extracting from bandfile number  1937 .  Calculating...
# (pid=279397) Extracting from bandfile number  24 .  Calculating...
# (pid=279398) Extracting from bandfile number  334 .  Calculating...
# (pid=279400) Extracting from bandfile number  815 .  Calculating...
# (pid=279406) Extracting from bandfile number  1938 .  Calculating...
# (pid=279401) Extracting from bandfile number  2257 .  Calculating...
# (pid=279403) Extracting from bandfile number  1136 .  Calculating...
# (pid=279405) Extracting from bandfile number  1299 .  Calculating...
# (pid=279403) Extracting from bandfile number  1137 .  Calculating...
# (pid=279398) Extracting from bandfile number  335 .  Calculating...
# (pid=279397) Extracting from bandfile number  25 .  Calculating...
# (pid=279401) Extracting from bandfile number  2258 .  Calculating...
# (pid=279407) Extracting from bandfile number  1619 .  Calculating...
# (pid=279396) Extracting from bandfile number  974 .  Calculating...
# (pid=279407) Extracting from bandfile number  1620 .  Calculating...
# (pid=279404) Extracting from bandfile number  1462 .  Calculating...
# (pid=279398) Extracting from bandfile number  336 .  Calculating...
# (pid=279397) Extracting from bandfile number  26 .  Calculating...
# (pid=279401) Extracting from bandfile number  2259 .  Calculating...
# (pid=279406) Extracting from bandfile number  1939 .  Calculating...
# (pid=279398) Extracting from bandfile number  337 .  Calculating...
# (pid=279400) Extracting from bandfile number  816 .  Calculating...
# (pid=279402) Extracting from bandfile number  1776 .  Calculating...
# (pid=279409) Extracting from bandfile number  180 .  Calculating...
# (pid=279410) Extracting from bandfile number  2097 .  Calculating...
# (pid=279404) Extracting from bandfile number  1463 .  Calculating...
# (pid=279409) Extracting from bandfile number  181 .  Calculating...
# (pid=279410) Extracting from bandfile number  2098 .  Calculating...
# (pid=279400) Extracting from bandfile number  817 .  Calculating...
# (pid=279408) Extracting from bandfile number  499 .  Calculating...
# (pid=279399) Extracting from bandfile number  653 .  Calculating...
# (pid=279397) Extracting from bandfile number  27 .  Calculating...
# (pid=279400) Extracting from bandfile number  818 .  Calculating...
# (pid=279399) Extracting from bandfile number  654 .  Calculating...
# (pid=279400) Extracting from bandfile number  819 .  Calculating...
# (pid=279407) Extracting from bandfile number  1621 .  Calculating...
# (pid=279400) Extracting from bandfile number  820 .  Calculating...
# (pid=279410) Extracting from bandfile number  2099 .  Calculating...
# (pid=279408) Extracting from bandfile number  500 .  Calculating...
# (pid=279409) Extracting from bandfile number  182 .  Calculating...
# (pid=279400) Extracting from bandfile number  821 .  Calculating...
# (pid=279403) Extracting from bandfile number  1138 .  Calculating...
# (pid=279405) Extracting from bandfile number  1300 .  Calculating...
# (pid=279397) Extracting from bandfile number  28 .  Calculating...
# (pid=279396) Extracting from bandfile number  975 .  Calculating...
# (pid=279401) Extracting from bandfile number  2260 .  Calculating...
# (pid=279406) Extracting from bandfile number  1940 .  Calculating...
# (pid=279404) Extracting from bandfile number  1464 .  Calculating...
# (pid=279397) Extracting from bandfile number  29 .  Calculating...
# (pid=279404) Extracting from bandfile number  1465 .  Calculating...
# (pid=279396) Extracting from bandfile number  976 .  Calculating...
# (pid=279402) Extracting from bandfile number  1777 .  Calculating...
# (pid=279401) Extracting from bandfile number  2261 .  Calculating...
# (pid=279408) Extracting from bandfile number  501 .  Calculating...
# (pid=279398) Extracting from bandfile number  338 .  Calculating...
# (pid=279399) Extracting from bandfile number  655 .  Calculating...
# (pid=279405) Extracting from bandfile number  1301 .  Calculating...
# (pid=279399) Extracting from bandfile number  656 .  Calculating...
# (pid=279409) Extracting from bandfile number  183 .  Calculating...
# (pid=279405) Extracting from bandfile number  1302 .  Calculating...
# (pid=279404) Extracting from bandfile number  1466 .  Calculating...
# (pid=279400) Extracting from bandfile number  822 .  Calculating...
# (pid=279402) Extracting from bandfile number  1778 .  Calculating...
# (pid=279405) Extracting from bandfile number  1303 .  Calculating...
# (pid=279407) Extracting from bandfile number  1622 .  Calculating...
# (pid=279398) Extracting from bandfile number  339 .  Calculating...
# (pid=279402) Extracting from bandfile number  1779 .  Calculating...
# (pid=279397) Extracting from bandfile number  30 .  Calculating...
# (pid=279401) Extracting from bandfile number  2262 .  Calculating...
# (pid=279405) Extracting from bandfile number  1304 .  Calculating...
# (pid=279405) Extracting from bandfile number  1305 .  Calculating...
# (pid=279403) Extracting from bandfile number  1139 .  Calculating...
# (pid=279410) Extracting from bandfile number  2100 .  Calculating...
# (pid=279400) Extracting from bandfile number  823 .  Calculating...
# (pid=279396) Extracting from bandfile number  977 .  Calculating...
# (pid=279403) Extracting from bandfile number  1140 .  Calculating...
# (pid=279398) Extracting from bandfile number  340 .  Calculating...
# (pid=279396) Extracting from bandfile number  978 .  Calculating...
# (pid=279410) Extracting from bandfile number  2101 .  Calculating...
# (pid=279399) Extracting from bandfile number  657 .  Calculating...
# (pid=279396) Extracting from bandfile number  979 .  Calculating...
# (pid=279407) Extracting from bandfile number  1623 .  Calculating...
# (pid=279408) Extracting from bandfile number  502 .  Calculating...
# (pid=279406) Extracting from bandfile number  1941 .  Calculating...
# (pid=279406) Extracting from bandfile number  1942 .  Calculating...
# (pid=279399) Extracting from bandfile number  658 .  Calculating...
# (pid=279401) Extracting from bandfile number  2263 .  Calculating...
# (pid=279397) Extracting from bandfile number  31 .  Calculating...
# (pid=279406) Extracting from bandfile number  1943 .  Calculating...
# (pid=279404) Extracting from bandfile number  1467 .  Calculating...
# (pid=279409) Extracting from bandfile number  184 .  Calculating...
# (pid=279402) Extracting from bandfile number  1780 .  Calculating...
# (pid=279400) Extracting from bandfile number  824 .  Calculating...
# (pid=279409) Extracting from bandfile number  185 .  Calculating...
# (pid=279408) Extracting from bandfile number  503 .  Calculating...
# (pid=279398) Extracting from bandfile number  341 .  Calculating...
# (pid=279408) Extracting from bandfile number  504 .  Calculating...
# (pid=279409) Extracting from bandfile number  186 .  Calculating...
# (pid=279408) Extracting from bandfile number  505 .  Calculating...
# (pid=279405) Extracting from bandfile number  1306 .  Calculating...
# (pid=279398) Extracting from bandfile number  342 .  Calculating...
# (pid=279408) Extracting from bandfile number  506 .  Calculating...
# (pid=279398) Extracting from bandfile number  343 .  Calculating...
# (pid=279398) Extracting from bandfile number  344 .  Calculating...
# (pid=279403) Extracting from bandfile number  1141 .  Calculating...
# (pid=279406) Extracting from bandfile number  1944 .  Calculating...
# (pid=279404) Extracting from bandfile number  1468 .  Calculating...
# (pid=279403) Extracting from bandfile number  1142 .  Calculating...
# (pid=279399) Extracting from bandfile number  659 .  Calculating...
# (pid=279400) Extracting from bandfile number  825 .  Calculating...
# (pid=279406) Extracting from bandfile number  1945 .  Calculating...
# (pid=279403) Extracting from bandfile number  1143 .  Calculating...
# (pid=279396) Extracting from bandfile number  980 .  Calculating...
# (pid=279400) Extracting from bandfile number  826 .  Calculating...
# (pid=279410) Extracting from bandfile number  2102 .  Calculating...
# (pid=279407) Extracting from bandfile number  1624 .  Calculating...
# (pid=279403) Extracting from bandfile number  1144 .  Calculating...
# (pid=279409) Extracting from bandfile number  187 .  Calculating...
# (pid=279403) Extracting from bandfile number  1145 .  Calculating...
# (pid=279405) Extracting from bandfile number  1307 .  Calculating...
# (pid=279396) Extracting from bandfile number  981 .  Calculating...
# (pid=279397) Extracting from bandfile number  32 .  Calculating...
# (pid=279409) Extracting from bandfile number  188 .  Calculating...
# (pid=279403) Extracting from bandfile number  1146 .  Calculating...
# (pid=279402) Extracting from bandfile number  1781 .  Calculating...
# (pid=279403) Extracting from bandfile number  1147 .  Calculating...
# (pid=279401) Extracting from bandfile number  2264 .  Calculating...
# (pid=279400) Extracting from bandfile number  827 .  Calculating...
# (pid=279405) Extracting from bandfile number  1308 .  Calculating...
# (pid=279401) Extracting from bandfile number  2265 .  Calculating...
# (pid=279402) Extracting from bandfile number  1782 .  Calculating...
# (pid=279399) Extracting from bandfile number  660 .  Calculating...
# (pid=279400) Extracting from bandfile number  828 .  Calculating...
# (pid=279402) Extracting from bandfile number  1783 .  Calculating...
# (pid=279402) Extracting from bandfile number  1784 .  Calculating...
# (pid=279410) Extracting from bandfile number  2103 .  Calculating...
# (pid=279408) Extracting from bandfile number  507 .  Calculating...
# (pid=279404) Extracting from bandfile number  1469 .  Calculating...
# (pid=279407) Extracting from bandfile number  1625 .  Calculating...
# (pid=279405) Extracting from bandfile number  1309 .  Calculating...
# (pid=279396) Extracting from bandfile number  982 .  Calculating...
# (pid=279410) Extracting from bandfile number  2104 .  Calculating...
# (pid=279409) Extracting from bandfile number  189 .  Calculating...
# (pid=279405) Extracting from bandfile number  1310 .  Calculating...
# (pid=279410) Extracting from bandfile number  2105 .  Calculating...
# (pid=279402) Extracting from bandfile number  1785 .  Calculating...
# (pid=279398) Extracting from bandfile number  345 .  Calculating...
# (pid=279402) Extracting from bandfile number  1786 .  Calculating...
# (pid=279410) Extracting from bandfile number  2106 .  Calculating...
# (pid=279396) Extracting from bandfile number  983 .  Calculating...
# (pid=279404) Extracting from bandfile number  1470 .  Calculating...
# (pid=279406) Extracting from bandfile number  1946 .  Calculating...
# (pid=279402) Extracting from bandfile number  1787 .  Calculating...
# (pid=279397) Extracting from bandfile number  33 .  Calculating...
# (pid=279398) Extracting from bandfile number  346 .  Calculating...
# (pid=279408) Extracting from bandfile number  508 .  Calculating...
# (pid=279399) Extracting from bandfile number  661 .  Calculating...
# (pid=279404) Extracting from bandfile number  1471 .  Calculating...
# (pid=279408) Extracting from bandfile number  509 .  Calculating...
# (pid=279404) Extracting from bandfile number  1472 .  Calculating...
# (pid=279399) Extracting from bandfile number  662 .  Calculating...
# (pid=279404) Extracting from bandfile number  1473 .  Calculating...
# (pid=279402) Extracting from bandfile number  1788 .  Calculating...
# (pid=279409) Extracting from bandfile number  190 .  Calculating...
# (pid=279401) Extracting from bandfile number  2266 .  Calculating...
# (pid=279405) Extracting from bandfile number  1311 .  Calculating...
# (pid=279400) Extracting from bandfile number  829 .  Calculating...
# (pid=279397) Extracting from bandfile number  34 .  Calculating...
# (pid=279401) Extracting from bandfile number  2267 .  Calculating...
# (pid=279407) Extracting from bandfile number  1626 .  Calculating...
# (pid=279403) Extracting from bandfile number  1148 .  Calculating...
# (pid=279409) Extracting from bandfile number  191 .  Calculating...
# (pid=279410) Extracting from bandfile number  2107 .  Calculating...
# (pid=279401) Extracting from bandfile number  2268 .  Calculating...
# (pid=279405) Extracting from bandfile number  1312 .  Calculating...
# (pid=279401) Extracting from bandfile number  2269 .  Calculating...
# (pid=279407) Extracting from bandfile number  1627 .  Calculating...
# (pid=279398) Extracting from bandfile number  347 .  Calculating...
# (pid=279400) Extracting from bandfile number  830 .  Calculating...
# (pid=279410) Extracting from bandfile number  2108 .  Calculating...
# (pid=279399) Extracting from bandfile number  663 .  Calculating...
# (pid=279396) Extracting from bandfile number  984 .  Calculating...
# (pid=279399) Extracting from bandfile number  664 .  Calculating...
# (pid=279397) Extracting from bandfile number  35 .  Calculating...
# (pid=279403) Extracting from bandfile number  1149 .  Calculating...
# (pid=279406) Extracting from bandfile number  1947 .  Calculating...
# (pid=279403) Extracting from bandfile number  1150 .  Calculating...
# (pid=279403) Extracting from bandfile number  1151 .  Calculating...
# (pid=279401) Extracting from bandfile number  2270 .  Calculating...
# (pid=279409) Extracting from bandfile number  192 .  Calculating...
# (pid=279409) Extracting from bandfile number  193 .  Calculating...
# (pid=279408) Extracting from bandfile number  510 .  Calculating...
# (pid=279410) Extracting from bandfile number  2109 .  Calculating...
# (pid=279409) Extracting from bandfile number  194 .  Calculating...
# (pid=279405) Extracting from bandfile number  1313 .  Calculating...
# (pid=279404) Extracting from bandfile number  1474 .  Calculating...
# (pid=279408) Extracting from bandfile number  511 .  Calculating...
# (pid=279398) Extracting from bandfile number  348 .  Calculating...
# (pid=279406) Extracting from bandfile number  1948 .  Calculating...
# (pid=279398) Extracting from bandfile number  349 .  Calculating...
# (pid=279398) Extracting from bandfile number  350 .  Calculating...
# (pid=279410) Extracting from bandfile number  2110 .  Calculating...
# (pid=279402) Extracting from bandfile number  1789 .  Calculating...
# (pid=279406) Extracting from bandfile number  1949 .  Calculating...
# (pid=279396) Extracting from bandfile number  985 .  Calculating...
# (pid=279401) Extracting from bandfile number  2271 .  Calculating...
# (pid=279403) Extracting from bandfile number  1152 .  Calculating...
# (pid=279402) Extracting from bandfile number  1790 .  Calculating...
# (pid=279407) Extracting from bandfile number  1628 .  Calculating...
# (pid=279396) Extracting from bandfile number  986 .  Calculating...
# (pid=279403) Extracting from bandfile number  1153 .  Calculating...
# (pid=279407) Extracting from bandfile number  1629 .  Calculating...
# (pid=279400) Extracting from bandfile number  831 .  Calculating...
# (pid=279409) Extracting from bandfile number  195 .  Calculating...
# (pid=279408) Extracting from bandfile number  512 .  Calculating...
# (pid=279409) Extracting from bandfile number  196 .  Calculating...
# (pid=279408) Extracting from bandfile number  513 .  Calculating...
# (pid=279407) Extracting from bandfile number  1630 .  Calculating...
# (pid=279397) Extracting from bandfile number  36 .  Calculating...
# (pid=279399) Extracting from bandfile number  665 .  Calculating...
# (pid=279404) Extracting from bandfile number  1475 .  Calculating...
# (pid=279396) Extracting from bandfile number  987 .  Calculating...
# (pid=279406) Extracting from bandfile number  1950 .  Calculating...
# (pid=279405) Extracting from bandfile number  1314 .  Calculating...
# (pid=279396) Extracting from bandfile number  988 .  Calculating...
# (pid=279406) Extracting from bandfile number  1951 .  Calculating...
# (pid=279409) Extracting from bandfile number  197 .  Calculating...
# (pid=279398) Extracting from bandfile number  351 .  Calculating...
# (pid=279408) Extracting from bandfile number  514 .  Calculating...
# (pid=279400) Extracting from bandfile number  832 .  Calculating...
# (pid=279401) Extracting from bandfile number  2272 .  Calculating...
# (pid=279400) Extracting from bandfile number  833 .  Calculating...
# (pid=279401) Extracting from bandfile number  2273 .  Calculating...
# (pid=279403) Extracting from bandfile number  1154 .  Calculating...
# (pid=279403) Extracting from bandfile number  1155 .  Calculating...
# (pid=279410) Extracting from bandfile number  2111 .  Calculating...
# (pid=279410) Extracting from bandfile number  2112 .  Calculating...
# (pid=279397) Extracting from bandfile number  37 .  Calculating...
# (pid=279410) Extracting from bandfile number  2113 .  Calculating...
# (pid=279402) Extracting from bandfile number  1791 .  Calculating...
# (pid=279406) Extracting from bandfile number  1952 .  Calculating...
# (pid=279401) Extracting from bandfile number  2274 .  Calculating...
# (pid=279399) Extracting from bandfile number  666 .  Calculating...
# (pid=279396) Extracting from bandfile number  989 .  Calculating...
# (pid=279404) Extracting from bandfile number  1476 .  Calculating...
# (pid=279399) Extracting from bandfile number  667 .  Calculating...
# (pid=279405) Extracting from bandfile number  1315 .  Calculating...
# (pid=279404) Extracting from bandfile number  1477 .  Calculating...
# (pid=279399) Extracting from bandfile number  668 .  Calculating...
# (pid=279396) Extracting from bandfile number  990 .  Calculating...
# (pid=279397) Extracting from bandfile number  38 .  Calculating...
# (pid=279407) Extracting from bandfile number  1631 .  Calculating...
# (pid=279398) Extracting from bandfile number  352 .  Calculating...
# (pid=279399) Extracting from bandfile number  669 .  Calculating...
# (pid=279396) Extracting from bandfile number  991 .  Calculating...
# (pid=279409) Extracting from bandfile number  198 .  Calculating...
# (pid=279400) Extracting from bandfile number  834 .  Calculating...
# (pid=279400) Extracting from bandfile number  835 .  Calculating...
# (pid=279408) Extracting from bandfile number  515 .  Calculating...
# (pid=279406) Extracting from bandfile number  1953 .  Calculating...
# (pid=279400) Extracting from bandfile number  836 .  Calculating...
# (pid=279402) Extracting from bandfile number  1792 .  Calculating...
# (pid=279408) Extracting from bandfile number  516 .  Calculating...
# (pid=279400) Extracting from bandfile number  837 .  Calculating...
# (pid=279410) Extracting from bandfile number  2114 .  Calculating...
# (pid=279400) Extracting from bandfile number  838 .  Calculating...
# (pid=279400) Extracting from bandfile number  839 .  Calculating...
# (pid=279403) Extracting from bandfile number  1156 .  Calculating...
# (pid=279404) Extracting from bandfile number  1478 .  Calculating...
# (pid=279401) Extracting from bandfile number  2275 .  Calculating...
# (pid=279399) Extracting from bandfile number  670 .  Calculating...
# (pid=279410) Extracting from bandfile number  2115 .  Calculating...
# (pid=279396) Extracting from bandfile number  992 .  Calculating...
# (pid=279398) Extracting from bandfile number  354 .  Calculating...
# (pid=279407) Extracting from bandfile number  1632 .  Calculating...
# (pid=279405) Extracting from bandfile number  1316 .  Calculating...
# (pid=279407) Extracting from bandfile number  1633 .  Calculating...
# (pid=279409) Extracting from bandfile number  199 .  Calculating...
# (pid=279402) Extracting from bandfile number  1793 .  Calculating...
# (pid=279407) Extracting from bandfile number  1634 .  Calculating...
# (pid=279400) Extracting from bandfile number  840 .  Calculating...
# (pid=279397) Extracting from bandfile number  39 .  Calculating...
# (pid=279403) Extracting from bandfile number  1157 .  Calculating...
# (pid=279406) Extracting from bandfile number  1954 .  Calculating...
# (pid=279406) Extracting from bandfile number  1955 .  Calculating...
# (pid=279408) Extracting from bandfile number  517 .  Calculating...
# (pid=279408) Extracting from bandfile number  518 .  Calculating...
# (pid=279410) Extracting from bandfile number  2116 .  Calculating...
# (pid=279398) Extracting from bandfile number  355 .  Calculating...
# (pid=279400) Extracting from bandfile number  841 .  Calculating...
# (pid=279397) Extracting from bandfile number  40 .  Calculating...
# (pid=279398) Extracting from bandfile number  356 .  Calculating...
# (pid=279404) Extracting from bandfile number  1479 .  Calculating...
# (pid=279398) Extracting from bandfile number  357 .  Calculating...
# (pid=279399) Extracting from bandfile number  671 .  Calculating...
# (pid=279410) Extracting from bandfile number  2117 .  Calculating...
# (pid=279396) Extracting from bandfile number  993 .  Calculating...
# (pid=279401) Extracting from bandfile number  2276 .  Calculating...
# (pid=279401) Extracting from bandfile number  2277 .  Calculating...
# (pid=279405) Extracting from bandfile number  1317 .  Calculating...
# (pid=279397) Extracting from bandfile number  41 .  Calculating...
# (pid=279409) Extracting from bandfile number  200 .  Calculating...
# (pid=279396) Extracting from bandfile number  994 .  Calculating...
# (pid=279408) Extracting from bandfile number  519 .  Calculating...
# (pid=279402) Extracting from bandfile number  1794 .  Calculating...
# (pid=279408) Extracting from bandfile number  520 .  Calculating...
# (pid=279398) Extracting from bandfile number  358 .  Calculating...
# (pid=279403) Extracting from bandfile number  1158 .  Calculating...
# (pid=279402) Extracting from bandfile number  1795 .  Calculating...
# (pid=279401) Extracting from bandfile number  2278 .  Calculating...
# (pid=279399) Extracting from bandfile number  672 .  Calculating...
# (pid=279406) Extracting from bandfile number  1956 .  Calculating...
# (pid=279410) Extracting from bandfile number  2118 .  Calculating...
# (pid=279398) Extracting from bandfile number  359 .  Calculating...
# (pid=279403) Extracting from bandfile number  1159 .  Calculating...
# (pid=279400) Extracting from bandfile number  842 .  Calculating...
# (pid=279407) Extracting from bandfile number  1635 .  Calculating...
# (pid=279396) Extracting from bandfile number  995 .  Calculating...
# (pid=279400) Extracting from bandfile number  843 .  Calculating...
# (pid=279404) Extracting from bandfile number  1480 .  Calculating...
# (pid=279400) Extracting from bandfile number  844 .  Calculating...
# (pid=279397) Extracting from bandfile number  42 .  Calculating...
# (pid=279409) Extracting from bandfile number  201 .  Calculating...
# (pid=279399) Extracting from bandfile number  673 .  Calculating...
# (pid=279407) Extracting from bandfile number  1636 .  Calculating...
# (pid=279407) Extracting from bandfile number  1637 .  Calculating...
# (pid=279409) Extracting from bandfile number  202 .  Calculating...
# (pid=279402) Extracting from bandfile number  1796 .  Calculating...
# (pid=279402) Extracting from bandfile number  1797 .  Calculating...
# (pid=279402) Extracting from bandfile number  1798 .  Calculating...
# (pid=279398) Extracting from bandfile number  360 .  Calculating...
# (pid=279401) Extracting from bandfile number  2279 .  Calculating...
# (pid=279406) Extracting from bandfile number  1957 .  Calculating...
# (pid=279408) Extracting from bandfile number  521 .  Calculating...
# (pid=279410) Extracting from bandfile number  2119 .  Calculating...
# (pid=279405) Extracting from bandfile number  1318 .  Calculating...
# (pid=279401) Extracting from bandfile number  2280 .  Calculating...
# (pid=279399) Extracting from bandfile number  674 .  Calculating...
# (pid=279403) Extracting from bandfile number  1160 .  Calculating...
# (pid=279403) Extracting from bandfile number  1161 .  Calculating...
# (pid=279407) Extracting from bandfile number  1638 .  Calculating...
# (pid=279398) Extracting from bandfile number  361 .  Calculating...
# (pid=279403) Extracting from bandfile number  1162 .  Calculating...
# (pid=279404) Extracting from bandfile number  1481 .  Calculating...
# (pid=279404) Extracting from bandfile number  1482 .  Calculating...
# (pid=279396) Extracting from bandfile number  996 .  Calculating...
# (pid=279403) Extracting from bandfile number  1163 .  Calculating...
# (pid=279402) Extracting from bandfile number  1799 .  Calculating...
# (pid=279397) Extracting from bandfile number  43 .  Calculating...
# (pid=279404) Extracting from bandfile number  1483 .  Calculating...
# (pid=279398) Extracting from bandfile number  362 .  Calculating...
# (pid=279408) Extracting from bandfile number  522 .  Calculating...
# (pid=279406) Extracting from bandfile number  1958 .  Calculating...
# (pid=279403) Extracting from bandfile number  1164 .  Calculating...
# (pid=279400) Extracting from bandfile number  845 .  Calculating...
# (pid=279400) Extracting from bandfile number  846 .  Calculating...
# (pid=279403) Extracting from bandfile number  1165 .  Calculating...
# (pid=279409) Extracting from bandfile number  203 .  Calculating...
# (pid=279398) Extracting from bandfile number  363 .  Calculating...
# (pid=279396) Extracting from bandfile number  997 .  Calculating...
# (pid=279405) Extracting from bandfile number  1319 .  Calculating...
# (pid=279409) Extracting from bandfile number  204 .  Calculating...
# (pid=279405) Extracting from bandfile number  1320 .  Calculating...
# (pid=279410) Extracting from bandfile number  2120 .  Calculating...
# (pid=279401) Extracting from bandfile number  2281 .  Calculating...
# (pid=279399) Extracting from bandfile number  675 .  Calculating...
# (pid=279400) Extracting from bandfile number  847 .  Calculating...
# (pid=279402) Extracting from bandfile number  1800 .  Calculating...
# (pid=279398) Extracting from bandfile number  364 .  Calculating...
# (pid=279402) Extracting from bandfile number  1801 .  Calculating...
# (pid=279398) Extracting from bandfile number  365 .  Calculating...
# (pid=279407) Extracting from bandfile number  1639 .  Calculating...
# (pid=279396) Extracting from bandfile number  998 .  Calculating...
# (pid=279406) Extracting from bandfile number  1959 .  Calculating...
# (pid=279402) Extracting from bandfile number  1802 .  Calculating...
# (pid=279406) Extracting from bandfile number  1960 .  Calculating...
# (pid=279408) Extracting from bandfile number  523 .  Calculating...
# (pid=279404) Extracting from bandfile number  1484 .  Calculating...
# (pid=279403) Extracting from bandfile number  1166 .  Calculating...
# (pid=279401) Extracting from bandfile number  2282 .  Calculating...
# (pid=279397) Extracting from bandfile number  44 .  Calculating...
# (pid=279398) Extracting from bandfile number  366 .  Calculating...
# (pid=279405) Extracting from bandfile number  1321 .  Calculating...
# (pid=279396) Extracting from bandfile number  999 .  Calculating...
# (pid=279405) Extracting from bandfile number  1322 .  Calculating...
# (pid=279401) Extracting from bandfile number  2283 .  Calculating...
# (pid=279408) Extracting from bandfile number  524 .  Calculating...
# (pid=279409) Extracting from bandfile number  205 .  Calculating...
# (pid=279399) Extracting from bandfile number  676 .  Calculating...
# (pid=279399) Extracting from bandfile number  677 .  Calculating...
# (pid=279400) Extracting from bandfile number  848 .  Calculating...
# (pid=279410) Extracting from bandfile number  2121 .  Calculating...
# (pid=279402) Extracting from bandfile number  1803 .  Calculating...
# (pid=279400) Extracting from bandfile number  849 .  Calculating...
# (pid=279410) Extracting from bandfile number  2122 .  Calculating...
# (pid=279407) Extracting from bandfile number  1640 .  Calculating...
# (pid=279410) Extracting from bandfile number  2123 .  Calculating...
# (pid=279402) Extracting from bandfile number  1804 .  Calculating...
# (pid=279406) Extracting from bandfile number  1961 .  Calculating...
# (pid=279406) Extracting from bandfile number  1962 .  Calculating...
# (pid=279397) Extracting from bandfile number  45 .  Calculating...
# (pid=279400) Extracting from bandfile number  850 .  Calculating...
# (pid=279405) Extracting from bandfile number  1323 .  Calculating...
# (pid=279406) Extracting from bandfile number  1963 .  Calculating...
# (pid=279402) Extracting from bandfile number  1805 .  Calculating...
# (pid=279403) Extracting from bandfile number  1167 .  Calculating...
# (pid=279402) Extracting from bandfile number  1806 .  Calculating...
# (pid=279405) Extracting from bandfile number  1324 .  Calculating...
# (pid=279406) Extracting from bandfile number  1964 .  Calculating...
# (pid=279402) Extracting from bandfile number  1807 .  Calculating...
# (pid=279398) Extracting from bandfile number  367 .  Calculating...
# (pid=279403) Extracting from bandfile number  1168 .  Calculating...
# (pid=279406) Extracting from bandfile number  1965 .  Calculating...
# (pid=279399) Extracting from bandfile number  678 .  Calculating...
# (pid=279402) Extracting from bandfile number  1808 .  Calculating...
# (pid=279399) Extracting from bandfile number  679 .  Calculating...
# (pid=279404) Extracting from bandfile number  1485 .  Calculating...
# (pid=279401) Extracting from bandfile number  2284 .  Calculating...
# (pid=279408) Extracting from bandfile number  525 .  Calculating...
# (pid=279401) Extracting from bandfile number  2285 .  Calculating...
# (pid=279406) Extracting from bandfile number  1966 .  Calculating...
# (pid=279398) Extracting from bandfile number  368 .  Calculating...
# (pid=279396) Extracting from bandfile number  1000 .  Calculating...
# (pid=279398) Extracting from bandfile number  369 .  Calculating...
# (pid=279409) Extracting from bandfile number  206 .  Calculating...
# (pid=279406) Extracting from bandfile number  1967 .  Calculating...
# (pid=279410) Extracting from bandfile number  2124 .  Calculating...
# (pid=279399) Extracting from bandfile number  680 .  Calculating...
# (pid=279409) Extracting from bandfile number  207 .  Calculating...
# (pid=279400) Extracting from bandfile number  851 .  Calculating...
# (pid=279397) Extracting from bandfile number  46 .  Calculating...
# (pid=279399) Extracting from bandfile number  681 .  Calculating...
# (pid=279399) Extracting from bandfile number  682 .  Calculating...
# (pid=279407) Extracting from bandfile number  1641 .  Calculating...
# (pid=279406) Extracting from bandfile number  1968 .  Calculating...
# (pid=279399) Extracting from bandfile number  683 .  Calculating...
# (pid=279401) Extracting from bandfile number  2286 .  Calculating...
# (pid=279409) Extracting from bandfile number  208 .  Calculating...
# (pid=279402) Extracting from bandfile number  1809 .  Calculating...
# (pid=279406) Extracting from bandfile number  1969 .  Calculating...
# (pid=279405) Extracting from bandfile number  1325 .  Calculating...
# (pid=279402) Extracting from bandfile number  1810 .  Calculating...
# (pid=279402) Extracting from bandfile number  1811 .  Calculating...
# (pid=279401) Extracting from bandfile number  2287 .  Calculating...
# (pid=279398) Extracting from bandfile number  370 .  Calculating...
# (pid=279398) Extracting from bandfile number  371 .  Calculating...
# (pid=279400) Extracting from bandfile number  852 .  Calculating...
# (pid=279396) Extracting from bandfile number  1001 .  Calculating...
# (pid=279403) Extracting from bandfile number  1169 .  Calculating...
# (pid=279404) Extracting from bandfile number  1486 .  Calculating...
# ...
# (pid=279401) Extracting from bandfile number  2385 .  Calculating...
# (pid=279404) Extracting from bandfile number  1577 .  Calculating...
# (pid=279408) Extracting from bandfile number  634 .  Calculating...
# (pid=279409) Extracting from bandfile number  300 .  Calculating...
# (pid=279398) Extracting from bandfile number  455 .  Calculating...
# (pid=279396) Extracting from bandfile number  1099 .  Calculating...
# (pid=279396) Extracting from bandfile number  1100 .  Calculating...
# (pid=279402) Extracting from bandfile number  1909 .  Calculating...
# (pid=279396) Extracting from bandfile number  1101 .  Calculating...
# (pid=279401) Extracting from bandfile number  2386 .  Calculating...
# (pid=279399) Extracting from bandfile number  773 .  Calculating...
# (pid=279407) Extracting from bandfile number  1748 .  Calculating...
# (pid=279408) Extracting from bandfile number  635 .  Calculating...
# (pid=279410) Extracting from bandfile number  2238 .  Calculating...
# (pid=279400) Extracting from bandfile number  951 .  Calculating...
# (pid=279410) Extracting from bandfile number  2239 .  Calculating...
# (pid=279398) Extracting from bandfile number  456 .  Calculating...
# (pid=279405) Extracting from bandfile number  1432 .  Calculating...
# (pid=279407) Extracting from bandfile number  1749 .  Calculating...
# (pid=279397) Extracting from bandfile number  145 .  Calculating...
# (pid=279399) Extracting from bandfile number  774 .  Calculating...
# (pid=279400) Extracting from bandfile number  952 .  Calculating...
# (pid=279407) Extracting from bandfile number  1750 .  Calculating...
# (pid=279399) Extracting from bandfile number  775 .  Calculating...
# (pid=279397) Extracting from bandfile number  146 .  Calculating...
# (pid=279400) Extracting from bandfile number  953 .  Calculating...
# (pid=279401) Extracting from bandfile number  2387 .  Calculating...
# (pid=279402) Extracting from bandfile number  1910 .  Calculating...
# (pid=279402) Extracting from bandfile number  1911 .  Calculating...
# (pid=279407) Extracting from bandfile number  1751 .  Calculating...
# (pid=279399) Extracting from bandfile number  776 .  Calculating...
# (pid=279397) Extracting from bandfile number  147 .  Calculating...
# (pid=279397) Extracting from bandfile number  148 .  Calculating...
# (pid=279407) Extracting from bandfile number  1752 .  Calculating...
# (pid=279397) Extracting from bandfile number  149 .  Calculating...
# (pid=279404) Extracting from bandfile number  1578 .  Calculating...
# (pid=279405) Extracting from bandfile number  1433 .  Calculating...
# (pid=279399) Extracting from bandfile number  777 .  Calculating...
# (pid=279409) Extracting from bandfile number  301 .  Calculating...
# (pid=279401) Extracting from bandfile number  2388 .  Calculating...
# (pid=279409) Extracting from bandfile number  302 .  Calculating...
# (pid=279406) Extracting from bandfile number  2068 .  Calculating...
# (pid=279403) Extracting from bandfile number  1275 .  Calculating...
# (pid=279400) Extracting from bandfile number  954 .  Calculating...
# (pid=279405) Extracting from bandfile number  1434 .  Calculating...
# (pid=279401) Extracting from bandfile number  2389 .  Calculating...
# (pid=279408) Extracting from bandfile number  636 .  Calculating...
# (pid=279396) Extracting from bandfile number  1102 .  Calculating...
# (pid=279401) Extracting from bandfile number  2390 .  Calculating...
# (pid=279410) Extracting from bandfile number  2240 .  Calculating...
# (pid=279399) Extracting from bandfile number  778 .  Calculating...
# (pid=279410) Done with files 2081 - 2240 .
# (pid=279403) Extracting from bandfile number  1276 .  Calculating...
# (pid=279401) Extracting from bandfile number  2391 .  Calculating...
# (pid=279407) Extracting from bandfile number  1753 .  Calculating...
# (pid=279405) Extracting from bandfile number  1435 .  Calculating...
# (pid=279398) Extracting from bandfile number  457 .  Calculating...
# (pid=279399) Extracting from bandfile number  779 .  Calculating...
# (pid=279402) Extracting from bandfile number  1912 .  Calculating...
# (pid=279409) Extracting from bandfile number  303 .  Calculating...
# (pid=279403) Extracting from bandfile number  1277 .  Calculating...
# (pid=279403) Extracting from bandfile number  1278 .  Calculating...
# (pid=279396) Extracting from bandfile number  1103 .  Calculating...
# (pid=279400) Extracting from bandfile number  955 .  Calculating...
# (pid=279400) Extracting from bandfile number  956 .  Calculating...
# (pid=279404) Extracting from bandfile number  1579 .  Calculating...
# (pid=279400) Extracting from bandfile number  957 .  Calculating...
# (pid=279400) Extracting from bandfile number  958 .  Calculating...
# (pid=279406) Extracting from bandfile number  2069 .  Calculating...
# (pid=279398) Extracting from bandfile number  458 .  Calculating...
# (pid=279407) Extracting from bandfile number  1754 .  Calculating...
# (pid=279401) Extracting from bandfile number  2392 .  Calculating...
# (pid=279398) Extracting from bandfile number  459 .  Calculating...
# (pid=279402) Extracting from bandfile number  1913 .  Calculating...
# (pid=279401) Extracting from bandfile number  2393 .  Calculating...
# (pid=279397) Extracting from bandfile number  150 .  Calculating...
# (pid=279404) Extracting from bandfile number  1580 .  Calculating...
# (pid=279401) Extracting from bandfile number  2394 .  Calculating...
# (pid=279409) Extracting from bandfile number  304 .  Calculating...
# (pid=279408) Extracting from bandfile number  637 .  Calculating...
# (pid=279406) Extracting from bandfile number  2070 .  Calculating...
# (pid=279397) Extracting from bandfile number  151 .  Calculating...
# (pid=279401) Extracting from bandfile number  2395 .  Calculating...
# (pid=279408) Extracting from bandfile number  638 .  Calculating...
# (pid=279408) Extracting from bandfile number  639 .  Calculating...
# (pid=279402) Extracting from bandfile number  1914 .  Calculating...
# (pid=279408) Extracting from bandfile number  640 .  Calculating...
# (pid=279400) Extracting from bandfile number  959 .  Calculating...
# (pid=279405) Extracting from bandfile number  1436 .  Calculating...
# (pid=279405) Extracting from bandfile number  1437 .  Calculating...
# (pid=279405) Extracting from bandfile number  1438 .  Calculating...
# (pid=279399) Extracting from bandfile number  780 .  Calculating...
# (pid=279398) Extracting from bandfile number  460 .  Calculating...
# (pid=279407) Extracting from bandfile number  1755 .  Calculating...
# (pid=279408) Done with files 481 - 640 .
# (pid=279403) Extracting from bandfile number  1279 .  Calculating...
# (pid=279409) Extracting from bandfile number  305 .  Calculating...
# (pid=279397) Extracting from bandfile number  152 .  Calculating...
# (pid=279409) Extracting from bandfile number  306 .  Calculating...
# (pid=279396) Extracting from bandfile number  1104 .  Calculating...
# (pid=279407) Extracting from bandfile number  1756 .  Calculating...
# (pid=279406) Extracting from bandfile number  2071 .  Calculating...
# (pid=279400) Extracting from bandfile number  960 .  Calculating...
# (pid=279405) Extracting from bandfile number  1439 .  Calculating...
# (pid=279409) Extracting from bandfile number  307 .  Calculating...
# (pid=279406) Extracting from bandfile number  2072 .  Calculating...
# (pid=279401) Extracting from bandfile number  2396 .  Calculating...
# (pid=279400) Done with files 801 - 960 .
# (pid=279406) Extracting from bandfile number  2073 .  Calculating...
# (pid=279401) Extracting from bandfile number  2397 .  Calculating...
# (pid=279396) Extracting from bandfile number  1105 .  Calculating...
# (pid=279404) Extracting from bandfile number  1581 .  Calculating...
# (pid=279401) Extracting from bandfile number  2398 .  Calculating...
# (pid=279396) Extracting from bandfile number  1106 .  Calculating...
# (pid=279399) Extracting from bandfile number  781 .  Calculating...
# (pid=279403) Extracting from bandfile number  1280 .  Calculating...
# (pid=279407) Extracting from bandfile number  1757 .  Calculating...
# (pid=279402) Extracting from bandfile number  1915 .  Calculating...
# (pid=279406) Extracting from bandfile number  2074 .  Calculating...
# (pid=279407) Extracting from bandfile number  1758 .  Calculating...
# (pid=279402) Extracting from bandfile number  1916 .  Calculating...
# (pid=279397) Extracting from bandfile number  153 .  Calculating...
# (pid=279407) Extracting from bandfile number  1759 .  Calculating...
# (pid=279404) Extracting from bandfile number  1582 .  Calculating...
# (pid=279399) Extracting from bandfile number  782 .  Calculating...
# (pid=279409) Extracting from bandfile number  309 .  Calculating...
# (pid=279401) Extracting from bandfile number  2399 .  Calculating...
# (pid=279397) Extracting from bandfile number  154 .  Calculating...
# (pid=279398) Extracting from bandfile number  461 .  Calculating...
# (pid=279397) Extracting from bandfile number  155 .  Calculating...
# (pid=279399) Extracting from bandfile number  783 .  Calculating...
# (pid=279405) Extracting from bandfile number  1440 .  Calculating...
# (pid=279405) Done with files 1281 - 1440 .
# (pid=279407) Extracting from bandfile number  1760 .  Calculating...
# (pid=279396) Extracting from bandfile number  1107 .  Calculating...
# (pid=279402) Extracting from bandfile number  1917 .  Calculating...
# (pid=279407) Done with files 1601 - 1760 .
# (pid=279406) Extracting from bandfile number  2075 .  Calculating...
# (pid=279403) Done with files 1121 - 1280 .
# (pid=279404) Extracting from bandfile number  1583 .  Calculating...
# (pid=279406) Extracting from bandfile number  2076 .  Calculating...
# (pid=279406) Extracting from bandfile number  2077 .  Calculating...
# (pid=279397) Extracting from bandfile number  156 .  Calculating...
# (pid=279397) Extracting from bandfile number  157 .  Calculating...
# (pid=279399) Extracting from bandfile number  784 .  Calculating...
# (pid=279399) Extracting from bandfile number  785 .  Calculating...
# (pid=279402) Extracting from bandfile number  1918 .  Calculating...
# (pid=279398) Extracting from bandfile number  462 .  Calculating...
# (pid=279402) Extracting from bandfile number  1919 .  Calculating...
# (pid=279406) Extracting from bandfile number  2078 .  Calculating...
# (pid=279401) Extracting from bandfile number  2400 .  Calculating...
# (pid=279406) Extracting from bandfile number  2079 .  Calculating...
# (pid=279398) Extracting from bandfile number  463 .  Calculating...
# (pid=279409) Extracting from bandfile number  310 .  Calculating...
# (pid=279396) Extracting from bandfile number  1108 .  Calculating...
# (pid=279406) Extracting from bandfile number  2080 .  Calculating...
# (pid=279396) Extracting from bandfile number  1109 .  Calculating...
# (pid=279399) Extracting from bandfile number  786 .  Calculating...
# (pid=279404) Extracting from bandfile number  1584 .  Calculating...
# (pid=279397) Extracting from bandfile number  158 .  Calculating...
# (pid=279399) Extracting from bandfile number  787 .  Calculating...
# (pid=279399) Extracting from bandfile number  788 .  Calculating...
# (pid=279399) Extracting from bandfile number  789 .  Calculating...
# (pid=279401) Done with files 2241 - 2400 .
# (pid=279404) Extracting from bandfile number  1585 .  Calculating...
# (pid=279404) Extracting from bandfile number  1586 .  Calculating...
# (pid=279402) Extracting from bandfile number  1920 .  Calculating...
# (pid=279398) Extracting from bandfile number  465 .  Calculating...
# (pid=279406) Done with files 1921 - 2080 .
# (pid=279396) Extracting from bandfile number  1110 .  Calculating...
# (pid=279409) Extracting from bandfile number  311 .  Calculating...
# (pid=279404) Extracting from bandfile number  1587 .  Calculating...
# (pid=279397) Extracting from bandfile number  159 .  Calculating...
# (pid=279398) Extracting from bandfile number  466 .  Calculating...
# (pid=279398) Extracting from bandfile number  467 .  Calculating...
# (pid=279397) Extracting from bandfile number  160 .  Calculating...
# (pid=279397) Done with files 1 - 160 .
# (pid=279398) Extracting from bandfile number  468 .  Calculating...
# (pid=279398) Extracting from bandfile number  469 .  Calculating...
# (pid=279402) Done with files 1761 - 1920 .
# (pid=279399) Extracting from bandfile number  790 .  Calculating...
# (pid=279409) Extracting from bandfile number  312 .  Calculating...
# (pid=279404) Extracting from bandfile number  1588 .  Calculating...
# (pid=279399) Extracting from bandfile number  791 .  Calculating...
# (pid=279396) Extracting from bandfile number  1111 .  Calculating...
# (pid=279396) Extracting from bandfile number  1112 .  Calculating...
# (pid=279398) Extracting from bandfile number  470 .  Calculating...
# (pid=279409) Extracting from bandfile number  313 .  Calculating...
# (pid=279404) Extracting from bandfile number  1589 .  Calculating...
# (pid=279404) Extracting from bandfile number  1590 .  Calculating...
# (pid=279404) Extracting from bandfile number  1591 .  Calculating...
# (pid=279398) Extracting from bandfile number  471 .  Calculating...
# (pid=279396) Extracting from bandfile number  1113 .  Calculating...
# (pid=279398) Extracting from bandfile number  472 .  Calculating...
# (pid=279399) Extracting from bandfile number  792 .  Calculating...
# (pid=279399) Extracting from bandfile number  793 .  Calculating...
# (pid=279409) Extracting from bandfile number  314 .  Calculating...
# (pid=279398) Extracting from bandfile number  473 .  Calculating...
# (pid=279396) Extracting from bandfile number  1114 .  Calculating...
# (pid=279399) Extracting from bandfile number  794 .  Calculating...
# (pid=279404) Extracting from bandfile number  1592 .  Calculating...
# (pid=279409) Extracting from bandfile number  315 .  Calculating...
# (pid=279409) Extracting from bandfile number  316 .  Calculating...
# (pid=279399) Extracting from bandfile number  795 .  Calculating...
# (pid=279399) Extracting from bandfile number  796 .  Calculating...
# (pid=279396) Extracting from bandfile number  1115 .  Calculating...
# (pid=279409) Extracting from bandfile number  317 .  Calculating...
# (pid=279399) Extracting from bandfile number  797 .  Calculating...
# (pid=279399) Extracting from bandfile number  798 .  Calculating...
# (pid=279404) Extracting from bandfile number  1593 .  Calculating...
# (pid=279404) Extracting from bandfile number  1594 .  Calculating...
# (pid=279404) Extracting from bandfile number  1595 .  Calculating...
# (pid=279398) Extracting from bandfile number  474 .  Calculating...
# (pid=279409) Extracting from bandfile number  318 .  Calculating...
# (pid=279396) Extracting from bandfile number  1116 .  Calculating...
# (pid=279398) Extracting from bandfile number  475 .  Calculating...
# (pid=279404) Extracting from bandfile number  1596 .  Calculating...
# (pid=279398) Extracting from bandfile number  476 .  Calculating...
# (pid=279396) Extracting from bandfile number  1117 .  Calculating...
# (pid=279399) Extracting from bandfile number  799 .  Calculating...
# (pid=279409) Extracting from bandfile number  319 .  Calculating...
# (pid=279409) Extracting from bandfile number  320 .  Calculating...
# (pid=279399) Extracting from bandfile number  800 .  Calculating...
# (pid=279404) Extracting from bandfile number  1597 .  Calculating...
# (pid=279409) Done with files 161 - 320 .
# (pid=279404) Extracting from bandfile number  1598 .  Calculating...
# (pid=279396) Extracting from bandfile number  1118 .  Calculating...
# (pid=279396) Extracting from bandfile number  1119 .  Calculating...
# (pid=279396) Extracting from bandfile number  1120 .  Calculating...
# (pid=279404) Extracting from bandfile number  1599 .  Calculating...
# (pid=279404) Extracting from bandfile number  1600 .  Calculating...
# (pid=279404) Done with files 1441 - 1600 .
# (pid=279396) Done with files 961 - 1120 .
# (pid=279399) Done with files 641 - 800 .
# (pid=279398) Extracting from bandfile number  477 .  Calculating...
# (pid=279398) Extracting from bandfile number  478 .  Calculating...
# (pid=279398) Extracting from bandfile number  479 .  Calculating...
# (pid=279398) Extracting from bandfile number  480 .  Calculating...
# (pid=279398) Done with files 321 - 480 .

# %%
# test set
list_of_file_numbers = []
for k in range(num_cpus):
    list_of_file_numbers.append(list(range(1 +k*40,40+1 +k*40)))
object_ids = []

# Parallel forcycle:
for core in range(num_cpus): # get the object ids into a list
    object_ids.append( iterate_thru_all.remote("test",list_of_file_numbers[core],"  Relaxation step number", "  lattice_vector ", "            atom", "       atom_frac", 
                 "ESTIMATED overall HOMO-LUMO gap:", "  | Total energy                  :", "  Final atomic structure:", 
                 "  | Total energy of the DFT / Hartree-Fock s.c.f. calculation      :")
)
dataframes = []
for core in range(num_cpus): # get the actual dataframes from the object ids
    dataframes.append(ray.get(object_ids[core]))
    
    
# concatenate the dataframes
df_general_DATA = pd.concat([dataframes[core][0] for core in range(num_cpus)], ignore_index=True)
df_lattice_vector_relaxation_DATA = pd.concat([dataframes[core][1] for core in range(num_cpus)], ignore_index=True)
df_energy_relaxation_DATA = pd.concat([dataframes[core][2] for core in range(num_cpus)], ignore_index=True)
df_atoms_xyz_relaxation_DATA = pd.concat([dataframes[core][3] for core in range(num_cpus)], ignore_index=True)
df_atoms_frac_xyz_relaxation_DATA = pd.concat([dataframes[core][4] for core in range(num_cpus)], ignore_index=True)

df_general_DATA.to_csv("../test/relaxation/general.csv", index = False)
df_lattice_vector_relaxation_DATA.to_csv("../test/relaxation/lattice_vector_relaxation.csv", index = False)
df_atoms_xyz_relaxation_DATA.to_csv("../test/relaxation/atoms_xyz_relaxation.csv", index = False)
df_atoms_frac_xyz_relaxation_DATA.to_csv("../test/relaxation/atoms_frac_xyz_relaxation.csv", index = False)
df_energy_relaxation_DATA.to_csv("../test/relaxation/energy_relaxation.csv", index = False)


df_lattice_vector_DATA = pd.concat([dataframes[core][5] for core in range(num_cpus)], ignore_index=True)
df_energy_DATA = pd.concat([dataframes[core][6] for core in range(num_cpus)], ignore_index=True)
df_atoms_xyz_DATA = pd.concat([dataframes[core][7] for core in range(num_cpus)], ignore_index=True)
df_atoms_frac_xyz_DATA = pd.concat([dataframes[core][8] for core in range(num_cpus)], ignore_index=True)

df_lattice_vector_DATA.to_csv("../test/final/lattice_vector.csv", index = False)
df_energy_DATA.to_csv("../test/final/energy.csv", index = False)
df_atoms_xyz_DATA.to_csv("../test/final/atoms_xyz.csv", index = False)
df_atoms_frac_xyz_DATA.to_csv("../test/final/atoms_frac_xyz.csv", index = False)
# Out:
# (pid=281159) Extracting from bandfile number  121 .  Calculating...
# (pid=281152) Extracting from bandfile number  481 .  Calculating...
# (pid=281155) Extracting from bandfile number  281 .  Calculating...
# (pid=281162) Extracting from bandfile number  241 .  Calculating...
# (pid=281148) Extracting from bandfile number  81 .  Calculating...
# (pid=281156) Extracting from bandfile number  1 .  Calculating...
# (pid=281149) Extracting from bandfile number  201 .  Calculating...
# (pid=281151) Extracting from bandfile number  321 .  Calculating...
# (pid=281157) Extracting from bandfile number  561 .  Calculating...
# (pid=281150) Extracting from bandfile number  401 .  Calculating...
# (pid=281147) Extracting from bandfile number  441 .  Calculating...
# (pid=281154) Extracting from bandfile number  161 .  Calculating...
# (pid=281153) Extracting from bandfile number  41 .  Calculating...
# (pid=281160) Extracting from bandfile number  361 .  Calculating...
# (pid=281158) Extracting from bandfile number  521 .  Calculating...
# (pid=281149) Extracting from bandfile number  202 .  Calculating...
# (pid=281148) Extracting from bandfile number  82 .  Calculating...
# (pid=281151) Extracting from bandfile number  322 .  Calculating...
# (pid=281157) Extracting from bandfile number  562 .  Calculating...
# (pid=281160) Extracting from bandfile number  362 .  Calculating...
# (pid=281148) Extracting from bandfile number  83 .  Calculating...
# (pid=281149) Extracting from bandfile number  203 .  Calculating...
# (pid=281158) Extracting from bandfile number  522 .  Calculating...
# (pid=281153) Extracting from bandfile number  42 .  Calculating...
# (pid=281160) Extracting from bandfile number  363 .  Calculating...
# (pid=281148) Extracting from bandfile number  84 .  Calculating...
# (pid=281149) Extracting from bandfile number  204 .  Calculating...
# (pid=281148) Extracting from bandfile number  85 .  Calculating...
# (pid=281150) Extracting from bandfile number  402 .  Calculating...
# (pid=281151) Extracting from bandfile number  323 .  Calculating...
# (pid=281150) Extracting from bandfile number  403 .  Calculating...
# (pid=281152) Extracting from bandfile number  482 .  Calculating...
# (pid=281155) Extracting from bandfile number  282 .  Calculating...
# (pid=281155) Extracting from bandfile number  283 .  Calculating...
# (pid=281152) Extracting from bandfile number  483 .  Calculating...
# (pid=281157) Extracting from bandfile number  563 .  Calculating...
# (pid=281162) Extracting from bandfile number  242 .  Calculating...
# (pid=281147) Extracting from bandfile number  442 .  Calculating...
# (pid=281159) Extracting from bandfile number  122 .  Calculating...
# (pid=281159) Extracting from bandfile number  123 .  Calculating...
# (pid=281154) Extracting from bandfile number  162 .  Calculating...
# (pid=281158) Extracting from bandfile number  523 .  Calculating...
# (pid=281156) Extracting from bandfile number  2 .  Calculating...
# (pid=281147) Extracting from bandfile number  443 .  Calculating...
# (pid=281148) Extracting from bandfile number  86 .  Calculating...
# (pid=281156) Extracting from bandfile number  3 .  Calculating...
# (pid=281147) Extracting from bandfile number  444 .  Calculating...
# (pid=281153) Extracting from bandfile number  43 .  Calculating...
# (pid=281153) Extracting from bandfile number  44 .  Calculating...
# (pid=281162) Extracting from bandfile number  243 .  Calculating...
# (pid=281157) Extracting from bandfile number  564 .  Calculating...
# (pid=281147) Extracting from bandfile number  445 .  Calculating...
# (pid=281156) Extracting from bandfile number  4 .  Calculating...
# (pid=281153) Extracting from bandfile number  45 .  Calculating...
# (pid=281162) Extracting from bandfile number  244 .  Calculating...
# (pid=281154) Extracting from bandfile number  163 .  Calculating...
# (pid=281160) Extracting from bandfile number  364 .  Calculating...
# (pid=281162) Extracting from bandfile number  245 .  Calculating...
# (pid=281147) Extracting from bandfile number  446 .  Calculating...
# (pid=281151) Extracting from bandfile number  324 .  Calculating...
# (pid=281160) Extracting from bandfile number  365 .  Calculating...
# (pid=281162) Extracting from bandfile number  246 .  Calculating...
# (pid=281155) Extracting from bandfile number  284 .  Calculating...
# (pid=281152) Extracting from bandfile number  484 .  Calculating...
# (pid=281153) Extracting from bandfile number  46 .  Calculating...
# (pid=281159) Extracting from bandfile number  124 .  Calculating...
# (pid=281153) Extracting from bandfile number  47 .  Calculating...
# (pid=281152) Extracting from bandfile number  485 .  Calculating...
# (pid=281158) Extracting from bandfile number  524 .  Calculating...
# (pid=281149) Extracting from bandfile number  205 .  Calculating...
# (pid=281151) Extracting from bandfile number  325 .  Calculating...
# (pid=281151) Extracting from bandfile number  326 .  Calculating...
# (pid=281150) Extracting from bandfile number  404 .  Calculating...
# (pid=281154) Extracting from bandfile number  164 .  Calculating...
# (pid=281158) Extracting from bandfile number  525 .  Calculating...
# (pid=281150) Extracting from bandfile number  405 .  Calculating...
# (pid=281155) Extracting from bandfile number  285 .  Calculating...
# (pid=281155) Extracting from bandfile number  286 .  Calculating...
# (pid=281156) Extracting from bandfile number  5 .  Calculating...
# (pid=281159) Extracting from bandfile number  125 .  Calculating...
# (pid=281157) Extracting from bandfile number  565 .  Calculating...
# (pid=281148) Extracting from bandfile number  87 .  Calculating...
# (pid=281148) Extracting from bandfile number  88 .  Calculating...
# (pid=281148) Extracting from bandfile number  89 .  Calculating...
# (pid=281157) Extracting from bandfile number  566 .  Calculating...
# (pid=281160) Extracting from bandfile number  366 .  Calculating...
# (pid=281156) Extracting from bandfile number  6 .  Calculating...
# (pid=281153) Extracting from bandfile number  48 .  Calculating...
# (pid=281157) Extracting from bandfile number  567 .  Calculating...
# (pid=281157) Extracting from bandfile number  568 .  Calculating...
# (pid=281156) Extracting from bandfile number  7 .  Calculating...
# (pid=281153) Extracting from bandfile number  49 .  Calculating...
# (pid=281154) Extracting from bandfile number  165 .  Calculating...
# (pid=281156) Extracting from bandfile number  8 .  Calculating...
# (pid=281151) Extracting from bandfile number  327 .  Calculating...
# (pid=281153) Extracting from bandfile number  50 .  Calculating...
# (pid=281147) Extracting from bandfile number  447 .  Calculating...
# (pid=281147) Extracting from bandfile number  448 .  Calculating...
# (pid=281147) Extracting from bandfile number  449 .  Calculating...
# (pid=281149) Extracting from bandfile number  206 .  Calculating...
# (pid=281162) Extracting from bandfile number  247 .  Calculating...
# (pid=281148) Extracting from bandfile number  90 .  Calculating...
# (pid=281157) Extracting from bandfile number  569 .  Calculating...
# (pid=281155) Extracting from bandfile number  287 .  Calculating...
# (pid=281158) Extracting from bandfile number  526 .  Calculating...
# (pid=281147) Extracting from bandfile number  450 .  Calculating...
# (pid=281150) Extracting from bandfile number  406 .  Calculating...
# (pid=281153) Extracting from bandfile number  51 .  Calculating...
# (pid=281157) Extracting from bandfile number  570 .  Calculating...
# (pid=281154) Extracting from bandfile number  166 .  Calculating...
# (pid=281152) Extracting from bandfile number  486 .  Calculating...
# (pid=281162) Extracting from bandfile number  248 .  Calculating...
# (pid=281149) Extracting from bandfile number  207 .  Calculating...
# (pid=281149) Extracting from bandfile number  208 .  Calculating...
# (pid=281152) Extracting from bandfile number  487 .  Calculating...
# (pid=281150) Extracting from bandfile number  407 .  Calculating...
# (pid=281148) Extracting from bandfile number  91 .  Calculating...
# (pid=281160) Extracting from bandfile number  367 .  Calculating...
# (pid=281151) Extracting from bandfile number  328 .  Calculating...
# (pid=281159) Extracting from bandfile number  126 .  Calculating...
# (pid=281149) Extracting from bandfile number  209 .  Calculating...
# (pid=281151) Extracting from bandfile number  329 .  Calculating...
# (pid=281149) Extracting from bandfile number  210 .  Calculating...
# (pid=281162) Extracting from bandfile number  249 .  Calculating...
# (pid=281158) Extracting from bandfile number  527 .  Calculating...
# (pid=281148) Extracting from bandfile number  92 .  Calculating...
# (pid=281156) Extracting from bandfile number  9 .  Calculating...
# (pid=281162) Extracting from bandfile number  250 .  Calculating...
# (pid=281153) Extracting from bandfile number  52 .  Calculating...
# (pid=281151) Extracting from bandfile number  330 .  Calculating...
# (pid=281156) Extracting from bandfile number  10 .  Calculating...
# (pid=281153) Extracting from bandfile number  53 .  Calculating...
# (pid=281147) Extracting from bandfile number  451 .  Calculating...
# (pid=281158) Extracting from bandfile number  528 .  Calculating...
# (pid=281160) Extracting from bandfile number  368 .  Calculating...
# (pid=281155) Extracting from bandfile number  288 .  Calculating...
# (pid=281150) Extracting from bandfile number  408 .  Calculating...
# (pid=281157) Extracting from bandfile number  571 .  Calculating...
# (pid=281154) Extracting from bandfile number  167 .  Calculating...
# (pid=281159) Extracting from bandfile number  127 .  Calculating...
# (pid=281151) Extracting from bandfile number  331 .  Calculating...
# (pid=281149) Extracting from bandfile number  211 .  Calculating...
# (pid=281158) Extracting from bandfile number  529 .  Calculating...
# (pid=281150) Extracting from bandfile number  409 .  Calculating...
# (pid=281152) Extracting from bandfile number  488 .  Calculating...
# (pid=281155) Extracting from bandfile number  289 .  Calculating...
# (pid=281162) Extracting from bandfile number  251 .  Calculating...
# (pid=281162) Extracting from bandfile number  252 .  Calculating...
# (pid=281155) Extracting from bandfile number  290 .  Calculating...
# (pid=281150) Extracting from bandfile number  410 .  Calculating...
# (pid=281156) Extracting from bandfile number  11 .  Calculating...
# (pid=281148) Extracting from bandfile number  93 .  Calculating...
# (pid=281162) Extracting from bandfile number  253 .  Calculating...
# (pid=281157) Extracting from bandfile number  572 .  Calculating...
# (pid=281155) Extracting from bandfile number  291 .  Calculating...
# (pid=281156) Extracting from bandfile number  12 .  Calculating...
# (pid=281158) Extracting from bandfile number  530 .  Calculating...
# (pid=281156) Extracting from bandfile number  13 .  Calculating...
# (pid=281157) Extracting from bandfile number  573 .  Calculating...
# (pid=281149) Extracting from bandfile number  212 .  Calculating...
# (pid=281160) Extracting from bandfile number  369 .  Calculating...
# (pid=281158) Extracting from bandfile number  531 .  Calculating...
# (pid=281160) Extracting from bandfile number  370 .  Calculating...
# (pid=281157) Extracting from bandfile number  574 .  Calculating...
# (pid=281155) Extracting from bandfile number  292 .  Calculating...
# (pid=281147) Extracting from bandfile number  452 .  Calculating...
# (pid=281158) Extracting from bandfile number  532 .  Calculating...
# (pid=281153) Extracting from bandfile number  54 .  Calculating...
# (pid=281152) Extracting from bandfile number  489 .  Calculating...
# (pid=281154) Extracting from bandfile number  168 .  Calculating...
# (pid=281151) Extracting from bandfile number  332 .  Calculating...
# (pid=281150) Extracting from bandfile number  411 .  Calculating...
# (pid=281151) Extracting from bandfile number  333 .  Calculating...
# (pid=281156) Extracting from bandfile number  14 .  Calculating...
# (pid=281150) Extracting from bandfile number  412 .  Calculating...
# (pid=281156) Extracting from bandfile number  15 .  Calculating...
# (pid=281150) Extracting from bandfile number  413 .  Calculating...
# (pid=281159) Extracting from bandfile number  128 .  Calculating...
# (pid=281153) Extracting from bandfile number  55 .  Calculating...
# (pid=281157) Extracting from bandfile number  575 .  Calculating...
# (pid=281153) Extracting from bandfile number  56 .  Calculating...
# (pid=281147) Extracting from bandfile number  453 .  Calculating...
# (pid=281148) Extracting from bandfile number  94 .  Calculating...
# (pid=281147) Extracting from bandfile number  454 .  Calculating...
# (pid=281154) Extracting from bandfile number  169 .  Calculating...
# (pid=281148) Extracting from bandfile number  95 .  Calculating...
# (pid=281148) Extracting from bandfile number  96 .  Calculating...
# (pid=281155) Extracting from bandfile number  293 .  Calculating...
# (pid=281162) Extracting from bandfile number  254 .  Calculating...
# (pid=281160) Extracting from bandfile number  371 .  Calculating...
# (pid=281147) Extracting from bandfile number  455 .  Calculating...
# (pid=281155) Extracting from bandfile number  294 .  Calculating...
# (pid=281152) Extracting from bandfile number  490 .  Calculating...
# (pid=281148) Extracting from bandfile number  97 .  Calculating...
# (pid=281152) Extracting from bandfile number  491 .  Calculating...
# (pid=281150) Extracting from bandfile number  414 .  Calculating...
# (pid=281156) Extracting from bandfile number  16 .  Calculating...
# (pid=281157) Extracting from bandfile number  576 .  Calculating...
# (pid=281155) Extracting from bandfile number  295 .  Calculating...
# (pid=281159) Extracting from bandfile number  129 .  Calculating...
# (pid=281149) Extracting from bandfile number  213 .  Calculating...
# (pid=281157) Extracting from bandfile number  577 .  Calculating...
# (pid=281153) Extracting from bandfile number  57 .  Calculating...
# (pid=281158) Extracting from bandfile number  533 .  Calculating...
# (pid=281151) Extracting from bandfile number  334 .  Calculating...
# (pid=281155) Extracting from bandfile number  296 .  Calculating...
# (pid=281155) Extracting from bandfile number  297 .  Calculating...
# (pid=281158) Extracting from bandfile number  534 .  Calculating...
# (pid=281155) Extracting from bandfile number  298 .  Calculating...
# (pid=281152) Extracting from bandfile number  492 .  Calculating...
# (pid=281156) Extracting from bandfile number  17 .  Calculating...
# (pid=281162) Extracting from bandfile number  255 .  Calculating...
# (pid=281154) Extracting from bandfile number  170 .  Calculating...
# (pid=281158) Extracting from bandfile number  535 .  Calculating...
# (pid=281157) Extracting from bandfile number  578 .  Calculating...
# (pid=281154) Extracting from bandfile number  171 .  Calculating...
# (pid=281158) Extracting from bandfile number  536 .  Calculating...
# (pid=281162) Extracting from bandfile number  256 .  Calculating...
# (pid=281160) Extracting from bandfile number  372 .  Calculating...
# (pid=281153) Extracting from bandfile number  58 .  Calculating...
# (pid=281147) Extracting from bandfile number  456 .  Calculating...
# (pid=281158) Extracting from bandfile number  537 .  Calculating...
# (pid=281148) Extracting from bandfile number  98 .  Calculating...
# (pid=281157) Extracting from bandfile number  579 .  Calculating...
# (pid=281150) Extracting from bandfile number  415 .  Calculating...
# (pid=281159) Extracting from bandfile number  130 .  Calculating...
# (pid=281162) Extracting from bandfile number  257 .  Calculating...
# (pid=281156) Extracting from bandfile number  18 .  Calculating...
# (pid=281148) Extracting from bandfile number  99 .  Calculating...
# (pid=281159) Extracting from bandfile number  131 .  Calculating...
# (pid=281151) Extracting from bandfile number  335 .  Calculating...
# (pid=281159) Extracting from bandfile number  132 .  Calculating...
# (pid=281148) Extracting from bandfile number  100 .  Calculating...
# (pid=281160) Extracting from bandfile number  373 .  Calculating...
# (pid=281153) Extracting from bandfile number  59 .  Calculating...
# (pid=281149) Extracting from bandfile number  214 .  Calculating...
# (pid=281162) Extracting from bandfile number  258 .  Calculating...
# (pid=281162) Extracting from bandfile number  259 .  Calculating...
# (pid=281155) Extracting from bandfile number  299 .  Calculating...
# (pid=281155) Extracting from bandfile number  300 .  Calculating...
# (pid=281152) Extracting from bandfile number  493 .  Calculating...
# (pid=281160) Extracting from bandfile number  374 .  Calculating...
# (pid=281150) Extracting from bandfile number  416 .  Calculating...
# (pid=281154) Extracting from bandfile number  172 .  Calculating...
# (pid=281162) Extracting from bandfile number  260 .  Calculating...
# (pid=281150) Extracting from bandfile number  417 .  Calculating...
# (pid=281154) Extracting from bandfile number  173 .  Calculating...
# (pid=281159) Extracting from bandfile number  133 .  Calculating...
# (pid=281154) Extracting from bandfile number  174 .  Calculating...
# (pid=281159) Extracting from bandfile number  134 .  Calculating...
# (pid=281153) Extracting from bandfile number  60 .  Calculating...
# (pid=281153) Extracting from bandfile number  61 .  Calculating...
# (pid=281148) Extracting from bandfile number  101 .  Calculating...
# (pid=281155) Extracting from bandfile number  301 .  Calculating...
# (pid=281147) Extracting from bandfile number  457 .  Calculating...
# (pid=281151) Extracting from bandfile number  336 .  Calculating...
# (pid=281156) Extracting from bandfile number  19 .  Calculating...
# (pid=281149) Extracting from bandfile number  215 .  Calculating...
# (pid=281152) Extracting from bandfile number  494 .  Calculating...
# (pid=281154) Extracting from bandfile number  175 .  Calculating...
# (pid=281147) Extracting from bandfile number  458 .  Calculating...
# (pid=281160) Extracting from bandfile number  375 .  Calculating...
# (pid=281158) Extracting from bandfile number  538 .  Calculating...
# (pid=281157) Extracting from bandfile number  580 .  Calculating...
# (pid=281160) Extracting from bandfile number  376 .  Calculating...
# (pid=281157) Extracting from bandfile number  581 .  Calculating...
# (pid=281147) Extracting from bandfile number  459 .  Calculating...
# (pid=281157) Extracting from bandfile number  582 .  Calculating...
# (pid=281150) Extracting from bandfile number  418 .  Calculating...
# (pid=281160) Extracting from bandfile number  377 .  Calculating...
# (pid=281159) Extracting from bandfile number  135 .  Calculating...
# (pid=281153) Extracting from bandfile number  62 .  Calculating...
# (pid=281150) Extracting from bandfile number  419 .  Calculating...
# (pid=281162) Extracting from bandfile number  261 .  Calculating...
# (pid=281157) Extracting from bandfile number  583 .  Calculating...
# (pid=281150) Extracting from bandfile number  420 .  Calculating...
# (pid=281151) Extracting from bandfile number  337 .  Calculating...
# (pid=281155) Extracting from bandfile number  302 .  Calculating...
# (pid=281157) Extracting from bandfile number  584 .  Calculating...
# (pid=281151) Extracting from bandfile number  338 .  Calculating...
# (pid=281150) Extracting from bandfile number  421 .  Calculating...
# (pid=281154) Extracting from bandfile number  176 .  Calculating...
# (pid=281155) Extracting from bandfile number  303 .  Calculating...
# (pid=281157) Extracting from bandfile number  585 .  Calculating...
# (pid=281156) Extracting from bandfile number  20 .  Calculating...
# (pid=281155) Extracting from bandfile number  304 .  Calculating...
# (pid=281149) Extracting from bandfile number  216 .  Calculating...
# (pid=281155) Extracting from bandfile number  305 .  Calculating...
# (pid=281152) Extracting from bandfile number  495 .  Calculating...
# (pid=281149) Extracting from bandfile number  217 .  Calculating...
# (pid=281151) Extracting from bandfile number  339 .  Calculating...
# (pid=281152) Extracting from bandfile number  496 .  Calculating...
# (pid=281150) Extracting from bandfile number  422 .  Calculating...
# (pid=281149) Extracting from bandfile number  218 .  Calculating...
# (pid=281148) Extracting from bandfile number  102 .  Calculating...
# (pid=281158) Extracting from bandfile number  539 .  Calculating...
# (pid=281151) Extracting from bandfile number  340 .  Calculating...
# (pid=281150) Extracting from bandfile number  423 .  Calculating...
# (pid=281148) Extracting from bandfile number  103 .  Calculating...
# (pid=281158) Extracting from bandfile number  540 .  Calculating...
# (pid=281153) Extracting from bandfile number  63 .  Calculating...
# (pid=281149) Extracting from bandfile number  219 .  Calculating...
# (pid=281151) Extracting from bandfile number  341 .  Calculating...
# (pid=281150) Extracting from bandfile number  424 .  Calculating...
# (pid=281153) Extracting from bandfile number  64 .  Calculating...
# (pid=281147) Extracting from bandfile number  460 .  Calculating...
# (pid=281150) Extracting from bandfile number  425 .  Calculating...
# (pid=281160) Extracting from bandfile number  378 .  Calculating...
# (pid=281154) Extracting from bandfile number  177 .  Calculating...
# (pid=281152) Extracting from bandfile number  497 .  Calculating...
# (pid=281160) Extracting from bandfile number  379 .  Calculating...
# (pid=281159) Extracting from bandfile number  136 .  Calculating...
# (pid=281162) Extracting from bandfile number  262 .  Calculating...
# (pid=281153) Extracting from bandfile number  65 .  Calculating...
# (pid=281160) Extracting from bandfile number  380 .  Calculating...
# (pid=281150) Extracting from bandfile number  426 .  Calculating...
# (pid=281160) Extracting from bandfile number  381 .  Calculating...
# (pid=281150) Extracting from bandfile number  427 .  Calculating...
# (pid=281156) Extracting from bandfile number  21 .  Calculating...
# (pid=281152) Extracting from bandfile number  498 .  Calculating...
# (pid=281156) Extracting from bandfile number  22 .  Calculating...
# (pid=281154) Extracting from bandfile number  178 .  Calculating...
# (pid=281150) Extracting from bandfile number  428 .  Calculating...
# (pid=281155) Extracting from bandfile number  306 .  Calculating...
# (pid=281162) Extracting from bandfile number  263 .  Calculating...
# (pid=281149) Extracting from bandfile number  220 .  Calculating...
# (pid=281150) Extracting from bandfile number  429 .  Calculating...
# (pid=281157) Extracting from bandfile number  586 .  Calculating...
# (pid=281149) Extracting from bandfile number  221 .  Calculating...
# (pid=281162) Extracting from bandfile number  264 .  Calculating...
# (pid=281157) Extracting from bandfile number  587 .  Calculating...
# (pid=281154) Extracting from bandfile number  179 .  Calculating...
# (pid=281162) Extracting from bandfile number  265 .  Calculating...
# (pid=281149) Extracting from bandfile number  222 .  Calculating...
# (pid=281147) Extracting from bandfile number  461 .  Calculating...
# (pid=281157) Extracting from bandfile number  588 .  Calculating...
# (pid=281151) Extracting from bandfile number  342 .  Calculating...
# (pid=281148) Extracting from bandfile number  104 .  Calculating...
# (pid=281162) Extracting from bandfile number  266 .  Calculating...
# (pid=281155) Extracting from bandfile number  307 .  Calculating...
# (pid=281153) Extracting from bandfile number  66 .  Calculating...
# (pid=281158) Extracting from bandfile number  541 .  Calculating...
# (pid=281160) Extracting from bandfile number  382 .  Calculating...
# (pid=281151) Extracting from bandfile number  343 .  Calculating...
# (pid=281162) Extracting from bandfile number  267 .  Calculating...
# (pid=281160) Extracting from bandfile number  383 .  Calculating...
# (pid=281148) Extracting from bandfile number  105 .  Calculating...
# (pid=281162) Extracting from bandfile number  268 .  Calculating...
# (pid=281151) Extracting from bandfile number  344 .  Calculating...
# (pid=281162) Extracting from bandfile number  269 .  Calculating...
# (pid=281153) Extracting from bandfile number  67 .  Calculating...
# (pid=281162) Extracting from bandfile number  270 .  Calculating...
# (pid=281153) Extracting from bandfile number  68 .  Calculating...
# (pid=281148) Extracting from bandfile number  106 .  Calculating...
# (pid=281150) Extracting from bandfile number  430 .  Calculating...
# (pid=281148) Extracting from bandfile number  107 .  Calculating...
# (pid=281152) Extracting from bandfile number  499 .  Calculating...
# (pid=281148) Extracting from bandfile number  108 .  Calculating...
# (pid=281160) Extracting from bandfile number  384 .  Calculating...
# (pid=281158) Extracting from bandfile number  542 .  Calculating...
# (pid=281156) Extracting from bandfile number  23 .  Calculating...
# (pid=281157) Extracting from bandfile number  589 .  Calculating...
# (pid=281159) Extracting from bandfile number  137 .  Calculating...
# (pid=281154) Extracting from bandfile number  180 .  Calculating...
# (pid=281147) Extracting from bandfile number  462 .  Calculating...
# (pid=281160) Extracting from bandfile number  385 .  Calculating...
# (pid=281162) Extracting from bandfile number  271 .  Calculating...
# (pid=281149) Extracting from bandfile number  223 .  Calculating...
# (pid=281157) Extracting from bandfile number  590 .  Calculating...
# (pid=281150) Extracting from bandfile number  431 .  Calculating...
# (pid=281153) Extracting from bandfile number  69 .  Calculating...
# (pid=281162) Extracting from bandfile number  272 .  Calculating...
# (pid=281150) Extracting from bandfile number  432 .  Calculating...
# (pid=281152) Extracting from bandfile number  500 .  Calculating...
# (pid=281158) Extracting from bandfile number  543 .  Calculating...
# (pid=281148) Extracting from bandfile number  109 .  Calculating...
# (pid=281153) Extracting from bandfile number  70 .  Calculating...
# (pid=281156) Extracting from bandfile number  24 .  Calculating...
# (pid=281159) Extracting from bandfile number  138 .  Calculating...
# (pid=281155) Extracting from bandfile number  308 .  Calculating...
# (pid=281151) Extracting from bandfile number  345 .  Calculating...
# (pid=281155) Extracting from bandfile number  309 .  Calculating...
# (pid=281154) Extracting from bandfile number  181 .  Calculating...
# (pid=281147) Extracting from bandfile number  463 .  Calculating...
# (pid=281149) Extracting from bandfile number  224 .  Calculating...
# (pid=281160) Extracting from bandfile number  386 .  Calculating...
# (pid=281162) Extracting from bandfile number  273 .  Calculating...
# (pid=281149) Extracting from bandfile number  225 .  Calculating...
# (pid=281157) Extracting from bandfile number  591 .  Calculating...
# (pid=281149) Extracting from bandfile number  226 .  Calculating...
# (pid=281157) Extracting from bandfile number  592 .  Calculating...
# (pid=281157) Extracting from bandfile number  593 .  Calculating...
# (pid=281149) Extracting from bandfile number  227 .  Calculating...
# (pid=281157) Extracting from bandfile number  594 .  Calculating...
# (pid=281162) Extracting from bandfile number  274 .  Calculating...
# (pid=281157) Extracting from bandfile number  595 .  Calculating...
# (pid=281150) Extracting from bandfile number  433 .  Calculating...
# (pid=281160) Extracting from bandfile number  387 .  Calculating...
# (pid=281157) Extracting from bandfile number  596 .  Calculating...
# (pid=281152) Extracting from bandfile number  501 .  Calculating...
# (pid=281157) Extracting from bandfile number  597 .  Calculating...
# (pid=281150) Extracting from bandfile number  434 .  Calculating...
# (pid=281149) Extracting from bandfile number  228 .  Calculating...
# (pid=281162) Extracting from bandfile number  275 .  Calculating...
# (pid=281151) Extracting from bandfile number  346 .  Calculating...
# (pid=281153) Extracting from bandfile number  71 .  Calculating...
# (pid=281159) Extracting from bandfile number  139 .  Calculating...
# (pid=281147) Extracting from bandfile number  464 .  Calculating...
# (pid=281155) Extracting from bandfile number  310 .  Calculating...
# (pid=281153) Extracting from bandfile number  72 .  Calculating...
# (pid=281149) Extracting from bandfile number  229 .  Calculating...
# (pid=281156) Extracting from bandfile number  25 .  Calculating...
# (pid=281158) Extracting from bandfile number  544 .  Calculating...
# (pid=281148) Extracting from bandfile number  110 .  Calculating...
# (pid=281162) Extracting from bandfile number  276 .  Calculating...
# (pid=281155) Extracting from bandfile number  311 .  Calculating...
# (pid=281160) Extracting from bandfile number  388 .  Calculating...
# (pid=281148) Extracting from bandfile number  111 .  Calculating...
# (pid=281160) Extracting from bandfile number  389 .  Calculating...
# (pid=281158) Extracting from bandfile number  545 .  Calculating...
# (pid=281160) Extracting from bandfile number  390 .  Calculating...
# (pid=281154) Extracting from bandfile number  182 .  Calculating...
# (pid=281152) Extracting from bandfile number  502 .  Calculating...
# (pid=281157) Extracting from bandfile number  598 .  Calculating...
# (pid=281154) Extracting from bandfile number  183 .  Calculating...
# (pid=281162) Extracting from bandfile number  277 .  Calculating...
# (pid=281157) Extracting from bandfile number  599 .  Calculating...
# (pid=281148) Extracting from bandfile number  112 .  Calculating...
# (pid=281156) Extracting from bandfile number  26 .  Calculating...
# (pid=281148) Extracting from bandfile number  113 .  Calculating...
# (pid=281159) Extracting from bandfile number  140 .  Calculating...
# (pid=281156) Extracting from bandfile number  27 .  Calculating...
# (pid=281151) Extracting from bandfile number  347 .  Calculating...
# (pid=281152) Extracting from bandfile number  503 .  Calculating...
# (pid=281147) Extracting from bandfile number  465 .  Calculating...
# (pid=281153) Extracting from bandfile number  73 .  Calculating...
# (pid=281162) Extracting from bandfile number  278 .  Calculating...
# (pid=281158) Extracting from bandfile number  546 .  Calculating...
# (pid=281153) Extracting from bandfile number  74 .  Calculating...
# (pid=281156) Extracting from bandfile number  28 .  Calculating...
# (pid=281151) Extracting from bandfile number  348 .  Calculating...
# (pid=281153) Extracting from bandfile number  75 .  Calculating...
# (pid=281156) Extracting from bandfile number  29 .  Calculating...
# (pid=281158) Extracting from bandfile number  547 .  Calculating...
# (pid=281150) Extracting from bandfile number  435 .  Calculating...
# (pid=281147) Extracting from bandfile number  466 .  Calculating...
# (pid=281156) Extracting from bandfile number  30 .  Calculating...
# (pid=281157) Extracting from bandfile number  600 .  Calculating...
# (pid=281155) Extracting from bandfile number  312 .  Calculating...
# (pid=281154) Extracting from bandfile number  184 .  Calculating...
# (pid=281149) Extracting from bandfile number  230 .  Calculating...
# (pid=281162) Extracting from bandfile number  279 .  Calculating...
# (pid=281156) Extracting from bandfile number  31 .  Calculating...
# (pid=281155) Extracting from bandfile number  313 .  Calculating...
# (pid=281160) Extracting from bandfile number  391 .  Calculating...
# (pid=281162) Extracting from bandfile number  280 .  Calculating...
# (pid=281154) Extracting from bandfile number  185 .  Calculating...
# (pid=281160) Extracting from bandfile number  392 .  Calculating...
# (pid=281159) Extracting from bandfile number  141 .  Calculating...
# (pid=281154) Extracting from bandfile number  186 .  Calculating...
# (pid=281160) Extracting from bandfile number  393 .  Calculating...
# (pid=281151) Extracting from bandfile number  349 .  Calculating...
# (pid=281158) Extracting from bandfile number  548 .  Calculating...
# (pid=281148) Extracting from bandfile number  114 .  Calculating...
# (pid=281148) Extracting from bandfile number  115 .  Calculating...
# (pid=281157) Done with files 561 - 600 .
# (pid=281158) Extracting from bandfile number  549 .  Calculating...
# (pid=281147) Extracting from bandfile number  467 .  Calculating...
# (pid=281150) Extracting from bandfile number  436 .  Calculating...
# (pid=281159) Extracting from bandfile number  142 .  Calculating...
# (pid=281156) Extracting from bandfile number  32 .  Calculating...
# (pid=281149) Extracting from bandfile number  231 .  Calculating...
# (pid=281152) Extracting from bandfile number  504 .  Calculating...
# (pid=281150) Extracting from bandfile number  437 .  Calculating...
# (pid=281162) Done with files 241 - 280 .
# (pid=281153) Extracting from bandfile number  76 .  Calculating...
# (pid=281147) Extracting from bandfile number  468 .  Calculating...
# (pid=281155) Extracting from bandfile number  314 .  Calculating...
# (pid=281154) Extracting from bandfile number  187 .  Calculating...
# (pid=281160) Extracting from bandfile number  394 .  Calculating...
# (pid=281148) Extracting from bandfile number  116 .  Calculating...
# (pid=281154) Extracting from bandfile number  188 .  Calculating...
# (pid=281159) Extracting from bandfile number  143 .  Calculating...
# (pid=281154) Extracting from bandfile number  189 .  Calculating...
# (pid=281151) Extracting from bandfile number  350 .  Calculating...
# (pid=281158) Extracting from bandfile number  550 .  Calculating...
# (pid=281156) Extracting from bandfile number  33 .  Calculating...
# (pid=281151) Extracting from bandfile number  351 .  Calculating...
# (pid=281158) Extracting from bandfile number  551 .  Calculating...
# (pid=281154) Extracting from bandfile number  190 .  Calculating...
# (pid=281151) Extracting from bandfile number  352 .  Calculating...
# (pid=281153) Extracting from bandfile number  77 .  Calculating...
# (pid=281150) Extracting from bandfile number  438 .  Calculating...
# (pid=281156) Extracting from bandfile number  34 .  Calculating...
# (pid=281150) Extracting from bandfile number  439 .  Calculating...
# (pid=281160) Extracting from bandfile number  395 .  Calculating...
# (pid=281158) Extracting from bandfile number  552 .  Calculating...
# (pid=281149) Extracting from bandfile number  232 .  Calculating...
# (pid=281153) Extracting from bandfile number  78 .  Calculating...
# (pid=281159) Extracting from bandfile number  144 .  Calculating...
# (pid=281158) Extracting from bandfile number  553 .  Calculating...
# (pid=281155) Extracting from bandfile number  315 .  Calculating...
# (pid=281152) Extracting from bandfile number  505 .  Calculating...
# (pid=281147) Extracting from bandfile number  469 .  Calculating...
# (pid=281147) Extracting from bandfile number  470 .  Calculating...
# (pid=281150) Extracting from bandfile number  440 .  Calculating...
# (pid=281154) Extracting from bandfile number  191 .  Calculating...
# (pid=281152) Extracting from bandfile number  506 .  Calculating...
# (pid=281156) Extracting from bandfile number  35 .  Calculating...
# (pid=281159) Extracting from bandfile number  145 .  Calculating...
# (pid=281155) Extracting from bandfile number  316 .  Calculating...
# (pid=281155) Extracting from bandfile number  317 .  Calculating...
# (pid=281148) Extracting from bandfile number  117 .  Calculating...
# (pid=281160) Extracting from bandfile number  396 .  Calculating...
# (pid=281149) Extracting from bandfile number  233 .  Calculating...
# (pid=281148) Extracting from bandfile number  118 .  Calculating...
# (pid=281158) Extracting from bandfile number  554 .  Calculating...
# (pid=281154) Extracting from bandfile number  192 .  Calculating...
# (pid=281159) Extracting from bandfile number  146 .  Calculating...
# (pid=281159) Extracting from bandfile number  147 .  Calculating...
# (pid=281147) Extracting from bandfile number  471 .  Calculating...
# (pid=281150) Done with files 401 - 440 .
# (pid=281159) Extracting from bandfile number  148 .  Calculating...
# (pid=281151) Extracting from bandfile number  353 .  Calculating...
# (pid=281158) Extracting from bandfile number  555 .  Calculating...
# (pid=281159) Extracting from bandfile number  149 .  Calculating...
# (pid=281158) Extracting from bandfile number  556 .  Calculating...
# (pid=281154) Extracting from bandfile number  193 .  Calculating...
# (pid=281153) Extracting from bandfile number  79 .  Calculating...
# (pid=281156) Extracting from bandfile number  36 .  Calculating...
# (pid=281148) Extracting from bandfile number  119 .  Calculating...
# (pid=281147) Extracting from bandfile number  472 .  Calculating...
# (pid=281160) Extracting from bandfile number  397 .  Calculating...
# (pid=281149) Extracting from bandfile number  234 .  Calculating...
# (pid=281154) Extracting from bandfile number  194 .  Calculating...
# (pid=281152) Extracting from bandfile number  507 .  Calculating...
# (pid=281147) Extracting from bandfile number  473 .  Calculating...
# (pid=281154) Extracting from bandfile number  195 .  Calculating...
# (pid=281158) Extracting from bandfile number  557 .  Calculating...
# (pid=281154) Extracting from bandfile number  196 .  Calculating...
# (pid=281147) Extracting from bandfile number  474 .  Calculating...
# (pid=281151) Extracting from bandfile number  354 .  Calculating...
# (pid=281149) Extracting from bandfile number  235 .  Calculating...
# (pid=281147) Extracting from bandfile number  475 .  Calculating...
# (pid=281154) Extracting from bandfile number  197 .  Calculating...
# (pid=281151) Extracting from bandfile number  355 .  Calculating...
# (pid=281155) Extracting from bandfile number  318 .  Calculating...
# (pid=281159) Extracting from bandfile number  150 .  Calculating...
# (pid=281155) Extracting from bandfile number  319 .  Calculating...
# (pid=281154) Extracting from bandfile number  198 .  Calculating...
# (pid=281153) Extracting from bandfile number  80 .  Calculating...
# (pid=281156) Extracting from bandfile number  37 .  Calculating...
# (pid=281154) Extracting from bandfile number  199 .  Calculating...
# (pid=281155) Extracting from bandfile number  320 .  Calculating...
# (pid=281158) Extracting from bandfile number  558 .  Calculating...
# (pid=281152) Extracting from bandfile number  508 .  Calculating...
# (pid=281160) Extracting from bandfile number  398 .  Calculating...
# (pid=281149) Extracting from bandfile number  236 .  Calculating...
# (pid=281160) Extracting from bandfile number  399 .  Calculating...
# (pid=281148) Extracting from bandfile number  120 .  Calculating...
# (pid=281159) Extracting from bandfile number  151 .  Calculating...
# (pid=281159) Extracting from bandfile number  152 .  Calculating...
# (pid=281151) Extracting from bandfile number  356 .  Calculating...
# (pid=281159) Extracting from bandfile number  153 .  Calculating...
# (pid=281155) Done with files 281 - 320 .
# (pid=281148) Done with files 81 - 120 .
# (pid=281152) Extracting from bandfile number  509 .  Calculating...
# (pid=281156) Extracting from bandfile number  38 .  Calculating...
# (pid=281152) Extracting from bandfile number  510 .  Calculating...
# (pid=281156) Extracting from bandfile number  39 .  Calculating...
# (pid=281159) Extracting from bandfile number  154 .  Calculating...
# (pid=281147) Extracting from bandfile number  476 .  Calculating...
# (pid=281159) Extracting from bandfile number  155 .  Calculating...
# (pid=281149) Extracting from bandfile number  237 .  Calculating...
# (pid=281156) Extracting from bandfile number  40 .  Calculating...
# (pid=281149) Extracting from bandfile number  238 .  Calculating...
# (pid=281154) Extracting from bandfile number  200 .  Calculating...
# (pid=281159) Extracting from bandfile number  156 .  Calculating...
# (pid=281154) Done with files 161 - 200 .
# (pid=281158) Extracting from bandfile number  559 .  Calculating...
# (pid=281152) Extracting from bandfile number  511 .  Calculating...
# (pid=281151) Extracting from bandfile number  357 .  Calculating...
# (pid=281153) Done with files 41 - 80 .
# (pid=281160) Extracting from bandfile number  400 .  Calculating...
# (pid=281159) Extracting from bandfile number  157 .  Calculating...
# (pid=281160) Done with files 361 - 400 .
# (pid=281147) Extracting from bandfile number  477 .  Calculating...
# (pid=281151) Extracting from bandfile number  358 .  Calculating...
# (pid=281156) Done with files 1 - 40 .
# (pid=281149) Extracting from bandfile number  239 .  Calculating...
# (pid=281152) Extracting from bandfile number  512 .  Calculating...
# (pid=281152) Extracting from bandfile number  513 .  Calculating...
# (pid=281158) Extracting from bandfile number  560 .  Calculating...
# (pid=281149) Extracting from bandfile number  240 .  Calculating...
# (pid=281158) Done with files 521 - 560 .
# (pid=281159) Extracting from bandfile number  158 .  Calculating...
# (pid=281159) Extracting from bandfile number  159 .  Calculating...
# (pid=281151) Extracting from bandfile number  359 .  Calculating...
# (pid=281159) Extracting from bandfile number  160 .  Calculating...
# (pid=281147) Extracting from bandfile number  478 .  Calculating...
# (pid=281159) Done with files 121 - 160 .
# (pid=281147) Extracting from bandfile number  479 .  Calculating...
# (pid=281152) Extracting from bandfile number  514 .  Calculating...
# (pid=281152) Extracting from bandfile number  515 .  Calculating...
# (pid=281149) Done with files 201 - 240 .
# (pid=281152) Extracting from bandfile number  516 .  Calculating...
# (pid=281152) Extracting from bandfile number  517 .  Calculating...
# (pid=281147) Extracting from bandfile number  480 .  Calculating...
# (pid=281147) Done with files 441 - 480 .
# (pid=281151) Extracting from bandfile number  360 .  Calculating...
# (pid=281151) Done with files 321 - 360 .
# (pid=281152) Extracting from bandfile number  518 .  Calculating...
# (pid=281152) Extracting from bandfile number  519 .  Calculating...
# (pid=281152) Extracting from bandfile number  520 .  Calculating...
# (pid=281152) Done with files 481 - 520 .

# %%
# Ending parallel calculation
ray.shutdown()
